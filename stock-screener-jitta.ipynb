# %%
try:
    get_ipython().system('pip install pandas_datareader')
    get_ipython().system('pip install pandas')
    get_ipython().system('pip install matplotlib')
    get_ipython().system('pip install yahoofinancials')
    get_ipython().system('pip install requests')
    get_ipython().system('pip install sympy')
    get_ipython().system('pip install scipy')
    get_ipython().system('pip install numpy')
    get_ipython().system('pip install beautifulsoup4')
except Exception:
    pass
# Out:
# ^C

# %%
import os
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import pandas as pd
import requests
from sympy.solvers import solve
from sympy import Symbol
from scipy.optimize import fsolve
import numpy as np
from bs4 import BeautifulSoup
import threading

# %%
# tickers = [ 'bkk:2S', 'bkk:3K-BAT', 'bkk:7UP', 'bkk:A', 'bkk:AAV', 'bkk:ABICO', 'bkk:ABM', 'bkk:ACAP', 'bkk:ACC', 'bkk:ACE', 'bkk:ACG', 'bkk:ADB', 'bkk:ADVANC', 'bkk:AEC', 'bkk:AEONTS', 'bkk:AF', 'bkk:AFC', 'bkk:AGE', 'bkk:AH', 'bkk:AHC', 'bkk:AI', 'bkk:AIE', 'bkk:AIRA', 'bkk:AIT', 'bkk:AJ', 'bkk:AJA', 'bkk:AKP', 'bkk:AKR', 'bkk:ALL', 'bkk:ALLA', 'bkk:ALT', 'bkk:ALUCON', 'bkk:AMA', 'bkk:AMANAH', 'bkk:AMARIN', 'bkk:AMATA', 'bkk:AMATAV', 'bkk:AMC', 'bkk:ANAN', 'bkk:AOT', 'bkk:AP', 'bkk:APCO', 'bkk:APCS', 'bkk:APEX', 'bkk:APP', 'bkk:APURE', 'bkk:AQ', 'bkk:AQUA', 'bkk:ARIN', 'bkk:ARIP', 'bkk:ARROW', 'bkk:AS', 'bkk:ASAP', 'bkk:ASEFA', 'bkk:ASIA', 'bkk:ASIAN', 'bkk:ASIMAR', 'bkk:ASK', 'bkk:ASN', 'bkk:ASP', 'bkk:ATP30', 'bkk:AU', 'bkk:AUCT', 'bkk:AWC', 'bkk:AYUD', 'bkk:B', 'bkk:B52', 'bkk:BA', 'bkk:BAFS', 'bkk:BAM', 'bkk:BANPU', 'bkk:BAT-3K', 'bkk:BAY', 'bkk:BBL', 'bkk:BC', 'bkk:BCH', 'bkk:BCP', 'bkk:BCPG', 'bkk:BCT', 'bkk:BDMS', 'bkk:BEAUTY', 'bkk:BEC', 'bkk:BEM', 'bkk:BFIT', 'bkk:BGC', 'bkk:BGRIM', 'bkk:BGT', 'bkk:BH', 'bkk:BIG', 'bkk:BIZ', 'bkk:BJC', 'bkk:BJCHI', 'bkk:BLA', 'bkk:BLAND', 'bkk:BLISS', 'bkk:BM', 'bkk:BOL', 'bkk:BPP', 'bkk:BR', 'bkk:BROCK', 'bkk:BROOK', 'bkk:BRR', 'bkk:BSBM', 'bkk:BSM', 'bkk:BTNC', 'bkk:BTS', 'bkk:BTW', 'bkk:BUI', 'bkk:BWG', 'bkk:CAZ', 'bkk:CBG', 'bkk:CCET', 'bkk:CCP', 'bkk:CEN', 'bkk:CENTEL', 'bkk:CFRESH', 'bkk:CGD', 'bkk:CGH', 'bkk:CHARAN', 'bkk:CHAYO', 'bkk:CHEWA', 'bkk:CHG', 'bkk:CHO', 'bkk:CHOTI', 'bkk:CHOW', 'bkk:CI', 'bkk:CIG', 'bkk:CIMBT', 'bkk:CITY', 'bkk:CK', 'bkk:CKP', 'bkk:CM', 'bkk:CMAN', 'bkk:CMC', 'bkk:CMO', 'bkk:CMR', 'bkk:CNT', 'bkk:COL', 'bkk:COLOR', 'bkk:COM7', 'bkk:COMAN', 'bkk:COTTO', 'bkk:CPALL', 'bkk:CPF', 'bkk:CPH', 'bkk:CPI', 'bkk:CPL', 'bkk:CPN', 'bkk:CPR', 'bkk:CPT', 'bkk:CPW', 'bkk:CRANE', 'bkk:CRC', 'bkk:CRD', 'bkk:CSC', 'bkk:CSP', 'bkk:CSR', 'bkk:CSS', 'bkk:CTW', 'bkk:CWT', 'bkk:D', 'bkk:DCC', 'bkk:DCON', 'bkk:DCORP', 'bkk:DDD', 'bkk:DELTA', 'bkk:DEMCO', 'bkk:DHOUSE', 'bkk:DIMET', 'bkk:DOD', 'bkk:DOHOME', 'bkk:DRT', 'bkk:DTAC', 'bkk:DTC', 'bkk:DTCI', 'bkk:DV8', 'bkk:EA', 'bkk:EASON', 'bkk:EASTW', 'bkk:ECF', 'bkk:ECL', 'bkk:EE', 'bkk:EFORL', 'bkk:EGCO', 'bkk:EKH', 'bkk:EMC', 'bkk:EP', 'bkk:EPG', 'bkk:ERW', 'bkk:ESSO', 'bkk:ESTAR', 'bkk:ETC', 'bkk:ETE', 'bkk:EVER', 'bkk:F&D', 'bkk:FANCY', 'bkk:FE', 'bkk:FLOYD', 'bkk:FMT', 'bkk:FN', 'bkk:FNS', 'bkk:FORTH', 'bkk:FPI', 'bkk:FPT', 'bkk:FSMART', 'bkk:FSS', 'bkk:FTE', 'bkk:FVC', 'bkk:GBX', 'bkk:GC', 'bkk:GCAP', 'bkk:GEL', 'bkk:GENCO', 'bkk:GFPT', 'bkk:GGC', 'bkk:GIFT', 'bkk:GJS', 'bkk:GL', 'bkk:GLAND', 'bkk:GLOBAL', 'bkk:GLOCON', 'bkk:GOLD', 'bkk:GPI', 'bkk:GPSC', 'bkk:GRAMMY', 'bkk:GRAND', 'bkk:GREEN', 'bkk:GSC', 'bkk:GSTEEL', 'bkk:GTB', 'bkk:GULF', 'bkk:GUNKUL', 'bkk:GYT', 'bkk:HANA', 'bkk:HARN', 'bkk:HFT', 'bkk:HMPRO', 'bkk:HPT', 'bkk:HTC', 'bkk:HTECH', 'bkk:HUMAN', 'bkk:HYDRO', 'bkk:ICC', 'bkk:ICHI', 'bkk:ICN', 'bkk:IFEC', 'bkk:IFS', 'bkk:IHL', 'bkk:IIG', 'bkk:III', 'bkk:ILINK', 'bkk:ILM', 'bkk:IMH', 'bkk:INET', 'bkk:INGRS', 'bkk:INOX', 'bkk:INSET', 'bkk:INSURE', 'bkk:INTUCH', 'bkk:IP', 'bkk:IRC', 'bkk:IRCP', 'bkk:IRPC', 'bkk:IT', 'bkk:ITD', 'bkk:ITEL', 'bkk:IVL', 'bkk:J', 'bkk:JAS', 'bkk:JCK', 'bkk:JCKH', 'bkk:JCT', 'bkk:JKN', 'bkk:JMART', 'bkk:JMT', 'bkk:JR', 'bkk:JSP', 'bkk:JTS', 'bkk:JUBILE', 'bkk:JUTHA', 'bkk:JWD', 'bkk:K', 'bkk:KAMART', 'bkk:KASET', 'bkk:KBANK', 'bkk:KBS', 'bkk:KC', 'bkk:KCAR', 'bkk:KCE', 'bkk:KCM', 'bkk:KDH', 'bkk:KGI', 'bkk:KIAT', 'bkk:KK', 'bkk:KKC', 'bkk:KKP', 'bkk:KOOL', 'bkk:KSL', 'bkk:KTB', 'bkk:KTC', 'bkk:KTECH', 'bkk:KTIS', 'bkk:KUMWEL', 'bkk:KUN', 'bkk:KWC', 'bkk:KWG', 'bkk:KWM', 'bkk:KYE', 'bkk:L&E', 'bkk:LALIN', 'bkk:LANNA', 'bkk:LDC', 'bkk:LEE', 'bkk:LEO', 'bkk:LH', 'bkk:LHFG', 'bkk:LHK', 'bkk:LIT', 'bkk:LOXLEY', 'bkk:LPH', 'bkk:LPN', 'bkk:LRH', 'bkk:LST', 'bkk:M', 'bkk:M-CHAI', 'bkk:MACO', 'bkk:MAJOR', 'bkk:MAKRO', 'bkk:MALEE', 'bkk:MANRIN', 'bkk:MATCH', 'bkk:MATI', 'bkk:MAX', 'bkk:MBAX', 'bkk:', 'bkk:ET', 'bkk:MC', 'bkk:MCOT', 'bkk:MCS', 'bkk:MDX', 'bkk:MEGA', 'bkk:META', 'bkk:METCO', 'bkk:MFC', 'bkk:MFEC', 'bkk:MGT', 'bkk:MICRO', 'bkk:MIDA', 'bkk:MILL', 'bkk:MINT', 'bkk:MITSIB', 'bkk:MJD', 'bkk:MK', 'bkk:ML', 'bkk:MM', 'bkk:MODERN', 'bkk:MONO', 'bkk:MOONG', 'bkk:MORE', 'bkk:MPG', 'bkk:MPIC', 'bkk:MSC', 'bkk:MTC', 'bkk:MTI', 'bkk:MVP', 'bkk:NBC', 'bkk:NC', 'bkk:NCAP', 'bkk:NCH', 'bkk:NCL', 'bkk:NDR', 'bkk:NEP', 'bkk:NER', 'bkk:NETBAY', 'bkk:NEW', 'bkk:NEWS', 'bkk:NEX', 'bkk:NFC', 'bkk:NINE', 'bkk:NKI', 'bkk:NMG', 'bkk:NNCL', 'bkk:NOBLE', 'bkk:NOK', 'bkk:NPK', 'bkk:NRF', 'bkk:NSI', 'bkk:NTV', 'bkk:NUSA', 'bkk:NVD', 'bkk:NWR', 'bkk:NYT', 'bkk:OCC', 'bkk:OCEAN', 'bkk:OGC', 'bkk:OHTL', 'bkk:OISHI', 'bkk:ORI', 'bkk:OSP', 'bkk:OTO', 'bkk:PACE', 'bkk:PAE', 'bkk:PAF', 'bkk:PAP', 'bkk:PATO', 'bkk:PB', 'bkk:PCSGH', 'bkk:PDG', 'bkk:PDI', 'bkk:PDJ', 'bkk:PE', 'bkk:PERM', 'bkk:PF', 'bkk:PG', 'bkk:PHOL', 'bkk:PICO', 'bkk:PIMO', 'bkk:PJW', 'bkk:PK', 'bkk:PL', 'bkk:PLANB', 'bkk:PLANET', 'bkk:PLAT', 'bkk:PLE', 'bkk:PM', 'bkk:PMTA', 'bkk:POLAR', 'bkk:PORT', 'bkk:POST', 'bkk:PPM', 'bkk:PPP', 'bkk:PPPM', 'bkk:PPS', 'bkk:PR9', 'bkk:PRAKIT', 'bkk:PRAPAT', 'bkk:PREB', 'bkk:PRECHA', 'bkk:PRG', 'bkk:PRIME', 'bkk:PRIN', 'bkk:PRINC', 'bkk:PRM', 'bkk:PRO', 'bkk:PROUD', 'bkk:PSH', 'bkk:PSL', 'bkk:PSTC', 'bkk:PT', 'bkk:PTG', 'bkk:PTL', 'bkk:PTT', 'bkk:PTTEP', 'bkk:PTTGC', 'bkk:PYLON', 'bkk:Q-CON', 'bkk:QH', 'bkk:QLT', 'bkk:QTC', 'bkk:RAM', 'bkk:RATCH', 'bkk:RBF', 'bkk:RCI', 'bkk:RCL', 'bkk:RICH', 'bkk:RICHY', 'bkk:RJH', 'bkk:RML', 'bkk:ROCK', 'bkk:ROH', 'bkk:ROJNA', 'bkk:RP', 'bkk:RPC', 'bkk:RPH', 'bkk:RS', 'bkk:RSP', 'bkk:RT', 'bkk:RWI', 'bkk:S&J', 'bkk:S', 'bkk:S11', 'bkk:SAAM', 'bkk:SABINA', 'bkk:SABUY', 'bkk:SAK', 'bkk:SALEE', 'bkk:SAM', 'bkk:SAMART', 'bkk:SAMCO', 'bkk:SAMTEL', 'bkk:SANKO', 'bkk:SAPPE', 'bkk:SAT', 'bkk:SAUCE', 'bkk:SAWAD', 'bkk:SAWANG', 'bkk:SC', 'bkk:SCB', 'bkk:SCC', 'bkk:SCCC', 'bkk:SCG', 'bkk:SCGP', 'bkk:SCI', 'bkk:SCM', 'bkk:SCN', 'bkk:SCP', 'bkk:SDC', 'bkk:SE', 'bkk:SE-ED', 'bkk:SEAFCO', 'bkk:SEAOIL', 'bkk:SEG', 'bkk:SELIC', 'bkk:SENA', 'bkk:SF', 'bkk:SFLEX', 'bkk:SFP', 'bkk:SFT', 'bkk:SGF', 'bkk:SGP', 'bkk:SHANG', 'bkk:SHR', 'bkk:SIAM', 'bkk:SICT', 'bkk:SIMAT', 'bkk:SINGER', 'bkk:SIRI', 'bkk:SIS', 'bkk:SISB', 'bkk:SITHAI', 'bkk:SK', 'bkk:SKE', 'bkk:SKN', 'bkk:SKR', 'bkk:SKY', 'bkk:SLM', 'bkk:SLP', 'bkk:SMART', 'bkk:SMIT', 'bkk:SMK', 'bkk:SMPC', 'bkk:SMT', 'bkk:SNC', 'bkk:SNP', 'bkk:SO', 'bkk:SOLAR', 'bkk:SONIC', 'bkk:SORKON', 'bkk:SPA', 'bkk:SPACK', 'bkk:SPALI', 'bkk:SPC', 'bkk:SPCG', 'bkk:SPG', 'bkk:SPI', 'bkk:SPRC', 'bkk:SPVI', 'bkk:SQ', 'bkk:SR', 'bkk:SRICHA', 'bkk:SSC', 'bkk:SSF', 'bkk:SSI', 'bkk:SSP', 'bkk:SSSC', 'bkk:SST', 'bkk:STA', 'bkk:STANLY', 'bkk:STAR', 'bkk:STARK', 'bkk:STC', 'bkk:STEC', 'bkk:STGT', 'bkk:STHAI', 'bkk:STI', 'bkk:STPI', 'bkk:SUC', 'bkk:SUN', 'bkk:SUPER', 'bkk:SUSCO', 'bkk:SUTHA', 'bkk:SVH', 'bkk:SVI', 'bkk:SVOA', 'bkk:SWC', 'bkk:SYMC', 'bkk:SYNEX', 'bkk:SYNTEC', 'bkk:T', 'bkk:TACC', 'bkk:TAE', 'bkk:TAKUNI', 'bkk:TAPAC', 'bkk:TASCO', 'bkk:TBSP', 'bkk:TC', 'bkk:TCAP', 'bkk:TCC', 'bkk:TCCC', 'bkk:TCJ', 'bkk:TCMC', 'bkk:TCOAT', 'bkk:TEAM', 'bkk:TEAMG', 'bkk:TFG', 'bkk:TFI', 'bkk:TFMAMA', 'bkk:TGPRO', 'bkk:TH', 'bkk:THAI', 'bkk:THANA', 'bkk:THANI', 'bkk:THCOM', 'bkk:THE', 'bkk:THG', 'bkk:THIP', 'bkk:THL', 'bkk:THMUI', 'bkk:THRE', 'bkk:THREL', 'bkk:TIGER', 'bkk:TIP', 'bkk:TIPCO', 'bkk:TISCO', 'bkk:TITLE', 'bkk:TIW', 'bkk:TK', 'bkk:TKN', 'bkk:TKS', 'bkk:TKT', 'bkk:TM', 'bkk:TMB', 'bkk:TMC', 'bkk:TMD', 'bkk:TMI', 'bkk:TMILL', 'bkk:TMT', 'bkk:TMW', 'bkk:TNDT', 'bkk:TNH', 'bkk:TNITY', 'bkk:TNL', 'bkk:TNP', 'bkk:TNPC', 'bkk:TNR', 'bkk:TOA', 'bkk:TOG', 'bkk:TOP', 'bkk:TOPP', 'bkk:TPA', 'bkk:TPAC', 'bkk:TPBI', 'bkk:TPCH', 'bkk:TPCORP', 'bkk:TPIPL', 'bkk:TPIPP', 'bkk:TPLAS', 'bkk:TPOLY', 'bkk:TPP', 'bkk:TPS', 'bkk:TQM', 'bkk:TR', 'bkk:TRC', 'bkk:TRITN', 'bkk:TRT', 'bkk:TRU', 'bkk:TRUBB', 'bkk:TRUE', 'bkk:TSC', 'bkk:TSE', 'bkk:TSF', 'bkk:TSI', 'bkk:TSR', 'bkk:TSTE', 'bkk:TSTH', 'bkk:TTA', 'bkk:TTCL', 'bkk:TTI', 'bkk:TTT', 'bkk:TTW', 'bkk:TU', 'bkk:TVD', 'bkk:TVI', 'bkk:TVO', 'bkk:TVT', 'bkk:TWP', 'bkk:TWPC', 'bkk:TWZ', 'bkk:TYCN', 'bkk:U', 'bkk:UAC', 'bkk:UBIS', 'bkk:UEC', 'bkk:UKEM', 'bkk:UMI', 'bkk:UMS', 'bkk:UNIQ', 'bkk:UH', 'bkk:UP', 'bkk:UPA', 'bkk:UPF', 'bkk:UPOIC', 'bkk:UREKA', 'bkk:UT', 'bkk:UTP', 'bkk:UV', 'bkk:UVAN', 'bkk:UWC', 'bkk:VARO', 'bkk:VCOM', 'bkk:VGI', 'bkk:VIBHA', 'bkk:VIH', 'bkk:VL', 'bkk:VNG', 'bkk:VNT', 'bkk:VPO', 'bkk:VRANDA', 'bkk:W', 'bkk:WACOAL', 'bkk:WAVE', 'bkk:WG', 'bkk:WGE', 'bkk:WHA', 'bkk:WHAUP', 'bkk:WICE', 'bkk:WIIK', 'bkk:WIN', 'bkk:WINNER', 'bkk:WORK', 'bkk:WP', 'bkk:WPH', 'bkk:WR', 'bkk:XO', 'bkk:YCI', 'bkk:YGG', 'bkk:YUASA', 'bkk:ZEN', 'bkk:ZIGA', 'bkk:ZMICO', ]

# %%
# tickers = [  'nasdaq:A', 'nasdaq:AA', 'nasdaq:AACG', 'nasdaq:AACQ', 'nasdaq:AACQU', 'nasdaq:AAIC', 'nasdaq:AAL', 'nasdaq:AAMC', 'nasdaq:AAME', 'nasdaq:AAN', 'nasdaq:AAOI', 'nasdaq:AAON', 'nasdaq:AAP', 'nasdaq:AAPL', 'nasdaq:AAT', 'nasdaq:AAU', 'nasdaq:AAWW', 'nasdaq:AB', 'nasdaq:ABB', 'nasdaq:ABBV', 'nasdaq:ABC', 'nasdaq:ABCB', 'nasdaq:ABCL', 'nasdaq:ABCM', 'nasdaq:ABEO', 'nasdaq:ABEV', 'nasdaq:ABG', 'nasdaq:ABIO', 'nasdaq:ABM', 'nasdaq:ABMD', 'nasdaq:ABNB', 'nasdaq:ABR', 'nasdaq:ABST', 'nasdaq:ABT', 'nasdaq:ABTX', 'nasdaq:ABUS', 'nasdaq:AC', 'nasdaq:ACA', 'nasdaq:ACAC', 'nasdaq:ACACU', 'nasdaq:ACAD', 'nasdaq:ACB', 'nasdaq:ACBI', 'nasdaq:ACC', 'nasdaq:ACCD', 'nasdaq:ACCO', 'nasdaq:ACEL', 'nasdaq:ACER', 'nasdaq:ACET', 'nasdaq:ACEV', 'nasdaq:ACEVU', 'nasdaq:ACGL', 'nasdaq:ACGLO', 'nasdaq:ACGLP', 'nasdaq:ACH', 'nasdaq:ACHC', 'nasdaq:ACHV', 'nasdaq:ACI', 'nasdaq:ACIA', 'nasdaq:ACIC', 'nasdaq:ACIU', 'nasdaq:ACIW', 'nasdaq:ACKIT', 'nasdaq:ACKIU', 'nasdaq:ACLS', 'nasdaq:ACM', 'nasdaq:ACMR', 'nasdaq:ACN', 'nasdaq:ACNB', 'nasdaq:ACND', 'nasdaq:ACOR', 'nasdaq:ACP', 'nasdaq:ACRE', 'nasdaq:ACRS', 'nasdaq:ACRX', 'nasdaq:ACST', 'nasdaq:ACTC', 'nasdaq:ACTCU', 'nasdaq:ACTG', 'nasdaq:ACU', 'nasdaq:ACV', 'nasdaq:ACY', 'nasdaq:ADAP', 'nasdaq:ADBE', 'nasdaq:ADC', 'nasdaq:ADCT', 'nasdaq:ADERU', 'nasdaq:ADES', 'nasdaq:ADI', 'nasdaq:ADIL', 'nasdaq:ADM', 'nasdaq:ADMA', 'nasdaq:ADMP', 'nasdaq:ADMS', 'nasdaq:ADN', 'nasdaq:ADNT', 'nasdaq:ADOC', 'nasdaq:ADOCR', 'nasdaq:ADP', 'nasdaq:ADPT', 'nasdaq:ADS', 'nasdaq:ADSK', 'nasdaq:ADT', 'nasdaq:ADTN', 'nasdaq:ADTX', 'nasdaq:ADUS', 'nasdaq:ADV', 'nasdaq:ADVM', 'nasdaq:ADX', 'nasdaq:ADXN', 'nasdaq:ADXS', 'nasdaq:AE', 'nasdaq:AEACU', 'nasdaq:AEB', 'nasdaq:AEE', 'nasdaq:AEF', 'nasdaq:AEFC', 'nasdaq:AEG', 'nasdaq:AEGN', 'nasdaq:AEHL', 'nasdaq:AEHR', 'nasdaq:AEI', 'nasdaq:AEIS', 'nasdaq:AEL', 'nasdaq:AEM', 'nasdaq:AEMD', 'nasdaq:AENZ', 'nasdaq:AEO', 'nasdaq:AEP', 'nasdaq:AEPPL', 'nasdaq:AEPPZ', 'nasdaq:AER', 'nasdaq:AERI', 'nasdaq:AES', 'nasdaq:AESE', 'nasdaq:AEY', 'nasdaq:AEYE', 'nasdaq:AEZS', 'nasdaq:AFB', 'nasdaq:AFBI', 'nasdaq:AFC', 'nasdaq:AFG', 'nasdaq:AFGB', 'nasdaq:AFGC', 'nasdaq:AFGD', 'nasdaq:AFGE', 'nasdaq:AFI', 'nasdaq:AFIB', 'nasdaq:AFIN', 'nasdaq:AFINO', 'nasdaq:AFINP', 'nasdaq:AFL', 'nasdaq:AFMD', 'nasdaq:AFRM', 'nasdaq:AFT', 'nasdaq:AFYA', 'nasdaq:AG', 'nasdaq:AGBA', 'nasdaq:AGBAR', 'nasdaq:AGC', 'nasdaq:AGCB', 'nasdaq:AGCO', 'nasdaq:AGCUU', 'nasdaq:AGD', 'nasdaq:AGE', 'nasdaq:AGEN', 'nasdaq:AGFS', 'nasdaq:AGFY', 'nasdaq:AGI', 'nasdaq:AGIO', 'nasdaq:AGLE', 'nasdaq:AGM', 'nasdaq:AGMH', 'nasdaq:AGNC', 'nasdaq:AGNCM', 'nasdaq:AGNCN', 'nasdaq:AGNCO', 'nasdaq:AGNCP', 'nasdaq:AGO', 'nasdaq:AGR', 'nasdaq:AGRO', 'nasdaq:AGRX', 'nasdaq:AGS', 'nasdaq:AGTC', 'nasdaq:AGX', 'nasdaq:AGYS', 'nasdaq:AHAC', 'nasdaq:AHACU', 'nasdaq:AHC', 'nasdaq:AHCO', 'nasdaq:AHH', 'nasdaq:AHPI', 'nasdaq:AHT', 'nasdaq:AI', 'nasdaq:AIC', 'nasdaq:AIF', 'nasdaq:AIG', 'nasdaq:AIH', 'nasdaq:AIHS', 'nasdaq:AIKI', 'nasdaq:AIM', 'nasdaq:AIMC', 'nasdaq:AIN', 'nasdaq:AINC', 'nasdaq:AINV', 'nasdaq:AIO', 'nasdaq:AIR', 'nasdaq:AIRC', 'nasdaq:AIRG', 'nasdaq:AIRI', 'nasdaq:AIRT', 'nasdaq:AIRTP', 'nasdaq:AIT', 'nasdaq:AIV', 'nasdaq:AIW', 'nasdaq:AIZ', 'nasdaq:AIZN', 'nasdaq:AIZP', 'nasdaq:AJAX', 'nasdaq:AJG', 'nasdaq:AJRD', 'nasdaq:AJX', 'nasdaq:AJXA', 'nasdaq:AKAM', 'nasdaq:AKBA', 'nasdaq:AKER', 'nasdaq:AKICU', 'nasdaq:AKO/A', 'nasdaq:AKO/B', 'nasdaq:AKR', 'nasdaq:AKRO', 'nasdaq:AKTS', 'nasdaq:AKU', 'nasdaq:AKUS', 'nasdaq:AL', 'nasdaq:ALAC', 'nasdaq:ALACR', 'nasdaq:ALB', 'nasdaq:ALBO', 'nasdaq:ALC', 'nasdaq:ALCO', 'nasdaq:ALDX', 'nasdaq:ALE', 'nasdaq:ALEC', 'nasdaq:ALEX', 'nasdaq:ALG', 'nasdaq:ALGM', 'nasdaq:ALGN', 'nasdaq:ALGS', 'nasdaq:ALGT', 'nasdaq:ALIM', 'nasdaq:ALJJ', 'nasdaq:ALK', 'nasdaq:ALKS', 'nasdaq:ALL', 'nasdaq:ALLE', 'nasdaq:ALLK', 'nasdaq:ALLO', 'nasdaq:ALLT', 'nasdaq:ALLY', 'nasdaq:ALNA', 'nasdaq:ALNY', 'nasdaq:ALOT', 'nasdaq:ALPN', 'nasdaq:ALRM', 'nasdaq:ALRN', 'nasdaq:ALRS', 'nasdaq:ALSK', 'nasdaq:ALSN', 'nasdaq:ALT', 'nasdaq:ALTA', 'nasdaq:ALTG', 'nasdaq:ALTM', 'nasdaq:ALTO', 'nasdaq:ALTR', 'nasdaq:ALTU', 'nasdaq:ALTUU', 'nasdaq:ALUS', 'nasdaq:ALV', 'nasdaq:ALVR', 'nasdaq:ALX', 'nasdaq:ALXN', 'nasdaq:ALXO', 'nasdaq:ALYA', 'nasdaq:AM', 'nasdaq:AMAL', 'nasdaq:AMAT', 'nasdaq:AMBA', 'nasdaq:AMBC', 'nasdaq:AMBO', 'nasdaq:AMC', 'nasdaq:AMCR', 'nasdaq:AMCX', 'nasdaq:AMD', 'nasdaq:AME', 'nasdaq:AMED', 'nasdaq:AMEH', 'nasdaq:AMG', 'nasdaq:AMGN', 'nasdaq:AMH', 'nasdaq:AMHC', 'nasdaq:AMHCU', 'nasdaq:AMK', 'nasdaq:AMKR', 'nasdaq:AMN', 'nasdaq:AMNB', 'nasdaq:AMOT', 'nasdaq:AMOV', 'nasdaq:AMP', 'nasdaq:AMPE', 'nasdaq:AMPH', 'nasdaq:AMPY', 'nasdaq:AMR', 'nasdaq:AMRB', 'nasdaq:AMRC', 'nasdaq:AMRK', 'nasdaq:AMRN', 'nasdaq:AMRS', 'nasdaq:AMRX', 'nasdaq:AMS', 'nasdaq:AMSC', 'nasdaq:AMSF', 'nasdaq:AMST', 'nasdaq:AMSWA', 'nasdaq:AMT', 'nasdaq:AMTB', 'nasdaq:AMTBB', 'nasdaq:AMTI', 'nasdaq:AMTX', 'nasdaq:AMWD', 'nasdaq:AMWL', 'nasdaq:AMX', 'nasdaq:AMYT', 'nasdaq:AMZN', 'nasdaq:AN', 'nasdaq:ANAB', 'nasdaq:ANAT', 'nasdaq:ANCN', 'nasdaq:ANDA', 'nasdaq:ANDAR', 'nasdaq:ANDAU', 'nasdaq:ANDE', 'nasdaq:ANET', 'nasdaq:ANF', 'nasdaq:ANGI', 'nasdaq:ANGN', 'nasdaq:ANGO', 'nasdaq:ANH', 'nasdaq:ANIK', 'nasdaq:ANIP', 'nasdaq:ANIX', 'nasdaq:ANNX', 'nasdaq:ANPC', 'nasdaq:ANSS', 'nasdaq:ANTE', 'nasdaq:ANTM', 'nasdaq:ANVS', 'nasdaq:ANY', 'nasdaq:AOD', 'nasdaq:AON', 'nasdaq:AONE', 'nasdaq:AOS', 'nasdaq:AOSL', 'nasdaq:AOUT', 'nasdaq:AP', 'nasdaq:APA', 'nasdaq:APAM', 'nasdaq:APD', 'nasdaq:APDN', 'nasdaq:APEI', 'nasdaq:APEN', 'nasdaq:APG', 'nasdaq:APH', 'nasdaq:APHA', 'nasdaq:API', 'nasdaq:APLE', 'nasdaq:APLS', 'nasdaq:APLT', 'nasdaq:APM', 'nasdaq:APO', 'nasdaq:APOG', 'nasdaq:APOP', 'nasdaq:APPF', 'nasdaq:APPH', 'nasdaq:APPN', 'nasdaq:APPS', 'nasdaq:APRE', 'nasdaq:APRN', 'nasdaq:APSG', 'nasdaq:APT', 'nasdaq:APTO', 'nasdaq:APTS', 'nasdaq:APTV', 'nasdaq:APTX', 'nasdaq:APVO', 'nasdaq:APWC', 'nasdaq:APXT', 'nasdaq:APXTU', 'nasdaq:APYX', 'nasdaq:AQB', 'nasdaq:AQMS', 'nasdaq:AQN', 'nasdaq:AQNA', 'nasdaq:AQNB', 'nasdaq:AQST', 'nasdaq:AQUA', 'nasdaq:AR', 'nasdaq:ARAV', 'nasdaq:ARAY', 'nasdaq:ARBG', 'nasdaq:ARBGU', 'nasdaq:ARC', 'nasdaq:ARCB', 'nasdaq:ARCC', 'nasdaq:ARCE', 'nasdaq:ARCH', 'nasdaq:ARCO', 'nasdaq:ARCT', 'nasdaq:ARD', 'nasdaq:ARDC', 'nasdaq:ARDS', 'nasdaq:ARDX', 'nasdaq:ARE', 'nasdaq:AREC', 'nasdaq:ARES', 'nasdaq:ARGD', 'nasdaq:ARGO', 'nasdaq:ARGX', 'nasdaq:ARI', 'nasdaq:ARKIU', 'nasdaq:ARKO', 'nasdaq:ARKR', 'nasdaq:ARL', 'nasdaq:ARLO', 'nasdaq:ARLP', 'nasdaq:ARMK', 'nasdaq:ARMP', 'nasdaq:ARNA', 'nasdaq:ARNC', 'nasdaq:AROC', 'nasdaq:AROW', 'nasdaq:ARPO', 'nasdaq:ARQT', 'nasdaq:ARR', 'nasdaq:ARRY', 'nasdaq:ARTL', 'nasdaq:ARTNA', 'nasdaq:ARTW', 'nasdaq:ARVN', 'nasdaq:ARW', 'nasdaq:ARWR', 'nasdaq:ARYA', 'nasdaq:ASA', 'nasdaq:ASAN', 'nasdaq:ASAQ', 'nasdaq:ASAXU', 'nasdaq:ASB', 'nasdaq:ASC', 'nasdaq:ASG', 'nasdaq:ASGI', 'nasdaq:ASGN', 'nasdaq:ASH', 'nasdaq:ASIX', 'nasdaq:ASLE', 'nasdaq:ASLN', 'nasdaq:ASM', 'nasdaq:ASMB', 'nasdaq:ASML', 'nasdaq:ASND', 'nasdaq:ASO', 'nasdaq:ASPL', 'nasdaq:ASPN', 'nasdaq:ASPS', 'nasdaq:ASPU', 'nasdaq:ASR', 'nasdaq:ASRT', 'nasdaq:ASRV', 'nasdaq:ASRVP', 'nasdaq:ASTC', 'nasdaq:ASTE', 'nasdaq:ASUR', 'nasdaq:ASX', 'nasdaq:ASYS', 'nasdaq:AT', 'nasdaq:ATA', 'nasdaq:ATAC', 'nasdaq:ATAX', 'nasdaq:ATC', 'nasdaq:ATCO', 'nasdaq:ATCX', 'nasdaq:ATEC', 'nasdaq:ATEN', 'nasdaq:ATEX', 'nasdaq:ATGE', 'nasdaq:ATH', 'nasdaq:ATHA', 'nasdaq:ATHE', 'nasdaq:ATHM', 'nasdaq:ATHX', 'nasdaq:ATI', 'nasdaq:ATIF', 'nasdaq:ATKR', 'nasdaq:ATLC', 'nasdaq:ATLO', 'nasdaq:ATNF', 'nasdaq:ATNI', 'nasdaq:ATNM', 'nasdaq:ATNX', 'nasdaq:ATO', 'nasdaq:ATOM', 'nasdaq:ATOS', 'nasdaq:ATR', 'nasdaq:ATRA', 'nasdaq:ATRC', 'nasdaq:ATRI', 'nasdaq:ATRO', 'nasdaq:ATRS', 'nasdaq:ATSG', 'nasdaq:ATTO', 'nasdaq:ATUS', 'nasdaq:ATVI', 'nasdaq:ATXI', 'nasdaq:AU', 'nasdaq:AUB', 'nasdaq:AUBAP', 'nasdaq:AUBN', 'nasdaq:AUDC', 'nasdaq:AUMN', 'nasdaq:AUPH', 'nasdaq:AUTL', 'nasdaq:AUTO', 'nasdaq:AUVI', 'nasdaq:AUY', 'nasdaq:AVA', 'nasdaq:AVAN', 'nasdaq:AVAV', 'nasdaq:AVB', 'nasdaq:AVCO', 'nasdaq:AVCT', 'nasdaq:AVD', 'nasdaq:AVDL', 'nasdaq:AVEO', 'nasdaq:AVGO', 'nasdaq:AVGOP', 'nasdaq:AVGR', 'nasdaq:AVID', 'nasdaq:AVIR', 'nasdaq:AVK', 'nasdaq:AVLR', 'nasdaq:AVNS', 'nasdaq:AVNT', 'nasdaq:AVNW', 'nasdaq:AVO', 'nasdaq:AVRO', 'nasdaq:AVT', 'nasdaq:AVTR', 'nasdaq:AVXL', 'nasdaq:AVY', 'nasdaq:AVYA', 'nasdaq:AWF', 'nasdaq:AWH', 'nasdaq:AWI', 'nasdaq:AWK', 'nasdaq:AWP', 'nasdaq:AWR', 'nasdaq:AWRE', 'nasdaq:AWX', 'nasdaq:AX', 'nasdaq:AXAS', 'nasdaq:AXDX', 'nasdaq:AXGN', 'nasdaq:AXL', 'nasdaq:AXLA', 'nasdaq:AXNX', 'nasdaq:AXO', 'nasdaq:AXON', 'nasdaq:AXP', 'nasdaq:AXR', 'nasdaq:AXS', 'nasdaq:AXSM', 'nasdaq:AXTA', 'nasdaq:AXTI', 'nasdaq:AXU', 'nasdaq:AY', 'nasdaq:AYI', 'nasdaq:AYLA', 'nasdaq:AYRO', 'nasdaq:AYTU', 'nasdaq:AYX', 'nasdaq:AZEK', 'nasdaq:AZN', 'nasdaq:AZO', 'nasdaq:AZPN', 'nasdaq:AZRE', 'nasdaq:AZRX', 'nasdaq:AZUL', 'nasdaq:AZYO', 'nasdaq:AZZ', 'nasdaq:B', 'nasdaq:BA', 'nasdaq:BABA', 'nasdaq:BAC', 'nasdaq:BAF', 'nasdaq:BAH', 'nasdaq:BALY', 'nasdaq:BAM', 'nasdaq:BAMH', 'nasdaq:BAMI', 'nasdaq:BANC', 'nasdaq:BAND', 'nasdaq:BANF', 'nasdaq:BANR', 'nasdaq:BANX', 'nasdaq:BAP', 'nasdaq:BASI', 'nasdaq:BATL', 'nasdaq:BATRA', 'nasdaq:BATRK', 'nasdaq:BAX', 'nasdaq:BB', 'nasdaq:BBAR', 'nasdaq:BBBY', 'nasdaq:BBCP', 'nasdaq:BBD', 'nasdaq:BBDC', 'nasdaq:BBDO', 'nasdaq:BBF', 'nasdaq:BBGI', 'nasdaq:BBI', 'nasdaq:BBIG', 'nasdaq:BBIO', 'nasdaq:BBK', 'nasdaq:BBN', 'nasdaq:BBQ', 'nasdaq:BBSI', 'nasdaq:BBU', 'nasdaq:BBVA', 'nasdaq:BBW', 'nasdaq:BBY', 'nasdaq:BC', 'nasdaq:BCAB', 'nasdaq:BCACU', 'nasdaq:BCAT', 'nasdaq:BCBP', 'nasdaq:BCC', 'nasdaq:BCDA', 'nasdaq:BCE', 'nasdaq:BCEI', 'nasdaq:BCEL', 'nasdaq:BCH', 'nasdaq:BCLI', 'nasdaq:BCML', 'nasdaq:BCO', 'nasdaq:BCOR', 'nasdaq:BCOV', 'nasdaq:BCOW', 'nasdaq:BCPC', 'nasdaq:BCRX', 'nasdaq:BCS', 'nasdaq:BCSF', 'nasdaq:BCTG', 'nasdaq:BCV', 'nasdaq:BCX', 'nasdaq:BCYC', 'nasdaq:BCYPU', 'nasdaq:BDC', 'nasdaq:BDJ', 'nasdaq:BDL', 'nasdaq:BDN', 'nasdaq:BDR', 'nasdaq:BDSI', 'nasdaq:BDSX', 'nasdaq:BDTX', 'nasdaq:BDX', 'nasdaq:BDXB', 'nasdaq:BE', 'nasdaq:BEAM', 'nasdaq:BEAT', 'nasdaq:BECN', 'nasdaq:BEDU', 'nasdaq:BEEM', 'nasdaq:BEKE', 'nasdaq:BELFA', 'nasdaq:BELFB', 'nasdaq:BEN', 'nasdaq:BENE', 'nasdaq:BENER', 'nasdaq:BENEU', 'nasdaq:BEP', 'nasdaq:BEPC', 'nasdaq:BERY', 'nasdaq:BEST', 'nasdaq:BF/A', 'nasdaq:BF/B', 'nasdaq:BFAM', 'nasdaq:BFC', 'nasdaq:BFI', 'nasdaq:BFIN', 'nasdaq:BFK', 'nasdaq:BFRA', 'nasdaq:BFS', 'nasdaq:BFST', 'nasdaq:BFT', 'nasdaq:BFY', 'nasdaq:BFZ', 'nasdaq:BG', 'nasdaq:BGB', 'nasdaq:BGCP', 'nasdaq:BGFV', 'nasdaq:BGH', 'nasdaq:BGI', 'nasdaq:BGIO', 'nasdaq:BGNE', 'nasdaq:BGR', 'nasdaq:BGS', 'nasdaq:BGSF', 'nasdaq:BGT', 'nasdaq:BGX', 'nasdaq:BGY', 'nasdaq:BH', 'nasdaq:BHAT', 'nasdaq:BHB', 'nasdaq:BHC', 'nasdaq:BHE', 'nasdaq:BHF', 'nasdaq:BHFAL', 'nasdaq:BHFAN', 'nasdaq:BHFAO', 'nasdaq:BHFAP', 'nasdaq:BHK', 'nasdaq:BHLB', 'nasdaq:BHP', 'nasdaq:BHR', 'nasdaq:BHSE', 'nasdaq:BHSEU', 'nasdaq:BHTG', 'nasdaq:BHV', 'nasdaq:BHVN', 'nasdaq:BIDU', 'nasdaq:BIF', 'nasdaq:BIG', 'nasdaq:BIGC', 'nasdaq:BIIB', 'nasdaq:BILI', 'nasdaq:BILL', 'nasdaq:BIMI', 'nasdaq:BIO', 'nasdaq:BIO/B', 'nasdaq:BIOC', 'nasdaq:BIOL', 'nasdaq:BIOTU', 'nasdaq:BIOX', 'nasdaq:BIP', 'nasdaq:BIPC', 'nasdaq:BIT', 'nasdaq:BIVI', 'nasdaq:BJ', 'nasdaq:BJRI', 'nasdaq:BK', 'nasdaq:BKCC', 'nasdaq:BKD', 'nasdaq:BKE', 'nasdaq:BKEP', 'nasdaq:BKEPP', 'nasdaq:BKH', 'nasdaq:BKI', 'nasdaq:BKN', 'nasdaq:BKNG', 'nasdaq:BKR', 'nasdaq:BKSC', 'nasdaq:BKT', 'nasdaq:BKTI', 'nasdaq:BKU', 'nasdaq:BKYI', 'nasdaq:BL', 'nasdaq:BLBD', 'nasdaq:BLCM', 'nasdaq:BLCT', 'nasdaq:BLD', 'nasdaq:BLDP', 'nasdaq:BLDR', 'nasdaq:BLE', 'nasdaq:BLFS', 'nasdaq:BLI', 'nasdaq:BLIN', 'nasdaq:BLK', 'nasdaq:BLKB', 'nasdaq:BLL', 'nasdaq:BLMN', 'nasdaq:BLNK', 'nasdaq:BLPH', 'nasdaq:BLRX', 'nasdaq:BLSA', 'nasdaq:BLTSU', 'nasdaq:BLU', 'nasdaq:BLUE', 'nasdaq:BLUWU', 'nasdaq:BLW', 'nasdaq:BLX', 'nasdaq:BME', 'nasdaq:BMEZ', 'nasdaq:BMI', 'nasdaq:BMO', 'nasdaq:BMRA', 'nasdaq:BMRC', 'nasdaq:BMRN', 'nasdaq:BMTC', 'nasdaq:BMTX', 'nasdaq:BMY', 'nasdaq:BNED', 'nasdaq:BNFT', 'nasdaq:BNGO', 'nasdaq:BNL', 'nasdaq:BNR', 'nasdaq:BNS', 'nasdaq:BNSO', 'nasdaq:BNTC', 'nasdaq:BNTX', 'nasdaq:BNY', 'nasdaq:BOAC', 'nasdaq:BOCH', 'nasdaq:BOE', 'nasdaq:BOH', 'nasdaq:BOKF', 'nasdaq:BOKFL', 'nasdaq:BOLT', 'nasdaq:BOMN', 'nasdaq:BOOM', 'nasdaq:BOOT', 'nasdaq:BORR', 'nasdaq:BOSC', 'nasdaq:BOTJ', 'nasdaq:BOWX', 'nasdaq:BOWXU', 'nasdaq:BOX', 'nasdaq:BOXL', 'nasdaq:BP', 'nasdaq:BPFH', 'nasdaq:BPMC', 'nasdaq:BPMP', 'nasdaq:BPOP', 'nasdaq:BPOPM', 'nasdaq:BPOPN', 'nasdaq:BPRN', 'nasdaq:BPT', 'nasdaq:BPTH', 'nasdaq:BPY', 'nasdaq:BPYPN', 'nasdaq:BPYPO', 'nasdaq:BPYPP', 'nasdaq:BPYU', 'nasdaq:BPYUP', 'nasdaq:BQ', 'nasdaq:BRBR', 'nasdaq:BRBS', 'nasdaq:BRC', 'nasdaq:BREZ', 'nasdaq:BREZR', 'nasdaq:BRFS', 'nasdaq:BRG', 'nasdaq:BRID', 'nasdaq:BRK/A', 'nasdaq:BRK/B', 'nasdaq:BRKL', 'nasdaq:BRKR', 'nasdaq:BRKS', 'nasdaq:BRLI', 'nasdaq:BRLIR', 'nasdaq:BRLIU', 'nasdaq:BRMK', 'nasdaq:BRN', 'nasdaq:BRO', 'nasdaq:BROG', 'nasdaq:BRP', 'nasdaq:BRPA', 'nasdaq:BRPAR', 'nasdaq:BRPAU', 'nasdaq:BRQS', 'nasdaq:BRT', 'nasdaq:BRX', 'nasdaq:BRY', 'nasdaq:BSA', 'nasdaq:BSAC', 'nasdaq:BSBK', 'nasdaq:BSBR', 'nasdaq:BSD', 'nasdaq:BSE', 'nasdaq:BSET', 'nasdaq:BSGM', 'nasdaq:BSIG', 'nasdaq:BSL', 'nasdaq:BSM', 'nasdaq:BSMX', 'nasdaq:BSN', 'nasdaq:BSQR', 'nasdaq:BSRR', 'nasdaq:BST', 'nasdaq:BSTZ', 'nasdaq:BSVN', 'nasdaq:BSX', 'nasdaq:BSY', 'nasdaq:BTA', 'nasdaq:BTAI', 'nasdaq:BTAQ', 'nasdaq:BTAQU', 'nasdaq:BTBT', 'nasdaq:BTG', 'nasdaq:BTN', 'nasdaq:BTNB', 'nasdaq:BTO', 'nasdaq:BTRS', 'nasdaq:BTT', 'nasdaq:BTU', 'nasdaq:BTWN', 'nasdaq:BTWNU', 'nasdaq:BTZ', 'nasdaq:BUI', 'nasdaq:BUR', 'nasdaq:BURL', 'nasdaq:BUSE', 'nasdaq:BV', 'nasdaq:BVH', 'nasdaq:BVN', 'nasdaq:BVXV', 'nasdaq:BW', 'nasdaq:BWA', 'nasdaq:BWAC', 'nasdaq:BWACU', 'nasdaq:BWAY', 'nasdaq:BWB', 'nasdaq:BWEN', 'nasdaq:BWFG', 'nasdaq:BWG', 'nasdaq:BWL/A', 'nasdaq:BWMX', 'nasdaq:BWXT', 'nasdaq:BX', 'nasdaq:BXC', 'nasdaq:BXG', 'nasdaq:BXMT', 'nasdaq:BXMX', 'nasdaq:BXP', 'nasdaq:BXRX', 'nasdaq:BXS', 'nasdaq:BY', 'nasdaq:BYD', 'nasdaq:BYFC', 'nasdaq:BYM', 'nasdaq:BYND', 'nasdaq:BYSI', 'nasdaq:BZH', 'nasdaq:BZM', 'nasdaq:BZUN', 'nasdaq:C', 'nasdaq:CAAP', 'nasdaq:CAAS', 'nasdaq:CABA', 'nasdaq:CABO', 'nasdaq:CAC', 'nasdaq:CACC', 'nasdaq:CACI', 'nasdaq:CADE', 'nasdaq:CAE', 'nasdaq:CAF', 'nasdaq:CAG', 'nasdaq:CAH', 'nasdaq:CAHCU', 'nasdaq:CAI', 'nasdaq:CAJ', 'nasdaq:CAKE', 'nasdaq:CAL', 'nasdaq:CALA', 'nasdaq:CALB', 'nasdaq:CALM', 'nasdaq:CALT', 'nasdaq:CALX', 'nasdaq:CAMP', 'nasdaq:CAMT', 'nasdaq:CAN', 'nasdaq:CANG', 'nasdaq:CAP', 'nasdaq:CAPA', 'nasdaq:CAPAU', 'nasdaq:CAPL', 'nasdaq:CAPR', 'nasdaq:CAR', 'nasdaq:CARA', 'nasdaq:CARE', 'nasdaq:CARG', 'nasdaq:CARR', 'nasdaq:CARS', 'nasdaq:CARV', 'nasdaq:CAS', 'nasdaq:CASA', 'nasdaq:CASH', 'nasdaq:CASI', 'nasdaq:CASS', 'nasdaq:CASY', 'nasdaq:CAT', 'nasdaq:CATB', 'nasdaq:CATC', 'nasdaq:CATM', 'nasdaq:CATO', 'nasdaq:CATY', 'nasdaq:CB', 'nasdaq:CBAH', 'nasdaq:CBAN', 'nasdaq:CBAT', 'nasdaq:CBAY', 'nasdaq:CBB', 'nasdaq:CBD', 'nasdaq:CBFV', 'nasdaq:CBH', 'nasdaq:CBIO', 'nasdaq:CBLI', 'nasdaq:CBMB', 'nasdaq:CBMG', 'nasdaq:CBNK', 'nasdaq:CBOE', 'nasdaq:CBPO', 'nasdaq:CBRE', 'nasdaq:CBRL', 'nasdaq:CBSH', 'nasdaq:CBT', 'nasdaq:CBTX', 'nasdaq:CBU', 'nasdaq:CBZ', 'nasdaq:CC', 'nasdaq:CCAC', 'nasdaq:CCAP', 'nasdaq:CCB', 'nasdaq:CCBG', 'nasdaq:CCCC', 'nasdaq:CCD', 'nasdaq:CCEP', 'nasdaq:CCF', 'nasdaq:CCI', 'nasdaq:CCIV', 'nasdaq:CCJ', 'nasdaq:CCK', 'nasdaq:CCL', 'nasdaq:CCLP', 'nasdaq:CCM', 'nasdaq:CCMP', 'nasdaq:CCNC', 'nasdaq:CCNE', 'nasdaq:CCNEP', 'nasdaq:CCO', 'nasdaq:CCOI', 'nasdaq:CCRC', 'nasdaq:CCRN', 'nasdaq:CCS', 'nasdaq:CCU', 'nasdaq:CCV', 'nasdaq:CCX', 'nasdaq:CCXI', 'nasdaq:CCZ', 'nasdaq:CD', 'nasdaq:CDAK', 'nasdaq:CDAY', 'nasdaq:CDE', 'nasdaq:CDEV', 'nasdaq:CDK', 'nasdaq:CDLX', 'nasdaq:CDMO', 'nasdaq:CDMOP', 'nasdaq:CDNA', 'nasdaq:CDNS', 'nasdaq:CDOR', 'nasdaq:CDR', 'nasdaq:CDTX', 'nasdaq:CDW', 'nasdaq:CDXC', 'nasdaq:CDXS', 'nasdaq:CDZI', 'nasdaq:CE', 'nasdaq:CEA', 'nasdaq:CECE', 'nasdaq:CEE', 'nasdaq:CEI', 'nasdaq:CEIX', 'nasdaq:CEL', 'nasdaq:CELC', 'nasdaq:CELH', 'nasdaq:CELP', 'nasdaq:CEM', 'nasdaq:CEMI', 'nasdaq:CEN', 'nasdaq:CENHU', 'nasdaq:CENT', 'nasdaq:CENTA', 'nasdaq:CENX', 'nasdaq:CEO', 'nasdaq:CEPU', 'nasdaq:CEQP', 'nasdaq:CERC', 'nasdaq:CERE', 'nasdaq:CERN', 'nasdaq:CERS', 'nasdaq:CERT', 'nasdaq:CET', 'nasdaq:CETX', 'nasdaq:CETXP', 'nasdaq:CEV', 'nasdaq:CEVA', 'nasdaq:CF', 'nasdaq:CFAC', 'nasdaq:CFACU', 'nasdaq:CFB', 'nasdaq:CFBK', 'nasdaq:CFFI', 'nasdaq:CFFN', 'nasdaq:CFFVU', 'nasdaq:CFG', 'nasdaq:CFII', 'nasdaq:CFIIU', 'nasdaq:CFIVU', 'nasdaq:CFMS', 'nasdaq:CFR', 'nasdaq:CFRX', 'nasdaq:CFX', 'nasdaq:CFXA', 'nasdaq:CG', 'nasdaq:CGA', 'nasdaq:CGBD', 'nasdaq:CGC', 'nasdaq:CGEM', 'nasdaq:CGEN', 'nasdaq:CGIX', 'nasdaq:CGNT', 'nasdaq:CGNX', 'nasdaq:CGO', 'nasdaq:CGRO', 'nasdaq:CGROU', 'nasdaq:CHAQ', 'nasdaq:CHCI', 'nasdaq:CHCO', 'nasdaq:CHCT', 'nasdaq:CHD', 'nasdaq:CHDN', 'nasdaq:CHE', 'nasdaq:CHEF', 'nasdaq:CHEK', 'nasdaq:CHFS', 'nasdaq:CHFW', 'nasdaq:CHGG', 'nasdaq:CHH', 'nasdaq:CHI', 'nasdaq:CHKP', 'nasdaq:CHMA', 'nasdaq:CHMG', 'nasdaq:CHMI', 'nasdaq:CHN', 'nasdaq:CHNG', 'nasdaq:CHNGU', 'nasdaq:CHNR', 'nasdaq:CHPM', 'nasdaq:CHPMU', 'nasdaq:CHRA', 'nasdaq:CHRS', 'nasdaq:CHRW', 'nasdaq:CHS', 'nasdaq:CHSCL', 'nasdaq:CHSCM', 'nasdaq:CHSCN', 'nasdaq:CHSCO', 'nasdaq:CHSCP', 'nasdaq:CHT', 'nasdaq:CHTR', 'nasdaq:CHUY', 'nasdaq:CHW', 'nasdaq:CHWY', 'nasdaq:CHX', 'nasdaq:CHY', 'nasdaq:CI', 'nasdaq:CIA', 'nasdaq:CIB', 'nasdaq:CIDM', 'nasdaq:CIEN', 'nasdaq:CIF', 'nasdaq:CIG', 'nasdaq:CIGI', 'nasdaq:CIH', 'nasdaq:CII', 'nasdaq:CIIC', 'nasdaq:CIICU', 'nasdaq:CIK', 'nasdaq:CIM', 'nasdaq:CINF', 'nasdaq:CINR', 'nasdaq:CIO', 'nasdaq:CIR', 'nasdaq:CIT', 'nasdaq:CIVB', 'nasdaq:CIX', 'nasdaq:CIXX', 'nasdaq:CIZN', 'nasdaq:CJJD', 'nasdaq:CKH', 'nasdaq:CKPT', 'nasdaq:CKX', 'nasdaq:CL', 'nasdaq:CLA', 'nasdaq:CLAR', 'nasdaq:CLB', 'nasdaq:CLBK', 'nasdaq:CLCT', 'nasdaq:CLDB', 'nasdaq:CLDR', 'nasdaq:CLDT', 'nasdaq:CLDX', 'nasdaq:CLEU', 'nasdaq:CLF', 'nasdaq:CLFD', 'nasdaq:CLGN', 'nasdaq:CLGX', 'nasdaq:CLH', 'nasdaq:CLI', 'nasdaq:CLII', 'nasdaq:CLIR', 'nasdaq:CLLS', 'nasdaq:CLM', 'nasdaq:CLMT', 'nasdaq:CLNC', 'nasdaq:CLNE', 'nasdaq:CLNN', 'nasdaq:CLNY', 'nasdaq:CLOV', 'nasdaq:CLPR', 'nasdaq:CLPS', 'nasdaq:CLPT', 'nasdaq:CLR', 'nasdaq:CLRB', 'nasdaq:CLRMU', 'nasdaq:CLRO', 'nasdaq:CLS', 'nasdaq:CLSD', 'nasdaq:CLSK', 'nasdaq:CLSN', 'nasdaq:CLVR', 'nasdaq:CLVS', 'nasdaq:CLVT', 'nasdaq:CLW', 'nasdaq:CLWT', 'nasdaq:CLX', 'nasdaq:CLXT', 'nasdaq:CM', 'nasdaq:CMA', 'nasdaq:CMBM', 'nasdaq:CMC', 'nasdaq:CMCL', 'nasdaq:CMCM', 'nasdaq:CMCO', 'nasdaq:CMCSA', 'nasdaq:CMCT', 'nasdaq:CMCTP', 'nasdaq:CMD', 'nasdaq:CME', 'nasdaq:CMFNL', 'nasdaq:CMG', 'nasdaq:CMI', 'nasdaq:CMLF', 'nasdaq:CMLFU', 'nasdaq:CMLS', 'nasdaq:CMO', 'nasdaq:CMP', 'nasdaq:CMPI', 'nasdaq:CMPR', 'nasdaq:CMPS', 'nasdaq:CMRE', 'nasdaq:CMRX', 'nasdaq:CMS', 'nasdaq:CMSA', 'nasdaq:CMSC', 'nasdaq:CMSD', 'nasdaq:CMT', 'nasdaq:CMTL', 'nasdaq:CMU', 'nasdaq:CNA', 'nasdaq:CNBKA', 'nasdaq:CNC', 'nasdaq:CNCE', 'nasdaq:CND', 'nasdaq:CNDT', 'nasdaq:CNET', 'nasdaq:CNEY', 'nasdaq:CNF', 'nasdaq:CNFR', 'nasdaq:CNFRL', 'nasdaq:CNHI', 'nasdaq:CNI', 'nasdaq:CNK', 'nasdaq:CNMD', 'nasdaq:CNNB', 'nasdaq:CNNE', 'nasdaq:CNO', 'nasdaq:CNOB', 'nasdaq:CNP', 'nasdaq:CNQ', 'nasdaq:CNR', 'nasdaq:CNS', 'nasdaq:CNSL', 'nasdaq:CNSP', 'nasdaq:CNST', 'nasdaq:CNTG', 'nasdaq:CNTY', 'nasdaq:CNX', 'nasdaq:CNXC', 'nasdaq:CNXN', 'nasdaq:CO', 'nasdaq:COCP', 'nasdaq:CODA', 'nasdaq:CODI', 'nasdaq:CODX', 'nasdaq:COE', 'nasdaq:COF', 'nasdaq:COFS', 'nasdaq:COG', 'nasdaq:COGT', 'nasdaq:COHN', 'nasdaq:COHR', 'nasdaq:COHU', 'nasdaq:COKE', 'nasdaq:COLB', 'nasdaq:COLD', 'nasdaq:COLL', 'nasdaq:COLM', 'nasdaq:COMM', 'nasdaq:COMS', 'nasdaq:CONE', 'nasdaq:CONN', 'nasdaq:CONX', 'nasdaq:CONXU', 'nasdaq:COO', 'nasdaq:COOLU', 'nasdaq:COOP', 'nasdaq:COP', 'nasdaq:COR', 'nasdaq:CORE', 'nasdaq:CORR', 'nasdaq:CORT', 'nasdaq:COST', 'nasdaq:COTY', 'nasdaq:COUP', 'nasdaq:COVAU', 'nasdaq:COWN', 'nasdaq:COWNL', 'nasdaq:COWNZ', 'nasdaq:CP', 'nasdaq:CPA', 'nasdaq:CPAC', 'nasdaq:CPAH', 'nasdaq:CPB', 'nasdaq:CPE', 'nasdaq:CPF', 'nasdaq:CPG', 'nasdaq:CPHC', 'nasdaq:CPHI', 'nasdaq:CPIX', 'nasdaq:CPK', 'nasdaq:CPLG', 'nasdaq:CPLP', 'nasdaq:CPRI', 'nasdaq:CPRT', 'nasdaq:CPRX', 'nasdaq:CPS', 'nasdaq:CPSH', 'nasdaq:CPSI', 'nasdaq:CPSR', 'nasdaq:CPSS', 'nasdaq:CPST', 'nasdaq:CPT', 'nasdaq:CPTA', 'nasdaq:CPTAG', 'nasdaq:CPTAL', 'nasdaq:CPZ', 'nasdaq:CQP', 'nasdaq:CR', 'nasdaq:CRAI', 'nasdaq:CRBP', 'nasdaq:CRC', 'nasdaq:CRD/A', 'nasdaq:CRD/B', 'nasdaq:CRDF', 'nasdaq:CREE', 'nasdaq:CREG', 'nasdaq:CRESY', 'nasdaq:CREX', 'nasdaq:CRF', 'nasdaq:CRH', 'nasdaq:CRHC', 'nasdaq:CRHM', 'nasdaq:CRI', 'nasdaq:CRIS', 'nasdaq:CRK', 'nasdaq:CRKN', 'nasdaq:CRL', 'nasdaq:CRM', 'nasdaq:CRMD', 'nasdaq:CRMT', 'nasdaq:CRNC', 'nasdaq:CRNT', 'nasdaq:CRNX', 'nasdaq:CRON', 'nasdaq:CROX', 'nasdaq:CRS', 'nasdaq:CRSA', 'nasdaq:CRSAU', 'nasdaq:CRSP', 'nasdaq:CRSR', 'nasdaq:CRT', 'nasdaq:CRTD', 'nasdaq:CRTO', 'nasdaq:CRTX', 'nasdaq:CRUS', 'nasdaq:CRVL', 'nasdaq:CRVS', 'nasdaq:CRWD', 'nasdaq:CRWS', 'nasdaq:CRY', 'nasdaq:CS', 'nasdaq:CSBR', 'nasdaq:CSCO', 'nasdaq:CSCW', 'nasdaq:CSGP', 'nasdaq:CSGS', 'nasdaq:CSII', 'nasdaq:CSIQ', 'nasdaq:CSL', 'nasdaq:CSLT', 'nasdaq:CSOD', 'nasdaq:CSPI', 'nasdaq:CSPR', 'nasdaq:CSQ', 'nasdaq:CSR', 'nasdaq:CSSE', 'nasdaq:CSSEN', 'nasdaq:CSSEP', 'nasdaq:CSTE', 'nasdaq:CSTL', 'nasdaq:CSTM', 'nasdaq:CSTR', 'nasdaq:CSU', 'nasdaq:CSV', 'nasdaq:CSWC', 'nasdaq:CSWI', 'nasdaq:CSX', 'nasdaq:CTAA', 'nasdaq:CTAC', 'nasdaq:CTAQ', 'nasdaq:CTAQU', 'nasdaq:CTAS', 'nasdaq:CTB', 'nasdaq:CTBB', 'nasdaq:CTBI', 'nasdaq:CTDD', 'nasdaq:CTEK', 'nasdaq:CTG', 'nasdaq:CTHR', 'nasdaq:CTIB', 'nasdaq:CTIC', 'nasdaq:CTK', 'nasdaq:CTLT', 'nasdaq:CTMX', 'nasdaq:CTO', 'nasdaq:CTR', 'nasdaq:CTRE', 'nasdaq:CTRM', 'nasdaq:CTRN', 'nasdaq:CTS', 'nasdaq:CTSH', 'nasdaq:CTSO', 'nasdaq:CTT', 'nasdaq:CTVA', 'nasdaq:CTXR', 'nasdaq:CTXS', 'nasdaq:CUB', 'nasdaq:CUBA', 'nasdaq:CUBB', 'nasdaq:CUBE', 'nasdaq:CUBI', 'nasdaq:CUE', 'nasdaq:CUEN', 'nasdaq:CUK', 'nasdaq:CULP', 'nasdaq:CURI', 'nasdaq:CURO', 'nasdaq:CUTR', 'nasdaq:CUZ', 'nasdaq:CVA', 'nasdaq:CVAC', 'nasdaq:CVBF', 'nasdaq:CVCO', 'nasdaq:CVCY', 'nasdaq:CVE', 'nasdaq:CVEO', 'nasdaq:CVET', 'nasdaq:CVGI', 'nasdaq:CVGW', 'nasdaq:CVI', 'nasdaq:CVLB', 'nasdaq:CVLG', 'nasdaq:CVLT', 'nasdaq:CVLY', 'nasdaq:CVM', 'nasdaq:CVNA', 'nasdaq:CVR', 'nasdaq:CVS', 'nasdaq:CVU', 'nasdaq:CVV', 'nasdaq:CVX', 'nasdaq:CW', 'nasdaq:CWBC', 'nasdaq:CWBR', 'nasdaq:CWCO', 'nasdaq:CWEN', 'nasdaq:CWH', 'nasdaq:CWK', 'nasdaq:CWST', 'nasdaq:CWT', 'nasdaq:CXDC', 'nasdaq:CXDO', 'nasdaq:CXE', 'nasdaq:CXH', 'nasdaq:CXP', 'nasdaq:CXW', 'nasdaq:CYAD', 'nasdaq:CYAN', 'nasdaq:CYBE', 'nasdaq:CYBR', 'nasdaq:CYCC', 'nasdaq:CYCCP', 'nasdaq:CYCN', 'nasdaq:CYD', 'nasdaq:CYH', 'nasdaq:CYRN', 'nasdaq:CYRX', 'nasdaq:CYTH', 'nasdaq:CYTK', 'nasdaq:CZNC', 'nasdaq:CZR', 'nasdaq:CZWI', 'nasdaq:CZZ', 'nasdaq:D', 'nasdaq:DAC', 'nasdaq:DADA', 'nasdaq:DAIO', 'nasdaq:DAKT', 'nasdaq:DAL', 'nasdaq:DAN', 'nasdaq:DAO', 'nasdaq:DAR', 'nasdaq:DARE', 'nasdaq:DASH', 'nasdaq:DAVA', 'nasdaq:DB', 'nasdaq:DBD', 'nasdaq:DBDR', 'nasdaq:DBDRU', 'nasdaq:DBI', 'nasdaq:DBL', 'nasdaq:DBVT', 'nasdaq:DBX', 'nasdaq:DCBO', 'nasdaq:DCF', 'nasdaq:DCI', 'nasdaq:DCO', 'nasdaq:DCOM', 'nasdaq:DCOMP', 'nasdaq:DCP', 'nasdaq:DCPH', 'nasdaq:DCRB', 'nasdaq:DCRBU', 'nasdaq:DCRNU', 'nasdaq:DCT', 'nasdaq:DCTH', 'nasdaq:DCUE', 'nasdaq:DD', 'nasdaq:DDD', 'nasdaq:DDF', 'nasdaq:DDMX', 'nasdaq:DDMXU', 'nasdaq:DDOG', 'nasdaq:DDS', 'nasdaq:DDT', 'nasdaq:DE', 'nasdaq:DEA', 'nasdaq:DECK', 'nasdaq:DEH', 'nasdaq:DEI', 'nasdaq:DELL', 'nasdaq:DEN', 'nasdaq:DENN', 'nasdaq:DEO', 'nasdaq:DESP', 'nasdaq:DEX', 'nasdaq:DFFN', 'nasdaq:DFH', 'nasdaq:DFHT', 'nasdaq:DFHTU', 'nasdaq:DFIN', 'nasdaq:DFNS', 'nasdaq:DFP', 'nasdaq:DFPH', 'nasdaq:DFPHU', 'nasdaq:DFS', 'nasdaq:DG', 'nasdaq:DGICA', 'nasdaq:DGICB', 'nasdaq:DGII', 'nasdaq:DGLY', 'nasdaq:DGNR', 'nasdaq:DGNS', 'nasdaq:DGX', 'nasdaq:DHC', 'nasdaq:DHCNI', 'nasdaq:DHCNL', 'nasdaq:DHF', 'nasdaq:DHHCU', 'nasdaq:DHI', 'nasdaq:DHIL', 'nasdaq:DHR', 'nasdaq:DHT', 'nasdaq:DHX', 'nasdaq:DHY', 'nasdaq:DIAX', 'nasdaq:DIN', 'nasdaq:DIOD', 'nasdaq:DIS', 'nasdaq:DISCA', 'nasdaq:DISCB', 'nasdaq:DISCK', 'nasdaq:DISH', 'nasdaq:DIT', 'nasdaq:DJCO', 'nasdaq:DK', 'nasdaq:DKL', 'nasdaq:DKNG', 'nasdaq:DKS', 'nasdaq:DL', 'nasdaq:DLA', 'nasdaq:DLB', 'nasdaq:DLCAU', 'nasdaq:DLHC', 'nasdaq:DLNG', 'nasdaq:DLPN', 'nasdaq:DLR', 'nasdaq:DLTH', 'nasdaq:DLTR', 'nasdaq:DLX', 'nasdaq:DLY', 'nasdaq:DM', 'nasdaq:DMAC', 'nasdaq:DMB', 'nasdaq:DMF', 'nasdaq:DMLP', 'nasdaq:DMO', 'nasdaq:DMRC', 'nasdaq:DMS', 'nasdaq:DMTK', 'nasdaq:DMYD', 'nasdaq:DMYI', 'nasdaq:DNB', 'nasdaq:DNK', 'nasdaq:DNLI', 'nasdaq:DNMR', 'nasdaq:DNN', 'nasdaq:DNOW', 'nasdaq:DNP', 'nasdaq:DOC', 'nasdaq:DOCU', 'nasdaq:DOGZ', 'nasdaq:DOMO', 'nasdaq:DOOO', 'nasdaq:DOOR', 'nasdaq:DORM', 'nasdaq:DOV', 'nasdaq:DOW', 'nasdaq:DOX', 'nasdaq:DOYU', 'nasdaq:DPG', 'nasdaq:DPW', 'nasdaq:DPZ', 'nasdaq:DQ', 'nasdaq:DRD', 'nasdaq:DRE', 'nasdaq:DRH', 'nasdaq:DRI', 'nasdaq:DRIO', 'nasdaq:DRNA', 'nasdaq:DRQ', 'nasdaq:DRRX', 'nasdaq:DRTT', 'nasdaq:DRUA', 'nasdaq:DRVN', 'nasdaq:DS', 'nasdaq:DSAC', 'nasdaq:DSACU', 'nasdaq:DSE', 'nasdaq:DSGX', 'nasdaq:DSKE', 'nasdaq:DSL', 'nasdaq:DSM', 'nasdaq:DSPG', 'nasdaq:DSS', 'nasdaq:DSSI', 'nasdaq:DSU', 'nasdaq:DSWL', 'nasdaq:DSX', 'nasdaq:DT', 'nasdaq:DTB', 'nasdaq:DTE', 'nasdaq:DTEA', 'nasdaq:DTF', 'nasdaq:DTIL', 'nasdaq:DTJ', 'nasdaq:DTP', 'nasdaq:DTSS', 'nasdaq:DTW', 'nasdaq:DTY', 'nasdaq:DUC', 'nasdaq:DUK', 'nasdaq:DUKB', 'nasdaq:DUKH', 'nasdaq:DUNEU', 'nasdaq:DUO', 'nasdaq:DUOT', 'nasdaq:DVA', 'nasdaq:DVAX', 'nasdaq:DVD', 'nasdaq:DVN', 'nasdaq:DWIN', 'nasdaq:DWSN', 'nasdaq:DX', 'nasdaq:DXC', 'nasdaq:DXCM', 'nasdaq:DXF', 'nasdaq:DXPE', 'nasdaq:DXR', 'nasdaq:DXYN', 'nasdaq:DY', 'nasdaq:DYAI', 'nasdaq:DYFN', 'nasdaq:DYN', 'nasdaq:DYNT', 'nasdaq:DZSI', 'nasdaq:E', 'nasdaq:EA', 'nasdaq:EACPU', 'nasdaq:EAD', 'nasdaq:EAF', 'nasdaq:EAI', 'nasdaq:EAR', 'nasdaq:EARN', 'nasdaq:EARS', 'nasdaq:EAST', 'nasdaq:EAT', 'nasdaq:EB', 'nasdaq:EBAY', 'nasdaq:EBAYL', 'nasdaq:EBC', 'nasdaq:EBF', 'nasdaq:EBIX', 'nasdaq:EBMT', 'nasdaq:EBON', 'nasdaq:EBR', 'nasdaq:EBS', 'nasdaq:EBSB', 'nasdaq:EBTC', 'nasdaq:EC', 'nasdaq:ECC           ', 'nasdaq:ECCB', 'nasdaq:ECCX', 'nasdaq:ECCY', 'nasdaq:ECF', 'nasdaq:ECHO', 'nasdaq:ECL', 'nasdaq:ECOL', 'nasdaq:ECOM          ', 'nasdaq:ECOR', 'nasdaq:ECPG', 'nasdaq:ED', 'nasdaq:EDAP', 'nasdaq:EDD', 'nasdaq:EDF', 'nasdaq:EDI', 'nasdaq:EDIT', 'nasdaq:EDN', 'nasdaq:EDRY', 'nasdaq:EDSA', 'nasdaq:EDTK', 'nasdaq:EDTXU', 'nasdaq:EDUC', 'nasdaq:EEA', 'nasdaq:EEFT', 'nasdaq:EEX', 'nasdaq:EFC', 'nasdaq:EFF', 'nasdaq:EFL', 'nasdaq:EFOI', 'nasdaq:EFR', 'nasdaq:EFSC', 'nasdaq:EFT', 'nasdaq:EFX', 'nasdaq:EGAN', 'nasdaq:EGBN', 'nasdaq:EGF', 'nasdaq:EGHT', 'nasdaq:EGLE', 'nasdaq:EGO', 'nasdaq:EGOV', 'nasdaq:EGP', 'nasdaq:EGRX', 'nasdaq:EGY', 'nasdaq:EH', 'nasdaq:EHC', 'nasdaq:EHI', 'nasdaq:EHT', 'nasdaq:EHTH', 'nasdaq:EIC', 'nasdaq:EIG', 'nasdaq:EIGI', 'nasdaq:EIGR', 'nasdaq:EIM', 'nasdaq:EIX', 'nasdaq:EKSO', 'nasdaq:EL', 'nasdaq:ELA', 'nasdaq:ELAN', 'nasdaq:ELAT', 'nasdaq:ELC', 'nasdaq:ELDN', 'nasdaq:ELF', 'nasdaq:ELLO', 'nasdaq:ELMD', 'nasdaq:ELOX', 'nasdaq:ELP', 'nasdaq:ELS', 'nasdaq:ELSE', 'nasdaq:ELTK', 'nasdaq:ELVT', 'nasdaq:ELY', 'nasdaq:ELYS', 'nasdaq:EMAN', 'nasdaq:EMCF', 'nasdaq:EMD', 'nasdaq:EME', 'nasdaq:EMF', 'nasdaq:EMKR', 'nasdaq:EML', 'nasdaq:EMN', 'nasdaq:EMO', 'nasdaq:EMP', 'nasdaq:EMPW', 'nasdaq:EMR', 'nasdaq:EMX', 'nasdaq:ENB', 'nasdaq:ENBA', 'nasdaq:ENBL', 'nasdaq:ENDP', 'nasdaq:ENFAU', 'nasdaq:ENG', 'nasdaq:ENIA', 'nasdaq:ENIC', 'nasdaq:ENJ', 'nasdaq:ENLC', 'nasdaq:ENLV', 'nasdaq:ENO', 'nasdaq:ENOB', 'nasdaq:ENPC', 'nasdaq:ENPH', 'nasdaq:ENR', 'nasdaq:ENS', 'nasdaq:ENSG', 'nasdaq:ENSV', 'nasdaq:ENTA', 'nasdaq:ENTG', 'nasdaq:ENTX', 'nasdaq:ENV', 'nasdaq:ENVA', 'nasdaq:ENVB', 'nasdaq:ENVIU', 'nasdaq:ENX', 'nasdaq:ENZ', 'nasdaq:EOD', 'nasdaq:EOG', 'nasdaq:EOI', 'nasdaq:EOLS', 'nasdaq:EOS', 'nasdaq:EOSE', 'nasdaq:EOT', 'nasdaq:EPAC', 'nasdaq:EPAM', 'nasdaq:EPAY', 'nasdaq:EPC', 'nasdaq:EPD', 'nasdaq:EPHYU', 'nasdaq:EPIX', 'nasdaq:EPM', 'nasdaq:EPR', 'nasdaq:EPRT', 'nasdaq:EPSN', 'nasdaq:EPZM', 'nasdaq:EQ', 'nasdaq:EQBK', 'nasdaq:EQC', 'nasdaq:EQD', 'nasdaq:EQH', 'nasdaq:EQIX', 'nasdaq:EQNR', 'nasdaq:EQOS', 'nasdaq:EQR', 'nasdaq:EQS', 'nasdaq:EQT', 'nasdaq:EQX', 'nasdaq:ERC', 'nasdaq:ERES', 'nasdaq:ERESU', 'nasdaq:ERF', 'nasdaq:ERH', 'nasdaq:ERIC', 'nasdaq:ERIE', 'nasdaq:ERII', 'nasdaq:ERJ', 'nasdaq:ERYP', 'nasdaq:ES', 'nasdaq:ESBK', 'nasdaq:ESCA', 'nasdaq:ESE', 'nasdaq:ESEA', 'nasdaq:ESGC', 'nasdaq:ESGR', 'nasdaq:ESGRO', 'nasdaq:ESGRP', 'nasdaq:ESI', 'nasdaq:ESLT', 'nasdaq:ESNT', 'nasdaq:ESP', 'nasdaq:ESPR', 'nasdaq:ESQ', 'nasdaq:ESRT', 'nasdaq:ESS', 'nasdaq:ESSA', 'nasdaq:ESSC', 'nasdaq:ESSCR', 'nasdaq:ESSCU', 'nasdaq:ESTA', 'nasdaq:ESTC', 'nasdaq:ESTE', 'nasdaq:ESXB', 'nasdaq:ET', 'nasdaq:ETAC', 'nasdaq:ETACU', 'nasdaq:ETB', 'nasdaq:ETG', 'nasdaq:ETH', 'nasdaq:ETJ', 'nasdaq:ETM', 'nasdaq:ETN', 'nasdaq:ETNB', 'nasdaq:ETO', 'nasdaq:ETON', 'nasdaq:ETR', 'nasdaq:ETRN', 'nasdaq:ETSY', 'nasdaq:ETTX', 'nasdaq:ETV', 'nasdaq:ETW', 'nasdaq:ETWO', 'nasdaq:ETX           ', 'nasdaq:ETY', 'nasdaq:EUCR', 'nasdaq:EUCRU', 'nasdaq:EURN', 'nasdaq:EUSGU', 'nasdaq:EV', 'nasdaq:EVA', 'nasdaq:EVAX', 'nasdaq:EVBG', 'nasdaq:EVBN', 'nasdaq:EVC', 'nasdaq:EVER', 'nasdaq:EVF', 'nasdaq:EVFM', 'nasdaq:EVG', 'nasdaq:EVGBC', 'nasdaq:EVGN', 'nasdaq:EVH', 'nasdaq:EVI', 'nasdaq:EVK', 'nasdaq:EVLO', 'nasdaq:EVM', 'nasdaq:EVN', 'nasdaq:EVOK', 'nasdaq:EVOL', 'nasdaq:EVOP', 'nasdaq:EVR', 'nasdaq:EVRG', 'nasdaq:EVRI', 'nasdaq:EVT', 'nasdaq:EVTC', 'nasdaq:EVV', 'nasdaq:EVY', 'nasdaq:EW', 'nasdaq:EWBC', 'nasdaq:EXAS', 'nasdaq:EXC', 'nasdaq:EXD', 'nasdaq:EXEL', 'nasdaq:EXFO', 'nasdaq:EXG', 'nasdaq:EXK', 'nasdaq:EXLS', 'nasdaq:EXN', 'nasdaq:EXP', 'nasdaq:EXPC', 'nasdaq:EXPCU', 'nasdaq:EXPD', 'nasdaq:EXPE', 'nasdaq:EXPI', 'nasdaq:EXPO', 'nasdaq:EXPR', 'nasdaq:EXR', 'nasdaq:EXTN', 'nasdaq:EXTR', 'nasdaq:EYE', 'nasdaq:EYEG', 'nasdaq:EYEN', 'nasdaq:EYES', 'nasdaq:EYPT', 'nasdaq:EZGO', 'nasdaq:EZPW', 'nasdaq:F', 'nasdaq:FAF', 'nasdaq:FAII', 'nasdaq:FAM', 'nasdaq:FAMI', 'nasdaq:FANG', 'nasdaq:FANH', 'nasdaq:FARM', 'nasdaq:FARO', 'nasdaq:FAST', 'nasdaq:FAT', 'nasdaq:FATBP', 'nasdaq:FATE', 'nasdaq:FAX', 'nasdaq:FB', 'nasdaq:FBC', 'nasdaq:FBHS', 'nasdaq:FBIO', 'nasdaq:FBIOP', 'nasdaq:FBIZ', 'nasdaq:FBK', 'nasdaq:FBMS', 'nasdaq:FBNC', 'nasdaq:FBP', 'nasdaq:FBRX', 'nasdaq:FBSS', 'nasdaq:FC', 'nasdaq:FCAC', 'nasdaq:FCACU', 'nasdaq:FCAP', 'nasdaq:FCBC', 'nasdaq:FCBP', 'nasdaq:FCCO', 'nasdaq:FCCY', 'nasdaq:FCEL', 'nasdaq:FCF', 'nasdaq:FCFS', 'nasdaq:FCN', 'nasdaq:FCNCA', 'nasdaq:FCNCP', 'nasdaq:FCO', 'nasdaq:FCPT', 'nasdaq:FCRD', 'nasdaq:FCRW', 'nasdaq:FCRZ', 'nasdaq:FCT', 'nasdaq:FCX', 'nasdaq:FDBC', 'nasdaq:FDEU', 'nasdaq:FDMT', 'nasdaq:FDP', 'nasdaq:FDS', 'nasdaq:FDUS', 'nasdaq:FDUSG', 'nasdaq:FDUSZ', 'nasdaq:FDX', 'nasdaq:FE', 'nasdaq:FEDU', 'nasdaq:FEI           ', 'nasdaq:FEIM', 'nasdaq:FELE', 'nasdaq:FEN', 'nasdaq:FENC', 'nasdaq:FENG', 'nasdaq:FEO', 'nasdaq:FET', 'nasdaq:FEYE', 'nasdaq:FF', 'nasdaq:FFA', 'nasdaq:FFBC', 'nasdaq:FFBW', 'nasdaq:FFC', 'nasdaq:FFG', 'nasdaq:FFHL', 'nasdaq:FFIC', 'nasdaq:FFIN', 'nasdaq:FFIV', 'nasdaq:FFNW', 'nasdaq:FFWM', 'nasdaq:FGB', 'nasdaq:FGBI', 'nasdaq:FGEN', 'nasdaq:FGF', 'nasdaq:FGFPP', 'nasdaq:FGNA', 'nasdaq:FHB', 'nasdaq:FHI', 'nasdaq:FHN', 'nasdaq:FHTX', 'nasdaq:FI', 'nasdaq:FIBK', 'nasdaq:FICO', 'nasdaq:FIF', 'nasdaq:FIII', 'nasdaq:FIIIU', 'nasdaq:FINMU', 'nasdaq:FINS', 'nasdaq:FINV', 'nasdaq:FIS', 'nasdaq:FISI', 'nasdaq:FISV', 'nasdaq:FITB', 'nasdaq:FITBI', 'nasdaq:FITBO', 'nasdaq:FITBP', 'nasdaq:FIV', 'nasdaq:FIVE', 'nasdaq:FIVN', 'nasdaq:FIX', 'nasdaq:FIXX', 'nasdaq:FIZZ', 'nasdaq:FL', 'nasdaq:FLACU', 'nasdaq:FLC', 'nasdaq:FLDM', 'nasdaq:FLEX', 'nasdaq:FLGT', 'nasdaq:FLIC', 'nasdaq:FLIR', 'nasdaq:FLL', 'nasdaq:FLMN', 'nasdaq:FLNG', 'nasdaq:FLNT', 'nasdaq:FLO', 'nasdaq:FLOW', 'nasdaq:FLR', 'nasdaq:FLS', 'nasdaq:FLT', 'nasdaq:FLUX', 'nasdaq:FLWS', 'nasdaq:FLXN', 'nasdaq:FLXS', 'nasdaq:FLY', 'nasdaq:FMAC', 'nasdaq:FMAO', 'nasdaq:FMBH', 'nasdaq:FMBI', 'nasdaq:FMBIO', 'nasdaq:FMBIP', 'nasdaq:FMC', 'nasdaq:FMN', 'nasdaq:FMNB', 'nasdaq:FMO', 'nasdaq:FMS', 'nasdaq:FMTX', 'nasdaq:FMX', 'nasdaq:FMY', 'nasdaq:FN', 'nasdaq:FNB', 'nasdaq:FNCB', 'nasdaq:FND', 'nasdaq:FNF', 'nasdaq:FNHC', 'nasdaq:FNKO', 'nasdaq:FNLC', 'nasdaq:FNV', 'nasdaq:FNWB', 'nasdaq:FOCS', 'nasdaq:FOE', 'nasdaq:FOF', 'nasdaq:FOLD', 'nasdaq:FONR', 'nasdaq:FOR', 'nasdaq:FORD', 'nasdaq:FORM', 'nasdaq:FORR', 'nasdaq:FORTY', 'nasdaq:FOSL', 'nasdaq:FOUR', 'nasdaq:FOX', 'nasdaq:FOXA', 'nasdaq:FOXF', 'nasdaq:FOXWU', 'nasdaq:FPAC', 'nasdaq:FPAY', 'nasdaq:FPF', 'nasdaq:FPH', 'nasdaq:FPI', 'nasdaq:FPL', 'nasdaq:FPRX', 'nasdaq:FR', 'nasdaq:FRA', 'nasdaq:FRAF', 'nasdaq:FRBA', 'nasdaq:FRBK', 'nasdaq:FRC', 'nasdaq:FRD', 'nasdaq:FREE', 'nasdaq:FREQ', 'nasdaq:FRG', 'nasdaq:FRGAP', 'nasdaq:FRGI', 'nasdaq:FRHC', 'nasdaq:FRLN', 'nasdaq:FRME', 'nasdaq:FRO', 'nasdaq:FROG', 'nasdaq:FRPH', 'nasdaq:FRPT', 'nasdaq:FRSX', 'nasdaq:FRT', 'nasdaq:FRTA', 'nasdaq:FRX', 'nasdaq:FSBW', 'nasdaq:FSD', 'nasdaq:FSDC', 'nasdaq:FSEA', 'nasdaq:FSFG', 'nasdaq:FSI', 'nasdaq:FSK', 'nasdaq:FSKR', 'nasdaq:FSLF', 'nasdaq:FSLR', 'nasdaq:FSLY', 'nasdaq:FSM', 'nasdaq:FSP', 'nasdaq:FSR', 'nasdaq:FSRV', 'nasdaq:FSRVU', 'nasdaq:FSS', 'nasdaq:FSSIU', 'nasdaq:FST', 'nasdaq:FSTR', 'nasdaq:FSTX', 'nasdaq:FSV', 'nasdaq:FT', 'nasdaq:FTAI', 'nasdaq:FTCH', 'nasdaq:FTCV', 'nasdaq:FTCVU', 'nasdaq:FTDR', 'nasdaq:FTEK', 'nasdaq:FTF', 'nasdaq:FTFT', 'nasdaq:FTHM', 'nasdaq:FTHY', 'nasdaq:FTI', 'nasdaq:FTIV', 'nasdaq:FTIVU', 'nasdaq:FTK', 'nasdaq:FTNT', 'nasdaq:FTOC', 'nasdaq:FTOCU', 'nasdaq:FTS', 'nasdaq:FTSI', 'nasdaq:FTV', 'nasdaq:FUBO', 'nasdaq:FUL', 'nasdaq:FULC', 'nasdaq:FULT', 'nasdaq:FULTP', 'nasdaq:FUN', 'nasdaq:FUNC', 'nasdaq:FUND', 'nasdaq:FURY', 'nasdaq:FUSB', 'nasdaq:FUSE', 'nasdaq:FUSN', 'nasdaq:FUTU', 'nasdaq:FUV', 'nasdaq:FVAM', 'nasdaq:FVCB', 'nasdaq:FVE', 'nasdaq:FVRR', 'nasdaq:FWAA', 'nasdaq:FWONA', 'nasdaq:FWONK', 'nasdaq:FWP', 'nasdaq:FWRD', 'nasdaq:FXNC', 'nasdaq:G', 'nasdaq:GAB', 'nasdaq:GABC', 'nasdaq:GAIA', 'nasdaq:GAIN', 'nasdaq:GAINL', 'nasdaq:GAINM', 'nasdaq:GALT', 'nasdaq:GAM', 'nasdaq:GAN', 'nasdaq:GASS', 'nasdaq:GATO', 'nasdaq:GATX', 'nasdaq:GAU', 'nasdaq:GB', 'nasdaq:GBAB', 'nasdaq:GBCI', 'nasdaq:GBDC', 'nasdaq:GBIO', 'nasdaq:GBL', 'nasdaq:GBLI', 'nasdaq:GBLIL', 'nasdaq:GBNY', 'nasdaq:GBR', 'nasdaq:GBS', 'nasdaq:GBT', 'nasdaq:GBX', 'nasdaq:GCACU', 'nasdaq:GCBC', 'nasdaq:GCI', 'nasdaq:GCMG', 'nasdaq:GCO', 'nasdaq:GCP', 'nasdaq:GCV', 'nasdaq:GD', 'nasdaq:GDDY', 'nasdaq:GDEN', 'nasdaq:GDL', 'nasdaq:GDO', 'nasdaq:GDOT', 'nasdaq:GDP', 'nasdaq:GDRX', 'nasdaq:GDS', 'nasdaq:GDV', 'nasdaq:GDYN', 'nasdaq:GE', 'nasdaq:GECC', 'nasdaq:GECCL', 'nasdaq:GECCM', 'nasdaq:GECCN', 'nasdaq:GEF', 'nasdaq:GEG', 'nasdaq:GEL', 'nasdaq:GEN           ', 'nasdaq:GENC', 'nasdaq:GEO', 'nasdaq:GEOS', 'nasdaq:GER', 'nasdaq:GERN', 'nasdaq:GES', 'nasdaq:GEVO', 'nasdaq:GF', 'nasdaq:GFED', 'nasdaq:GFF', 'nasdaq:GFI', 'nasdaq:GFL', 'nasdaq:GFLU', 'nasdaq:GFN', 'nasdaq:GFNCP', 'nasdaq:GFNSZ', 'nasdaq:GGAL', 'nasdaq:GGB', 'nasdaq:GGG', 'nasdaq:GGM', 'nasdaq:GGN', 'nasdaq:GGT', 'nasdaq:GGZ', 'nasdaq:GH', 'nasdaq:GHACU', 'nasdaq:GHC', 'nasdaq:GHG', 'nasdaq:GHL', 'nasdaq:GHLD', 'nasdaq:GHM', 'nasdaq:GHSI', 'nasdaq:GHVI', 'nasdaq:GHVIU', 'nasdaq:GHY', 'nasdaq:GIB', 'nasdaq:GIFI', 'nasdaq:GIGM', 'nasdaq:GIII', 'nasdaq:GIK', 'nasdaq:GIL', 'nasdaq:GILD', 'nasdaq:GILT', 'nasdaq:GIM', 'nasdaq:GIS', 'nasdaq:GIX', 'nasdaq:GJH', 'nasdaq:GJO', 'nasdaq:GJP', 'nasdaq:GJR', 'nasdaq:GJS', 'nasdaq:GJT', 'nasdaq:GKOS', 'nasdaq:GL', 'nasdaq:GLAD', 'nasdaq:GLADL', 'nasdaq:GLAQ', 'nasdaq:GLAQU', 'nasdaq:GLBS', 'nasdaq:GLBZ', 'nasdaq:GLDD', 'nasdaq:GLDG', 'nasdaq:GLEO', 'nasdaq:GLG', 'nasdaq:GLMD', 'nasdaq:GLNG', 'nasdaq:GLO', 'nasdaq:GLOB', 'nasdaq:GLOG', 'nasdaq:GLOP', 'nasdaq:GLP', 'nasdaq:GLPG', 'nasdaq:GLPI', 'nasdaq:GLQ', 'nasdaq:GLRE', 'nasdaq:GLSI', 'nasdaq:GLT', 'nasdaq:GLTO', 'nasdaq:GLU', 'nasdaq:GLUU', 'nasdaq:GLV', 'nasdaq:GLW', 'nasdaq:GLYC', 'nasdaq:GM', 'nasdaq:GMAB', 'nasdaq:GMBL', 'nasdaq:GMBTU', 'nasdaq:GMDA', 'nasdaq:GME', 'nasdaq:GMED', 'nasdaq:GMIIU', 'nasdaq:GMLP', 'nasdaq:GMLPP', 'nasdaq:GMRE', 'nasdaq:GMS', 'nasdaq:GMTA', 'nasdaq:GNACU', 'nasdaq:GNCA', 'nasdaq:GNE', 'nasdaq:GNFT', 'nasdaq:GNK', 'nasdaq:GNL', 'nasdaq:GNLN', 'nasdaq:GNMK', 'nasdaq:GNOG', 'nasdaq:GNPK', 'nasdaq:GNPX', 'nasdaq:GNRC', 'nasdaq:GNRS', 'nasdaq:GNRSU', 'nasdaq:GNSS', 'nasdaq:GNT', 'nasdaq:GNTX', 'nasdaq:GNTY', 'nasdaq:GNUS', 'nasdaq:GNW', 'nasdaq:GO', 'nasdaq:GOAC', 'nasdaq:GOCO', 'nasdaq:GOED', 'nasdaq:GOEV', 'nasdaq:GOF', 'nasdaq:GOGL', 'nasdaq:GOGO', 'nasdaq:GOLD', 'nasdaq:GOLF', 'nasdaq:GOOD', 'nasdaq:GOODM', 'nasdaq:GOODN', 'nasdaq:GOOG', 'nasdaq:GOOGL', 'nasdaq:GOOS', 'nasdaq:GORO', 'nasdaq:GOSS', 'nasdaq:GOVX', 'nasdaq:GP', 'nasdaq:GPACU', 'nasdaq:GPC', 'nasdaq:GPI', 'nasdaq:GPJA', 'nasdaq:GPK', 'nasdaq:GPL', 'nasdaq:GPM', 'nasdaq:GPMT', 'nasdaq:GPN', 'nasdaq:GPP', 'nasdaq:GPRE', 'nasdaq:GPRK', 'nasdaq:GPRO', 'nasdaq:GPS', 'nasdaq:GPX', 'nasdaq:GRA', 'nasdaq:GRAY', 'nasdaq:GRBK', 'nasdaq:GRC', 'nasdaq:GRCL', 'nasdaq:GRCY', 'nasdaq:GRCYU', 'nasdaq:GRF', 'nasdaq:GRFS', 'nasdaq:GRIL', 'nasdaq:GRIN', 'nasdaq:GRMN', 'nasdaq:GRNQ', 'nasdaq:GRNV', 'nasdaq:GRNVR', 'nasdaq:GROW', 'nasdaq:GRPN', 'nasdaq:GRSV', 'nasdaq:GRSVU', 'nasdaq:GRTS', 'nasdaq:GRTX', 'nasdaq:GRUB', 'nasdaq:GRVY', 'nasdaq:GRWG', 'nasdaq:GRX', 'nasdaq:GS', 'nasdaq:GSAH', 'nasdaq:GSAQU', 'nasdaq:GSAT', 'nasdaq:GSBC', 'nasdaq:GSBD', 'nasdaq:GSHD', 'nasdaq:GSIT', 'nasdaq:GSK', 'nasdaq:GSKY', 'nasdaq:GSL', 'nasdaq:GSLD', 'nasdaq:GSM', 'nasdaq:GSMG', 'nasdaq:GSS', 'nasdaq:GSUM', 'nasdaq:GSV', 'nasdaq:GSX', 'nasdaq:GT', 'nasdaq:GTE', 'nasdaq:GTEC', 'nasdaq:GTES', 'nasdaq:GTH', 'nasdaq:GTHX', 'nasdaq:GTIM', 'nasdaq:GTLS', 'nasdaq:GTN', 'nasdaq:GTS', 'nasdaq:GTT', 'nasdaq:GTY', 'nasdaq:GTYH', 'nasdaq:GURE', 'nasdaq:GUT', 'nasdaq:GVA', 'nasdaq:GVP', 'nasdaq:GWAC', 'nasdaq:GWB', 'nasdaq:GWGH', 'nasdaq:GWPH', 'nasdaq:GWRE', 'nasdaq:GWRS', 'nasdaq:GWW', 'nasdaq:GXGX', 'nasdaq:GXGXU', 'nasdaq:GYC', 'nasdaq:GYRO', 'nasdaq:H', 'nasdaq:HA', 'nasdaq:HAAC', 'nasdaq:HAACU', 'nasdaq:HAE', 'nasdaq:HAFC', 'nasdaq:HAIN', 'nasdaq:HAL', 'nasdaq:HALL', 'nasdaq:HALO', 'nasdaq:HAPP', 'nasdaq:HARP', 'nasdaq:HAS', 'nasdaq:HASI', 'nasdaq:HAYN', 'nasdaq:HBAN', 'nasdaq:HBANN', 'nasdaq:HBANO', 'nasdaq:HBB', 'nasdaq:HBCP', 'nasdaq:HBI', 'nasdaq:HBIO', 'nasdaq:HBM', 'nasdaq:HBMD', 'nasdaq:HBNC', 'nasdaq:HBP', 'nasdaq:HBT', 'nasdaq:HCA', 'nasdaq:HCAP', 'nasdaq:HCAPZ', 'nasdaq:HCAQ', 'nasdaq:HCAR', 'nasdaq:HCARU', 'nasdaq:HCAT', 'nasdaq:HCC', 'nasdaq:HCCCU', 'nasdaq:HCCI', 'nasdaq:HCDI', 'nasdaq:HCHC', 'nasdaq:HCI', 'nasdaq:HCICU', 'nasdaq:HCIIU', 'nasdaq:HCKT', 'nasdaq:HCM', 'nasdaq:HCSG', 'nasdaq:HCXY', 'nasdaq:HCXZ', 'nasdaq:HD', 'nasdaq:HDB', 'nasdaq:HDSN', 'nasdaq:HE', 'nasdaq:HEAR', 'nasdaq:HEC', 'nasdaq:HECCU', 'nasdaq:HEES', 'nasdaq:HEI', 'nasdaq:HEI/A', 'nasdaq:HELE', 'nasdaq:HEP', 'nasdaq:HEPA', 'nasdaq:HEQ', 'nasdaq:HES', 'nasdaq:HESM', 'nasdaq:HEXO', 'nasdaq:HFBL', 'nasdaq:HFC', 'nasdaq:HFFG', 'nasdaq:HFRO', 'nasdaq:HFWA', 'nasdaq:HGBL', 'nasdaq:HGEN', 'nasdaq:HGH', 'nasdaq:HGLB', 'nasdaq:HGSH', 'nasdaq:HGV', 'nasdaq:HHC', 'nasdaq:HHR', 'nasdaq:HI', 'nasdaq:HIBB', 'nasdaq:HIE', 'nasdaq:HIFS', 'nasdaq:HIG', 'nasdaq:HIGA', 'nasdaq:HIHO', 'nasdaq:HII', 'nasdaq:HIL', 'nasdaq:HIMS', 'nasdaq:HIMX', 'nasdaq:HIO', 'nasdaq:HIW', 'nasdaq:HIX', 'nasdaq:HJLI', 'nasdaq:HKIB', 'nasdaq:HL', 'nasdaq:HLAHU', 'nasdaq:HLF', 'nasdaq:HLG', 'nasdaq:HLI', 'nasdaq:HLIO', 'nasdaq:HLIT', 'nasdaq:HLNE', 'nasdaq:HLT', 'nasdaq:HLX', 'nasdaq:HLXA', 'nasdaq:HMC', 'nasdaq:HMCO', 'nasdaq:HMCOU', 'nasdaq:HMG', 'nasdaq:HMHC', 'nasdaq:HMI', 'nasdaq:HMLP', 'nasdaq:HMN', 'nasdaq:HMNF', 'nasdaq:HMPT', 'nasdaq:HMST', 'nasdaq:HMSY', 'nasdaq:HMTV', 'nasdaq:HMY', 'nasdaq:HNGR', 'nasdaq:HNI', 'nasdaq:HNNA', 'nasdaq:HNP', 'nasdaq:HNRG', 'nasdaq:HNW', 'nasdaq:HOFT', 'nasdaq:HOFV', 'nasdaq:HOG', 'nasdaq:HOL', 'nasdaq:HOLI', 'nasdaq:HOLUU', 'nasdaq:HOLX', 'nasdaq:HOMB', 'nasdaq:HOME', 'nasdaq:HON', 'nasdaq:HONE', 'nasdaq:HOOK', 'nasdaq:HOPE', 'nasdaq:HOTH', 'nasdaq:HOV', 'nasdaq:HOVNP', 'nasdaq:HP', 'nasdaq:HPE', 'nasdaq:HPF', 'nasdaq:HPI', 'nasdaq:HPK', 'nasdaq:HPP', 'nasdaq:HPQ', 'nasdaq:HPR', 'nasdaq:HPS', 'nasdaq:HPX', 'nasdaq:HQH', 'nasdaq:HQI', 'nasdaq:HQL', 'nasdaq:HQY', 'nasdaq:HR', 'nasdaq:HRB', 'nasdaq:HRC', 'nasdaq:HRI', 'nasdaq:HRL', 'nasdaq:HRMY', 'nasdaq:HROW', 'nasdaq:HRTG', 'nasdaq:HRTX', 'nasdaq:HRZN', 'nasdaq:HSAQ', 'nasdaq:HSBC', 'nasdaq:HSC', 'nasdaq:HSDT', 'nasdaq:HSIC', 'nasdaq:HSII', 'nasdaq:HSKA', 'nasdaq:HSON', 'nasdaq:HST', 'nasdaq:HSTM', 'nasdaq:HSTO', 'nasdaq:HSY', 'nasdaq:HT', 'nasdaq:HTA', 'nasdaq:HTBI', 'nasdaq:HTBK', 'nasdaq:HTBX', 'nasdaq:HTD', 'nasdaq:HTFA', 'nasdaq:HTGC', 'nasdaq:HTGM', 'nasdaq:HTH', 'nasdaq:HTHT', 'nasdaq:HTIA', 'nasdaq:HTLD', 'nasdaq:HTLF', 'nasdaq:HTLFP', 'nasdaq:HTOO', 'nasdaq:HTPA', 'nasdaq:HTY', 'nasdaq:HUBB', 'nasdaq:HUBG', 'nasdaq:HUBS', 'nasdaq:HUDI', 'nasdaq:HUGE', 'nasdaq:HUIZ', 'nasdaq:HUM', 'nasdaq:HUN', 'nasdaq:HURC', 'nasdaq:HURN', 'nasdaq:HUSA', 'nasdaq:HUSN', 'nasdaq:HUYA', 'nasdaq:HVBC', 'nasdaq:HVT', 'nasdaq:HVT/A', 'nasdaq:HWBK', 'nasdaq:HWC', 'nasdaq:HWCC', 'nasdaq:HWCPL', 'nasdaq:HWCPZ', 'nasdaq:HWKN', 'nasdaq:HWM', 'nasdaq:HXL', 'nasdaq:HY', 'nasdaq:HYB', 'nasdaq:HYFM', 'nasdaq:HYI', 'nasdaq:HYLN', 'nasdaq:HYMC', 'nasdaq:HYRE', 'nasdaq:HYT', 'nasdaq:HZAC', 'nasdaq:HZN', 'nasdaq:HZNP', 'nasdaq:HZO', 'nasdaq:HZON', 'nasdaq:IAA', 'nasdaq:IAC', 'nasdaq:IACA', 'nasdaq:IAE', 'nasdaq:IAF', 'nasdaq:IAG', 'nasdaq:IART', 'nasdaq:IBA', 'nasdaq:IBCP', 'nasdaq:IBEX', 'nasdaq:IBIO', 'nasdaq:IBKR', 'nasdaq:IBM', 'nasdaq:IBN', 'nasdaq:IBOC', 'nasdaq:IBP', 'nasdaq:IBTX', 'nasdaq:ICAD', 'nasdaq:ICBK', 'nasdaq:ICCC', 'nasdaq:ICCH', 'nasdaq:ICD', 'nasdaq:ICE', 'nasdaq:ICFI', 'nasdaq:ICHR', 'nasdaq:ICL', 'nasdaq:ICLK', 'nasdaq:ICLR', 'nasdaq:ICMB', 'nasdaq:ICON', 'nasdaq:ICPT', 'nasdaq:ICUI', 'nasdaq:ID', 'nasdaq:IDA', 'nasdaq:IDCC', 'nasdaq:IDE', 'nasdaq:IDEX', 'nasdaq:IDN', 'nasdaq:IDRA', 'nasdaq:IDT', 'nasdaq:IDXG', 'nasdaq:IDXX', 'nasdaq:IDYA', 'nasdaq:IEA', 'nasdaq:IEC', 'nasdaq:IEP', 'nasdaq:IESC', 'nasdaq:IEX', 'nasdaq:IFF', 'nasdaq:IFFT', 'nasdaq:IFMK', 'nasdaq:IFN', 'nasdaq:IFRX', 'nasdaq:IFS', 'nasdaq:IGA', 'nasdaq:IGAC', 'nasdaq:IGACU', 'nasdaq:IGC', 'nasdaq:IGD', 'nasdaq:IGI', 'nasdaq:IGIC', 'nasdaq:IGMS', 'nasdaq:IGNYU', 'nasdaq:IGR', 'nasdaq:IGT', 'nasdaq:IH', 'nasdaq:IHC', 'nasdaq:IHD', 'nasdaq:IHG', 'nasdaq:IHIT', 'nasdaq:IHRT', 'nasdaq:IHT', 'nasdaq:IHTA', 'nasdaq:IIAC', 'nasdaq:IID', 'nasdaq:IIF', 'nasdaq:III', 'nasdaq:IIIIU', 'nasdaq:IIIN', 'nasdaq:IIIV', 'nasdaq:IIM', 'nasdaq:IIN', 'nasdaq:IIPR', 'nasdaq:IIVI', 'nasdaq:IIVIP', 'nasdaq:IKNX', 'nasdaq:IKT', 'nasdaq:ILMN', 'nasdaq:ILPT', 'nasdaq:IMAB', 'nasdaq:IMAC', 'nasdaq:IMAX', 'nasdaq:IMBI', 'nasdaq:IMCR', 'nasdaq:IMGN', 'nasdaq:IMH', 'nasdaq:IMKTA', 'nasdaq:IMMP', 'nasdaq:IMMR', 'nasdaq:IMNM', 'nasdaq:IMO', 'nasdaq:IMOS', 'nasdaq:IMPX', 'nasdaq:IMRA', 'nasdaq:IMRN', 'nasdaq:IMTE', 'nasdaq:IMTX', 'nasdaq:IMUX', 'nasdaq:IMV', 'nasdaq:IMVT', 'nasdaq:IMXI', 'nasdaq:INAQ', 'nasdaq:INAQU', 'nasdaq:INBK', 'nasdaq:INBKL', 'nasdaq:INBKZ', 'nasdaq:INBX', 'nasdaq:INCY', 'nasdaq:INDB', 'nasdaq:INDO', 'nasdaq:INDT', 'nasdaq:INFI', 'nasdaq:INFN', 'nasdaq:INFO', 'nasdaq:INFU', 'nasdaq:INFY', 'nasdaq:ING', 'nasdaq:INGN', 'nasdaq:INGR', 'nasdaq:INKAU', 'nasdaq:INM', 'nasdaq:INMB', 'nasdaq:INMD', 'nasdaq:INN', 'nasdaq:INO', 'nasdaq:INOD', 'nasdaq:INOV', 'nasdaq:INPX', 'nasdaq:INS', 'nasdaq:INSE', 'nasdaq:INSG', 'nasdaq:INSI', 'nasdaq:INSM', 'nasdaq:INSP', 'nasdaq:INSW', 'nasdaq:INT', 'nasdaq:INTC', 'nasdaq:INTG', 'nasdaq:INTT', 'nasdaq:INTU', 'nasdaq:INTZ', 'nasdaq:INUV', 'nasdaq:INVA', 'nasdaq:INVE', 'nasdaq:INVH', 'nasdaq:INVO', 'nasdaq:INZY', 'nasdaq:IO', 'nasdaq:IONS', 'nasdaq:IOR', 'nasdaq:IOSP', 'nasdaq:IOVA', 'nasdaq:IP', 'nasdaq:IPA', 'nasdaq:IPAR', 'nasdaq:IPDN', 'nasdaq:IPG', 'nasdaq:IPGP', 'nasdaq:IPHA', 'nasdaq:IPHI', 'nasdaq:IPI', 'nasdaq:IPLDP', 'nasdaq:IPOD', 'nasdaq:IPOE', 'nasdaq:IPOF', 'nasdaq:IPV', 'nasdaq:IPWR', 'nasdaq:IQ', 'nasdaq:IQI', 'nasdaq:IQV', 'nasdaq:IR', 'nasdaq:IRBT', 'nasdaq:IRCP', 'nasdaq:IRDM', 'nasdaq:IRIX', 'nasdaq:IRL', 'nasdaq:IRM', 'nasdaq:IRMD', 'nasdaq:IROQ', 'nasdaq:IRR', 'nasdaq:IRS', 'nasdaq:IRT', 'nasdaq:IRTC', 'nasdaq:IRWD', 'nasdaq:ISBC', 'nasdaq:ISD', 'nasdaq:ISDR', 'nasdaq:ISEE', 'nasdaq:ISIG', 'nasdaq:ISNS', 'nasdaq:ISR', 'nasdaq:ISRG', 'nasdaq:ISSC', 'nasdaq:ISTR', 'nasdaq:ISUN', 'nasdaq:IT', 'nasdaq:ITAC', 'nasdaq:ITACU', 'nasdaq:ITCB', 'nasdaq:ITCI', 'nasdaq:ITGR', 'nasdaq:ITHXU', 'nasdaq:ITI', 'nasdaq:ITIC', 'nasdaq:ITMR', 'nasdaq:ITOS', 'nasdaq:ITP', 'nasdaq:ITQRU', 'nasdaq:ITRG', 'nasdaq:ITRI', 'nasdaq:ITRM', 'nasdaq:ITRN', 'nasdaq:ITT', 'nasdaq:ITUB', 'nasdaq:ITW', 'nasdaq:IVA', 'nasdaq:IVAC', 'nasdaq:IVC', 'nasdaq:IVH', 'nasdaq:IVR', 'nasdaq:IVZ', 'nasdaq:IX', 'nasdaq:IZEA', 'nasdaq:J', 'nasdaq:JACK', 'nasdaq:JAGX', 'nasdaq:JAKK', 'nasdaq:JAMF', 'nasdaq:JAN', 'nasdaq:JAX', 'nasdaq:JAZZ', 'nasdaq:JBGS', 'nasdaq:JBHT', 'nasdaq:JBK', 'nasdaq:JBL', 'nasdaq:JBLU', 'nasdaq:JBSS', 'nasdaq:JBT', 'nasdaq:JCE', 'nasdaq:JCI', 'nasdaq:JCICU', 'nasdaq:JCO', 'nasdaq:JCOM', 'nasdaq:JCS', 'nasdaq:JCTCF', 'nasdaq:JD', 'nasdaq:JDD', 'nasdaq:JE', 'nasdaq:JEF', 'nasdaq:JELD', 'nasdaq:JEMD', 'nasdaq:JEQ', 'nasdaq:JFIN', 'nasdaq:JFR', 'nasdaq:JFU', 'nasdaq:JG', 'nasdaq:JGH', 'nasdaq:JHAA', 'nasdaq:JHB', 'nasdaq:JHG', 'nasdaq:JHI', 'nasdaq:JHS', 'nasdaq:JHX', 'nasdaq:JIH', 'nasdaq:JILL', 'nasdaq:JJSF', 'nasdaq:JKHY', 'nasdaq:JKS', 'nasdaq:JLL', 'nasdaq:JLS', 'nasdaq:JMIA', 'nasdaq:JMM', 'nasdaq:JMP', 'nasdaq:JMPNL', 'nasdaq:JMPNZ', 'nasdaq:JNCE', 'nasdaq:JNJ', 'nasdaq:JNPR', 'nasdaq:JOB', 'nasdaq:JOBS', 'nasdaq:JOE', 'nasdaq:JOF', 'nasdaq:JOFFU', 'nasdaq:JOUT', 'nasdaq:JP', 'nasdaq:JPC', 'nasdaq:JPI', 'nasdaq:JPM', 'nasdaq:JPS', 'nasdaq:JPT', 'nasdaq:JQC', 'nasdaq:JRI', 'nasdaq:JRJC', 'nasdaq:JRO', 'nasdaq:JRS', 'nasdaq:JRSH', 'nasdaq:JRVR', 'nasdaq:JSD', 'nasdaq:JSM', 'nasdaq:JT', 'nasdaq:JTA', 'nasdaq:JTD', 'nasdaq:JUPW', 'nasdaq:JVA', 'nasdaq:JW/A', 'nasdaq:JW/B', 'nasdaq:JWN', 'nasdaq:JWS', 'nasdaq:JYAC', 'nasdaq:JYNT', 'nasdaq:K', 'nasdaq:KAI', 'nasdaq:KAIRU', 'nasdaq:KALA', 'nasdaq:KALU', 'nasdaq:KALV', 'nasdaq:KAMN', 'nasdaq:KAR', 'nasdaq:KB', 'nasdaq:KBAL', 'nasdaq:KBH', 'nasdaq:KBNT', 'nasdaq:KBR', 'nasdaq:KBSF', 'nasdaq:KC', 'nasdaq:KCAPL', 'nasdaq:KDMN', 'nasdaq:KDNY', 'nasdaq:KDP', 'nasdaq:KE', 'nasdaq:KELYA', 'nasdaq:KELYB', 'nasdaq:KEN', 'nasdaq:KEP', 'nasdaq:KEQU', 'nasdaq:KERN', 'nasdaq:KEX', 'nasdaq:KEY', 'nasdaq:KEYS', 'nasdaq:KF', 'nasdaq:KFFB', 'nasdaq:KFRC', 'nasdaq:KFS', 'nasdaq:KFY', 'nasdaq:KGC', 'nasdaq:KHC', 'nasdaq:KIDS', 'nasdaq:KIM', 'nasdaq:KIN', 'nasdaq:KINS', 'nasdaq:KINZ', 'nasdaq:KINZU', 'nasdaq:KIO', 'nasdaq:KIQ', 'nasdaq:KIRK', 'nasdaq:KKR', 'nasdaq:KL', 'nasdaq:KLAC', 'nasdaq:KLAQU', 'nasdaq:KLDO', 'nasdaq:KLIC', 'nasdaq:KLR', 'nasdaq:KLXE', 'nasdaq:KMB', 'nasdaq:KMDA', 'nasdaq:KMF', 'nasdaq:KMI', 'nasdaq:KMPH', 'nasdaq:KMPR', 'nasdaq:KMT', 'nasdaq:KMX', 'nasdaq:KN', 'nasdaq:KNDI', 'nasdaq:KNL', 'nasdaq:KNOP', 'nasdaq:KNSA', 'nasdaq:KNSL', 'nasdaq:KNTE', 'nasdaq:KNX', 'nasdaq:KO', 'nasdaq:KOD', 'nasdaq:KODK', 'nasdaq:KOF', 'nasdaq:KOP', 'nasdaq:KOPN', 'nasdaq:KOR', 'nasdaq:KOS', 'nasdaq:KOSS', 'nasdaq:KPTI', 'nasdaq:KR', 'nasdaq:KRA', 'nasdaq:KRBP', 'nasdaq:KRC', 'nasdaq:KREF', 'nasdaq:KRG', 'nasdaq:KRKR', 'nasdaq:KRMD', 'nasdaq:KRNLU', 'nasdaq:KRNT', 'nasdaq:KRNY', 'nasdaq:KRO', 'nasdaq:KRON', 'nasdaq:KROS', 'nasdaq:KRP', 'nasdaq:KRTX', 'nasdaq:KRUS', 'nasdaq:KRYS', 'nasdaq:KSM', 'nasdaq:KSMT', 'nasdaq:KSMTU', 'nasdaq:KSPN', 'nasdaq:KSS', 'nasdaq:KSU', 'nasdaq:KT', 'nasdaq:KTB', 'nasdaq:KTCC', 'nasdaq:KTF', 'nasdaq:KTH', 'nasdaq:KTN', 'nasdaq:KTOS', 'nasdaq:KTRA', 'nasdaq:KUKE', 'nasdaq:KURA', 'nasdaq:KVHI', 'nasdaq:KW', 'nasdaq:KWR', 'nasdaq:KXIN', 'nasdaq:KYMR', 'nasdaq:KYN', 'nasdaq:KZIA', 'nasdaq:KZR', 'nasdaq:L', 'nasdaq:LABP', 'nasdaq:LAC', 'nasdaq:LACQ', 'nasdaq:LACQU', 'nasdaq:LAD', 'nasdaq:LADR', 'nasdaq:LAIX', 'nasdaq:LAKE', 'nasdaq:LAMR', 'nasdaq:LANC', 'nasdaq:LAND', 'nasdaq:LANDM', 'nasdaq:LANDO', 'nasdaq:LANDP', 'nasdaq:LARK', 'nasdaq:LASR', 'nasdaq:LATN', 'nasdaq:LAUR', 'nasdaq:LAWS', 'nasdaq:LAZ', 'nasdaq:LAZR', 'nasdaq:LAZY', 'nasdaq:LB', 'nasdaq:LBAI', 'nasdaq:LBC', 'nasdaq:LBRDA', 'nasdaq:LBRDK', 'nasdaq:LBRDP', 'nasdaq:LBRT', 'nasdaq:LBTYA', 'nasdaq:LBTYB', 'nasdaq:LBTYK', 'nasdaq:LC', 'nasdaq:LCAP', 'nasdaq:LCAPU', 'nasdaq:LCI', 'nasdaq:LCII', 'nasdaq:LCNB', 'nasdaq:LCTX', 'nasdaq:LCUT', 'nasdaq:LCY', 'nasdaq:LCYAU', 'nasdaq:LDL', 'nasdaq:LDOS', 'nasdaq:LDP', 'nasdaq:LE', 'nasdaq:LEA', 'nasdaq:LEAF', 'nasdaq:LEAP', 'nasdaq:LECO', 'nasdaq:LEDS', 'nasdaq:LEE', 'nasdaq:LEG', 'nasdaq:LEGH', 'nasdaq:LEGN', 'nasdaq:LEGOU', 'nasdaq:LEJU', 'nasdaq:LEN', 'nasdaq:LEO', 'nasdaq:LESL', 'nasdaq:LEU', 'nasdaq:LEVI', 'nasdaq:LEVL', 'nasdaq:LEVLP', 'nasdaq:LEXX', 'nasdaq:LFC', 'nasdaq:LFT', 'nasdaq:LFTR', 'nasdaq:LFTRU', 'nasdaq:LFUS', 'nasdaq:LFVN', 'nasdaq:LGHL', 'nasdaq:LGI', 'nasdaq:LGIH', 'nasdaq:LGL', 'nasdaq:LGND', 'nasdaq:LGVW', 'nasdaq:LH', 'nasdaq:LHCG', 'nasdaq:LHDX', 'nasdaq:LHX', 'nasdaq:LI', 'nasdaq:LIFE', 'nasdaq:LII', 'nasdaq:LILA', 'nasdaq:LILAK', 'nasdaq:LIN', 'nasdaq:LINC', 'nasdaq:LIND', 'nasdaq:LINX', 'nasdaq:LIQT', 'nasdaq:LITB', 'nasdaq:LITE', 'nasdaq:LIVE', 'nasdaq:LIVK', 'nasdaq:LIVKU', 'nasdaq:LIVN', 'nasdaq:LIVX', 'nasdaq:LIXT', 'nasdaq:LIZI', 'nasdaq:LJAQU', 'nasdaq:LJPC', 'nasdaq:LKCO', 'nasdaq:LKFN', 'nasdaq:LKQ', 'nasdaq:LL', 'nasdaq:LLIT', 'nasdaq:LLNW', 'nasdaq:LLY', 'nasdaq:LMACU', 'nasdaq:LMAOU', 'nasdaq:LMAT', 'nasdaq:LMB', 'nasdaq:LMFA', 'nasdaq:LMND', 'nasdaq:LMNL', 'nasdaq:LMNR', 'nasdaq:LMNX', 'nasdaq:LMPX', 'nasdaq:LMRK', 'nasdaq:LMRKN', 'nasdaq:LMRKO', 'nasdaq:LMRKP', 'nasdaq:LMST', 'nasdaq:LMT', 'nasdaq:LNC', 'nasdaq:LNDC', 'nasdaq:LNFA', 'nasdaq:LNG', 'nasdaq:LNN', 'nasdaq:LNSR', 'nasdaq:LNT', 'nasdaq:LNTH', 'nasdaq:LOAC', 'nasdaq:LOACR', 'nasdaq:LOACU', 'nasdaq:LOAN', 'nasdaq:LOB', 'nasdaq:LOCO', 'nasdaq:LODE', 'nasdaq:LOGC', 'nasdaq:LOGI', 'nasdaq:LOKB', 'nasdaq:LOMA', 'nasdaq:LOOP', 'nasdaq:LOPE', 'nasdaq:LORL', 'nasdaq:LOTZ', 'nasdaq:LOV', 'nasdaq:LOVE', 'nasdaq:LOW', 'nasdaq:LPCN', 'nasdaq:LPG', 'nasdaq:LPI', 'nasdaq:LPL', 'nasdaq:LPLA', 'nasdaq:LPRO', 'nasdaq:LPSN', 'nasdaq:LPTH', 'nasdaq:LPTX', 'nasdaq:LPX', 'nasdaq:LQDA', 'nasdaq:LQDT', 'nasdaq:LRCX', 'nasdaq:LRMR', 'nasdaq:LRN', 'nasdaq:LSAQ', 'nasdaq:LSBK', 'nasdaq:LSCC', 'nasdaq:LSEA', 'nasdaq:LSF', 'nasdaq:LSI', 'nasdaq:LSPD', 'nasdaq:LSTR', 'nasdaq:LSXMA', 'nasdaq:LSXMB', 'nasdaq:LSXMK', 'nasdaq:LTBR', 'nasdaq:LTC', 'nasdaq:LTHM', 'nasdaq:LTRN', 'nasdaq:LTRPA', 'nasdaq:LTRPB', 'nasdaq:LTRX', 'nasdaq:LU', 'nasdaq:LUB', 'nasdaq:LULU', 'nasdaq:LUMN', 'nasdaq:LUMO', 'nasdaq:LUNA', 'nasdaq:LUNG', 'nasdaq:LUV', 'nasdaq:LUXA', 'nasdaq:LUXAU', 'nasdaq:LVS', 'nasdaq:LW', 'nasdaq:LWACU', 'nasdaq:LWAY', 'nasdaq:LX', 'nasdaq:LXEH', 'nasdaq:LXFR', 'nasdaq:LXP', 'nasdaq:LXRX', 'nasdaq:LXU', 'nasdaq:LYB', 'nasdaq:LYFT', 'nasdaq:LYG', 'nasdaq:LYL', 'nasdaq:LYRA', 'nasdaq:LYTS', 'nasdaq:LYV', 'nasdaq:LZB', 'nasdaq:M', 'nasdaq:MA', 'nasdaq:MAA', 'nasdaq:MAAC', 'nasdaq:MAACU', 'nasdaq:MAC', 'nasdaq:MACK', 'nasdaq:MACU', 'nasdaq:MACUU', 'nasdaq:MAG', 'nasdaq:MAGS', 'nasdaq:MAIN', 'nasdaq:MAN', 'nasdaq:MANH', 'nasdaq:MANT', 'nasdaq:MANU', 'nasdaq:MAR', 'nasdaq:MARA', 'nasdaq:MARK', 'nasdaq:MARPS', 'nasdaq:MAS', 'nasdaq:MASI', 'nasdaq:MASS', 'nasdaq:MAT', 'nasdaq:MATW', 'nasdaq:MATX', 'nasdaq:MAV', 'nasdaq:MAX', 'nasdaq:MAXN', 'nasdaq:MAXR', 'nasdaq:MAYS', 'nasdaq:MBCN', 'nasdaq:MBI', 'nasdaq:MBII', 'nasdaq:MBIN', 'nasdaq:MBINO', 'nasdaq:MBINP', 'nasdaq:MBIO', 'nasdaq:MBNKP', 'nasdaq:MBOT', 'nasdaq:MBRX', 'nasdaq:MBT', 'nasdaq:MBUU', 'nasdaq:MBWM', 'nasdaq:MC', 'nasdaq:MCA', 'nasdaq:MCAC', 'nasdaq:MCACR', 'nasdaq:MCACU', 'nasdaq:MCADU', 'nasdaq:MCB', 'nasdaq:MCBC', 'nasdaq:MCBS', 'nasdaq:MCD', 'nasdaq:MCF', 'nasdaq:MCFE', 'nasdaq:MCFT', 'nasdaq:MCHP', 'nasdaq:MCHX', 'nasdaq:MCI', 'nasdaq:MCK', 'nasdaq:MCMJ', 'nasdaq:MCN', 'nasdaq:MCO', 'nasdaq:MCR', 'nasdaq:MCRB', 'nasdaq:MCRI', 'nasdaq:MCS', 'nasdaq:MCY', 'nasdaq:MD', 'nasdaq:MDB', 'nasdaq:MDC', 'nasdaq:MDCA', 'nasdaq:MDGS', 'nasdaq:MDIA', 'nasdaq:MDJH', 'nasdaq:MDLA', 'nasdaq:MDLQ', 'nasdaq:MDLX', 'nasdaq:MDLY', 'nasdaq:MDLZ', 'nasdaq:MDNA', 'nasdaq:MDP', 'nasdaq:MDRR', 'nasdaq:MDRRP', 'nasdaq:MDRX', 'nasdaq:MDT', 'nasdaq:MDU', 'nasdaq:MDVL', 'nasdaq:MDWD', 'nasdaq:MDWT', 'nasdaq:MDXG', 'nasdaq:MEC', 'nasdaq:MED', 'nasdaq:MEDP', 'nasdaq:MEDS', 'nasdaq:MEG', 'nasdaq:MEI', 'nasdaq:MEIP', 'nasdaq:MELI', 'nasdaq:MEN', 'nasdaq:MEOH', 'nasdaq:MERC', 'nasdaq:MESA', 'nasdaq:MESO', 'nasdaq:MET', 'nasdaq:METC', 'nasdaq:METX', 'nasdaq:MFA', 'nasdaq:MFC', 'nasdaq:MFD', 'nasdaq:MFGP', 'nasdaq:MFH', 'nasdaq:MFIN', 'nasdaq:MFINL', 'nasdaq:MFL', 'nasdaq:MFM', 'nasdaq:MFNC', 'nasdaq:MFT', 'nasdaq:MFV', 'nasdaq:MG', 'nasdaq:MGA', 'nasdaq:MGEE', 'nasdaq:MGF', 'nasdaq:MGI', 'nasdaq:MGIC', 'nasdaq:MGLN', 'nasdaq:MGM', 'nasdaq:MGNI', 'nasdaq:MGNX', 'nasdaq:MGP', 'nasdaq:MGPI', 'nasdaq:MGR', 'nasdaq:MGRB', 'nasdaq:MGRC', 'nasdaq:MGTA', 'nasdaq:MGTX', 'nasdaq:MGU', 'nasdaq:MGY', 'nasdaq:MGYR', 'nasdaq:MHD', 'nasdaq:MHE', 'nasdaq:MHF', 'nasdaq:MHH', 'nasdaq:MHI', 'nasdaq:MHK', 'nasdaq:MHLA', 'nasdaq:MHLD', 'nasdaq:MHN', 'nasdaq:MHNC', 'nasdaq:MHO', 'nasdaq:MIC', 'nasdaq:MICT', 'nasdaq:MIDD', 'nasdaq:MIE', 'nasdaq:MIK', 'nasdaq:MIME', 'nasdaq:MIN', 'nasdaq:MIND', 'nasdaq:MINDP', 'nasdaq:MIRM', 'nasdaq:MIST', 'nasdaq:MITK', 'nasdaq:MITO', 'nasdaq:MITT', 'nasdaq:MIXT', 'nasdaq:MIY', 'nasdaq:MKC', 'nasdaq:MKD', 'nasdaq:MKGI', 'nasdaq:MKL', 'nasdaq:MKSI', 'nasdaq:MKTX', 'nasdaq:MLAB', 'nasdaq:MLAC', 'nasdaq:MLACU', 'nasdaq:MLCO', 'nasdaq:MLHR', 'nasdaq:MLI', 'nasdaq:MLM', 'nasdaq:MLND', 'nasdaq:MLP', 'nasdaq:MLR', 'nasdaq:MLSS', 'nasdaq:MLVF', 'nasdaq:MMAC', 'nasdaq:MMC', 'nasdaq:MMD', 'nasdaq:MMI', 'nasdaq:MMLP', 'nasdaq:MMM', 'nasdaq:MMP', 'nasdaq:MMS', 'nasdaq:MMSI', 'nasdaq:MMT', 'nasdaq:MMU', 'nasdaq:MMX', 'nasdaq:MMYT', 'nasdaq:MN', 'nasdaq:MNDO', 'nasdaq:MNKD', 'nasdaq:MNOV', 'nasdaq:MNP', 'nasdaq:MNPR', 'nasdaq:MNR', 'nasdaq:MNRL', 'nasdaq:MNRO', 'nasdaq:MNSB', 'nasdaq:MNSBP', 'nasdaq:MNSO', 'nasdaq:MNST', 'nasdaq:MNTK', 'nasdaq:MNTX', 'nasdaq:MO', 'nasdaq:MOD', 'nasdaq:MODN', 'nasdaq:MODV', 'nasdaq:MOFG', 'nasdaq:MOGO', 'nasdaq:MOGU', 'nasdaq:MOH', 'nasdaq:MOHO', 'nasdaq:MOMO', 'nasdaq:MONCU', 'nasdaq:MOR', 'nasdaq:MORF', 'nasdaq:MORN', 'nasdaq:MOS', 'nasdaq:MOSY', 'nasdaq:MOTN', 'nasdaq:MOTNU', 'nasdaq:MOTS', 'nasdaq:MOTV', 'nasdaq:MOV', 'nasdaq:MOXC', 'nasdaq:MP', 'nasdaq:MPA', 'nasdaq:MPAA', 'nasdaq:MPB', 'nasdaq:MPC', 'nasdaq:MPLN', 'nasdaq:MPLX', 'nasdaq:MPV', 'nasdaq:MPW', 'nasdaq:MPWR', 'nasdaq:MPX', 'nasdaq:MQT', 'nasdaq:MQY', 'nasdaq:MRAC', 'nasdaq:MRACU', 'nasdaq:MRAM', 'nasdaq:MRBK', 'nasdaq:MRC', 'nasdaq:MRCC', 'nasdaq:MRCCL', 'nasdaq:MRCY', 'nasdaq:MREO', 'nasdaq:MRIN', 'nasdaq:MRK', 'nasdaq:MRKR', 'nasdaq:MRLN', 'nasdaq:MRM', 'nasdaq:MRNA', 'nasdaq:MRNS', 'nasdaq:MRO', 'nasdaq:MRSN', 'nasdaq:MRTN', 'nasdaq:MRTX', 'nasdaq:MRUS', 'nasdaq:MRVI', 'nasdaq:MRVL', 'nasdaq:MS', 'nasdaq:MSA', 'nasdaq:MSB', 'nasdaq:MSBI', 'nasdaq:MSC', 'nasdaq:MSCI', 'nasdaq:MSD', 'nasdaq:MSEX', 'nasdaq:MSFT', 'nasdaq:MSGE', 'nasdaq:MSGM', 'nasdaq:MSGN', 'nasdaq:MSGS', 'nasdaq:MSI', 'nasdaq:MSM', 'nasdaq:MSN', 'nasdaq:MSON', 'nasdaq:MSP', 'nasdaq:MSTR', 'nasdaq:MSVB', 'nasdaq:MT', 'nasdaq:MTA', 'nasdaq:MTACU', 'nasdaq:MTB', 'nasdaq:MTBC', 'nasdaq:MTBCP', 'nasdaq:MTC', 'nasdaq:MTCH', 'nasdaq:MTCN', 'nasdaq:MTCR', 'nasdaq:MTD', 'nasdaq:MTDR', 'nasdaq:MTEM', 'nasdaq:MTEX', 'nasdaq:MTG', 'nasdaq:MTH', 'nasdaq:MTL', 'nasdaq:MTLS', 'nasdaq:MTN', 'nasdaq:MTNB', 'nasdaq:MTOR', 'nasdaq:MTP', 'nasdaq:MTR', 'nasdaq:MTRN', 'nasdaq:MTRX', 'nasdaq:MTSC', 'nasdaq:MTSI', 'nasdaq:MTSL', 'nasdaq:MTT', 'nasdaq:MTW', 'nasdaq:MTX', 'nasdaq:MTZ', 'nasdaq:MU', 'nasdaq:MUA', 'nasdaq:MUC', 'nasdaq:MUDS', 'nasdaq:MUDSU', 'nasdaq:MUE', 'nasdaq:MUFG', 'nasdaq:MUH', 'nasdaq:MUI', 'nasdaq:MUJ', 'nasdaq:MUR', 'nasdaq:MUS', 'nasdaq:MUSA', 'nasdaq:MUX', 'nasdaq:MVBF', 'nasdaq:MVF', 'nasdaq:MVIS', 'nasdaq:MVO', 'nasdaq:MVT', 'nasdaq:MWA', 'nasdaq:MWK', 'nasdaq:MX', 'nasdaq:MXC', 'nasdaq:MXE', 'nasdaq:MXF', 'nasdaq:MXIM', 'nasdaq:MXL', 'nasdaq:MYC', 'nasdaq:MYD', 'nasdaq:MYE', 'nasdaq:MYF', 'nasdaq:MYFW', 'nasdaq:MYGN', 'nasdaq:MYI', 'nasdaq:MYJ', 'nasdaq:MYN', 'nasdaq:MYO', 'nasdaq:MYOV', 'nasdaq:MYRG', 'nasdaq:MYSZ', 'nasdaq:MYT', 'nasdaq:MYTE', 'nasdaq:MZA', 'nasdaq:NAACU', 'nasdaq:NAC', 'nasdaq:NAD', 'nasdaq:NAII', 'nasdaq:NAK', 'nasdaq:NAKD', 'nasdaq:NAN', 'nasdaq:NAOV', 'nasdaq:NARI', 'nasdaq:NAT', 'nasdaq:NATH', 'nasdaq:NATI', 'nasdaq:NATR', 'nasdaq:NAV', 'nasdaq:NAVB', 'nasdaq:NAVI', 'nasdaq:NAZ', 'nasdaq:NBA', 'nasdaq:NBAC', 'nasdaq:NBACR', 'nasdaq:NBACU', 'nasdaq:NBB', 'nasdaq:NBEV', 'nasdaq:NBH', 'nasdaq:NBHC', 'nasdaq:NBIX', 'nasdaq:NBLX', 'nasdaq:NBN', 'nasdaq:NBO', 'nasdaq:NBR', 'nasdaq:NBRV', 'nasdaq:NBSE', 'nasdaq:NBTB', 'nasdaq:NBTX', 'nasdaq:NBW', 'nasdaq:NBY', 'nasdaq:NC', 'nasdaq:NCA', 'nasdaq:NCB', 'nasdaq:NCBS', 'nasdaq:NCLH', 'nasdaq:NCMI', 'nasdaq:NCNA', 'nasdaq:NCNO', 'nasdaq:NCR', 'nasdaq:NCSM', 'nasdaq:NCTY', 'nasdaq:NCV', 'nasdaq:NCZ', 'nasdaq:NDAQ', 'nasdaq:NDLS', 'nasdaq:NDMO', 'nasdaq:NDP', 'nasdaq:NDRA', 'nasdaq:NDSN', 'nasdaq:NEA', 'nasdaq:NEBC', 'nasdaq:NEBCU', 'nasdaq:NEE', 'nasdaq:NEM', 'nasdaq:NEN', 'nasdaq:NEO', 'nasdaq:NEOG', 'nasdaq:NEON', 'nasdaq:NEOS', 'nasdaq:NEP', 'nasdaq:NEPH', 'nasdaq:NEPT', 'nasdaq:NERV', 'nasdaq:NES', 'nasdaq:NESR', 'nasdaq:NET', 'nasdaq:NETE', 'nasdaq:NEU', 'nasdaq:NEV', 'nasdaq:NEW', 'nasdaq:NEWA', 'nasdaq:NEWR', 'nasdaq:NEWT', 'nasdaq:NEWTI', 'nasdaq:NEWTL', 'nasdaq:NEWTZ', 'nasdaq:NEX', 'nasdaq:NEXA', 'nasdaq:NEXT', 'nasdaq:NFBK', 'nasdaq:NFE', 'nasdaq:NFG', 'nasdaq:NFH', 'nasdaq:NFJ', 'nasdaq:NG', 'nasdaq:NGA', 'nasdaq:NGAC', 'nasdaq:NGACU', 'nasdaq:NGD', 'nasdaq:NGG', 'nasdaq:NGL', 'nasdaq:NGM', 'nasdaq:NGMS', 'nasdaq:NGS', 'nasdaq:NGVC', 'nasdaq:NGVT', 'nasdaq:NH', 'nasdaq:NHA', 'nasdaq:NHC', 'nasdaq:NHF', 'nasdaq:NHI', 'nasdaq:NHIC', 'nasdaq:NHICU', 'nasdaq:NHLD', 'nasdaq:NHS', 'nasdaq:NHTC', 'nasdaq:NI', 'nasdaq:NICE', 'nasdaq:NICK', 'nasdaq:NID', 'nasdaq:NIE', 'nasdaq:NIM', 'nasdaq:NINE', 'nasdaq:NIO', 'nasdaq:NIQ', 'nasdaq:NISN', 'nasdaq:NIU', 'nasdaq:NJR', 'nasdaq:NJV', 'nasdaq:NK', 'nasdaq:NKE', 'nasdaq:NKG', 'nasdaq:NKLA', 'nasdaq:NKSH', 'nasdaq:NKTR', 'nasdaq:NKTX', 'nasdaq:NKX', 'nasdaq:NL', 'nasdaq:NLOK', 'nasdaq:NLS', 'nasdaq:NLSN', 'nasdaq:NLSP', 'nasdaq:NLTX', 'nasdaq:NLY', 'nasdaq:NM', 'nasdaq:NMCI', 'nasdaq:NMCO', 'nasdaq:NMFC', 'nasdaq:NMFCL', 'nasdaq:NMI', 'nasdaq:NMIH', 'nasdaq:NML', 'nasdaq:NMM', 'nasdaq:NMMC', 'nasdaq:NMMCU', 'nasdaq:NMRD', 'nasdaq:NMRK', 'nasdaq:NMS', 'nasdaq:NMT', 'nasdaq:NMTR', 'nasdaq:NMY', 'nasdaq:NMZ', 'nasdaq:NNA', 'nasdaq:NNBR', 'nasdaq:NNDM', 'nasdaq:NNI', 'nasdaq:NNN', 'nasdaq:NNOX', 'nasdaq:NNVC', 'nasdaq:NNY', 'nasdaq:NOA', 'nasdaq:NOAC', 'nasdaq:NOACU', 'nasdaq:NOAH', 'nasdaq:NOC', 'nasdaq:NODK', 'nasdaq:NOG', 'nasdaq:NOK', 'nasdaq:NOM', 'nasdaq:NOMD', 'nasdaq:NOV', 'nasdaq:NOVA', 'nasdaq:NOVN', 'nasdaq:NOVT', 'nasdaq:NOW', 'nasdaq:NP', 'nasdaq:NPA', 'nasdaq:NPAUU', 'nasdaq:NPK', 'nasdaq:NPN', 'nasdaq:NPO', 'nasdaq:NPTN', 'nasdaq:NPV', 'nasdaq:NQP', 'nasdaq:NR', 'nasdaq:NRACU', 'nasdaq:NRBO', 'nasdaq:NRC', 'nasdaq:NREF', 'nasdaq:NRG', 'nasdaq:NRGX', 'nasdaq:NRIM', 'nasdaq:NRIX', 'nasdaq:NRK', 'nasdaq:NRO', 'nasdaq:NRP', 'nasdaq:NRT', 'nasdaq:NRUC', 'nasdaq:NRZ', 'nasdaq:NS', 'nasdaq:NSA', 'nasdaq:NSC', 'nasdaq:NSCO', 'nasdaq:NSEC', 'nasdaq:NSH', 'nasdaq:NSIT', 'nasdaq:NSL', 'nasdaq:NSP', 'nasdaq:NSPR', 'nasdaq:NSS', 'nasdaq:NSSC', 'nasdaq:NSTG', 'nasdaq:NSYS', 'nasdaq:NTAP', 'nasdaq:NTB', 'nasdaq:NTCO', 'nasdaq:NTCT', 'nasdaq:NTEC', 'nasdaq:NTES', 'nasdaq:NTG', 'nasdaq:NTGR', 'nasdaq:NTIC', 'nasdaq:NTIP', 'nasdaq:NTLA', 'nasdaq:NTN', 'nasdaq:NTNX', 'nasdaq:NTP', 'nasdaq:NTR', 'nasdaq:NTRA', 'nasdaq:NTRS', 'nasdaq:NTRSO', 'nasdaq:NTST', 'nasdaq:NTUS', 'nasdaq:NTWK', 'nasdaq:NTZ', 'nasdaq:NUAN', 'nasdaq:NUE', 'nasdaq:NUM', 'nasdaq:NUO', 'nasdaq:NURO', 'nasdaq:NUS', 'nasdaq:NUV', 'nasdaq:NUVA', 'nasdaq:NUW', 'nasdaq:NUZE', 'nasdaq:NVAX', 'nasdaq:NVCN', 'nasdaq:NVCR', 'nasdaq:NVDA', 'nasdaq:NVEC', 'nasdaq:NVEE', 'nasdaq:NVFY', 'nasdaq:NVG', 'nasdaq:NVGS', 'nasdaq:NVIV', 'nasdaq:NVMI', 'nasdaq:NVO', 'nasdaq:NVR', 'nasdaq:NVRO', 'nasdaq:NVS', 'nasdaq:NVST', 'nasdaq:NVT', 'nasdaq:NVTA', 'nasdaq:NWBI', 'nasdaq:NWE', 'nasdaq:NWFL', 'nasdaq:NWG', 'nasdaq:NWHM', 'nasdaq:NWL', 'nasdaq:NWLI', 'nasdaq:NWN', 'nasdaq:NWPX', 'nasdaq:NWS', 'nasdaq:NWSA', 'nasdaq:NX', 'nasdaq:NXC', 'nasdaq:NXE', 'nasdaq:NXGN', 'nasdaq:NXJ', 'nasdaq:NXN', 'nasdaq:NXP', 'nasdaq:NXPI', 'nasdaq:NXQ', 'nasdaq:NXR', 'nasdaq:NXRT', 'nasdaq:NXST', 'nasdaq:NXTC', 'nasdaq:NXTD', 'nasdaq:NYC', 'nasdaq:NYCB', 'nasdaq:NYMT', 'nasdaq:NYMTM', 'nasdaq:NYMTN', 'nasdaq:NYMTO', 'nasdaq:NYMTP', 'nasdaq:NYMX', 'nasdaq:NYT', 'nasdaq:NYV', 'nasdaq:NZF', 'nasdaq:O', 'nasdaq:OACB', 'nasdaq:OAS', 'nasdaq:OBAS', 'nasdaq:OBCI', 'nasdaq:OBLG', 'nasdaq:OBLN', 'nasdaq:OBNK', 'nasdaq:OBSV', 'nasdaq:OC', 'nasdaq:OCA', 'nasdaq:OCAXU', 'nasdaq:OCC', 'nasdaq:OCCI', 'nasdaq:OCCIP', 'nasdaq:OCDX', 'nasdaq:OCFC', 'nasdaq:OCFCP', 'nasdaq:OCFT', 'nasdaq:OCG', 'nasdaq:OCGN', 'nasdaq:OCN', 'nasdaq:OCSI', 'nasdaq:OCSL', 'nasdaq:OCUL', 'nasdaq:OCUP', 'nasdaq:OCX', 'nasdaq:ODC', 'nasdaq:ODFL', 'nasdaq:ODP', 'nasdaq:ODT', 'nasdaq:OEC', 'nasdaq:OEG', 'nasdaq:OEPWU', 'nasdaq:OESX', 'nasdaq:OFC', 'nasdaq:OFED', 'nasdaq:OFG', 'nasdaq:OFIX', 'nasdaq:OFLX', 'nasdaq:OFS', 'nasdaq:OFSSG', 'nasdaq:OFSSI', 'nasdaq:OFSSL', 'nasdaq:OFSSZ', 'nasdaq:OGE', 'nasdaq:OGEN', 'nasdaq:OGI', 'nasdaq:OGS', 'nasdaq:OHI', 'nasdaq:OI', 'nasdaq:OIA', 'nasdaq:OII', 'nasdaq:OIIM', 'nasdaq:OIS', 'nasdaq:OKE', 'nasdaq:OKTA', 'nasdaq:OLB', 'nasdaq:OLED', 'nasdaq:OLLI', 'nasdaq:OLMA', 'nasdaq:OLN', 'nasdaq:OLP', 'nasdaq:OM', 'nasdaq:OMAB', 'nasdaq:OMC', 'nasdaq:OMCL', 'nasdaq:OMEG', 'nasdaq:OMER', 'nasdaq:OMEX', 'nasdaq:OMF', 'nasdaq:OMI', 'nasdaq:OMP', 'nasdaq:ON', 'nasdaq:ONB', 'nasdaq:ONCR', 'nasdaq:ONCS', 'nasdaq:ONCT', 'nasdaq:ONCY', 'nasdaq:ONDS', 'nasdaq:ONE', 'nasdaq:ONEM', 'nasdaq:ONEW', 'nasdaq:ONTF', 'nasdaq:ONTO', 'nasdaq:ONTX', 'nasdaq:ONVO', 'nasdaq:OOMA', 'nasdaq:OPBK', 'nasdaq:OPCH', 'nasdaq:OPEN', 'nasdaq:OPGN', 'nasdaq:OPHC', 'nasdaq:OPI', 'nasdaq:OPINI', 'nasdaq:OPINL', 'nasdaq:OPK', 'nasdaq:OPNT', 'nasdaq:OPOF', 'nasdaq:OPP', 'nasdaq:OPRA', 'nasdaq:OPRT', 'nasdaq:OPRX', 'nasdaq:OPT', 'nasdaq:OPTN', 'nasdaq:OPTT', 'nasdaq:OPY', 'nasdaq:OR', 'nasdaq:ORA', 'nasdaq:ORAN', 'nasdaq:ORBC', 'nasdaq:ORC', 'nasdaq:ORCC', 'nasdaq:ORCL', 'nasdaq:ORGO', 'nasdaq:ORGS', 'nasdaq:ORI', 'nasdaq:ORIC', 'nasdaq:ORLA', 'nasdaq:ORLY', 'nasdaq:ORMP', 'nasdaq:ORN', 'nasdaq:ORPH', 'nasdaq:ORRF', 'nasdaq:ORTX', 'nasdaq:OSBC', 'nasdaq:OSG', 'nasdaq:OSH', 'nasdaq:OSIS', 'nasdaq:OSK', 'nasdaq:OSMT', 'nasdaq:OSN', 'nasdaq:OSPN', 'nasdaq:OSS', 'nasdaq:OSTK', 'nasdaq:OSTRU', 'nasdaq:OSUR', 'nasdaq:OSW', 'nasdaq:OTEL', 'nasdaq:OTEX', 'nasdaq:OTIC', 'nasdaq:OTIS', 'nasdaq:OTLK', 'nasdaq:OTRA', 'nasdaq:OTRAU', 'nasdaq:OTRK', 'nasdaq:OTRKP', 'nasdaq:OTTR', 'nasdaq:OUT', 'nasdaq:OVBC', 'nasdaq:OVID', 'nasdaq:OVLY', 'nasdaq:OVV', 'nasdaq:OXBR', 'nasdaq:OXFD', 'nasdaq:OXLC', 'nasdaq:OXLCM', 'nasdaq:OXLCO', 'nasdaq:OXLCP', 'nasdaq:OXM', 'nasdaq:OXSQ', 'nasdaq:OXSQL', 'nasdaq:OXSQZ', 'nasdaq:OXY', 'nasdaq:OYST', 'nasdaq:OZK', 'nasdaq:OZON', 'nasdaq:PAA', 'nasdaq:PAAS', 'nasdaq:PAC', 'nasdaq:PACB', 'nasdaq:PACE', 'nasdaq:PACK', 'nasdaq:PACW', 'nasdaq:PACXU', 'nasdaq:PAE', 'nasdaq:PAG', 'nasdaq:PAGP', 'nasdaq:PAGS', 'nasdaq:PAHC', 'nasdaq:PAI', 'nasdaq:PAIC', 'nasdaq:PAICU', 'nasdaq:PAM', 'nasdaq:PANA', 'nasdaq:PAND', 'nasdaq:PANL', 'nasdaq:PANW', 'nasdaq:PAQCU', 'nasdaq:PAR', 'nasdaq:PARR', 'nasdaq:PASG', 'nasdaq:PATI', 'nasdaq:PATK', 'nasdaq:PAVM', 'nasdaq:PAX', 'nasdaq:PAYA', 'nasdaq:PAYC', 'nasdaq:PAYS', 'nasdaq:PAYX', 'nasdaq:PB', 'nasdaq:PBA', 'nasdaq:PBB', 'nasdaq:PBC', 'nasdaq:PBCT', 'nasdaq:PBCTP', 'nasdaq:PBF', 'nasdaq:PBFS', 'nasdaq:PBFX', 'nasdaq:PBH', 'nasdaq:PBHC', 'nasdaq:PBI', 'nasdaq:PBIP', 'nasdaq:PBLA', 'nasdaq:PBPB', 'nasdaq:PBR', 'nasdaq:PBT', 'nasdaq:PBTS', 'nasdaq:PBY', 'nasdaq:PBYI', 'nasdaq:PCAR', 'nasdaq:PCB', 'nasdaq:PCF', 'nasdaq:PCG', 'nasdaq:PCGU', 'nasdaq:PCH', 'nasdaq:PCI', 'nasdaq:PCK', 'nasdaq:PCM', 'nasdaq:PCN', 'nasdaq:PCOM', 'nasdaq:PCPC', 'nasdaq:PCQ', 'nasdaq:PCRX', 'nasdaq:PCSA', 'nasdaq:PCSB', 'nasdaq:PCTI', 'nasdaq:PCTY', 'nasdaq:PCVX', 'nasdaq:PCYG', 'nasdaq:PCYO', 'nasdaq:PD', 'nasdaq:PDAC', 'nasdaq:PDCE', 'nasdaq:PDCO', 'nasdaq:PDD', 'nasdaq:PDEX', 'nasdaq:PDFS', 'nasdaq:PDI', 'nasdaq:PDLB', 'nasdaq:PDM', 'nasdaq:PDO', 'nasdaq:PDS', 'nasdaq:PDSB', 'nasdaq:PDT', 'nasdaq:PEAK', 'nasdaq:PEB', 'nasdaq:PEBK', 'nasdaq:PEBO', 'nasdaq:PED', 'nasdaq:PEG', 'nasdaq:PEGA', 'nasdaq:PEI', 'nasdaq:PEN', 'nasdaq:PENN', 'nasdaq:PEO', 'nasdaq:PEP', 'nasdaq:PERI', 'nasdaq:PESI', 'nasdaq:PETQ', 'nasdaq:PETS', 'nasdaq:PETZ', 'nasdaq:PFBC', 'nasdaq:PFBI', 'nasdaq:PFC', 'nasdaq:PFD', 'nasdaq:PFE', 'nasdaq:PFG', 'nasdaq:PFGC', 'nasdaq:PFH', 'nasdaq:PFHD', 'nasdaq:PFIE', 'nasdaq:PFIN', 'nasdaq:PFIS', 'nasdaq:PFL', 'nasdaq:PFLT', 'nasdaq:PFMT', 'nasdaq:PFN', 'nasdaq:PFO', 'nasdaq:PFPT', 'nasdaq:PFS', 'nasdaq:PFSI', 'nasdaq:PFSW', 'nasdaq:PFX', 'nasdaq:PFXNL', 'nasdaq:PG', 'nasdaq:PGC', 'nasdaq:PGEN', 'nasdaq:PGNY', 'nasdaq:PGP', 'nasdaq:PGR', 'nasdaq:PGRE', 'nasdaq:PGTI', 'nasdaq:PGZ', 'nasdaq:PH', 'nasdaq:PHAR', 'nasdaq:PHAS', 'nasdaq:PHAT', 'nasdaq:PHCF', 'nasdaq:PHD', 'nasdaq:PHG', 'nasdaq:PHGE', 'nasdaq:PHIC', 'nasdaq:PHICU', 'nasdaq:PHIO', 'nasdaq:PHK', 'nasdaq:PHM', 'nasdaq:PHR', 'nasdaq:PHT', 'nasdaq:PHUN', 'nasdaq:PHVS', 'nasdaq:PHX', 'nasdaq:PI', 'nasdaq:PIAI', 'nasdaq:PICO', 'nasdaq:PII', 'nasdaq:PIM', 'nasdaq:PINC', 'nasdaq:PINE', 'nasdaq:PING', 'nasdaq:PINS', 'nasdaq:PIPP', 'nasdaq:PIPR', 'nasdaq:PIRS', 'nasdaq:PIXY', 'nasdaq:PJT', 'nasdaq:PK', 'nasdaq:PKBK', 'nasdaq:PKE', 'nasdaq:PKG', 'nasdaq:PKI', 'nasdaq:PKO', 'nasdaq:PKOH', 'nasdaq:PKX', 'nasdaq:PLAB', 'nasdaq:PLAG', 'nasdaq:PLAN', 'nasdaq:PLAY', 'nasdaq:PLBC', 'nasdaq:PLCE', 'nasdaq:PLD', 'nasdaq:PLG', 'nasdaq:PLIN', 'nasdaq:PLL', 'nasdaq:PLM', 'nasdaq:PLMR', 'nasdaq:PLNT', 'nasdaq:PLOW', 'nasdaq:PLPC', 'nasdaq:PLRX', 'nasdaq:PLSE', 'nasdaq:PLT', 'nasdaq:PLTK', 'nasdaq:PLTR', 'nasdaq:PLUG', 'nasdaq:PLUS', 'nasdaq:PLX', 'nasdaq:PLXP', 'nasdaq:PLXS', 'nasdaq:PLYA', 'nasdaq:PLYM', 'nasdaq:PM', 'nasdaq:PMBC', 'nasdaq:PMD', 'nasdaq:PME', 'nasdaq:PMF', 'nasdaq:PML', 'nasdaq:PMM', 'nasdaq:PMO', 'nasdaq:PMT', 'nasdaq:PMVC', 'nasdaq:PMVP', 'nasdaq:PMX', 'nasdaq:PNBK', 'nasdaq:PNC', 'nasdaq:PNF', 'nasdaq:PNFP', 'nasdaq:PNFPP', 'nasdaq:PNI', 'nasdaq:PNM', 'nasdaq:PNNT', 'nasdaq:PNNTG', 'nasdaq:PNR', 'nasdaq:PNRG', 'nasdaq:PNTG', 'nasdaq:PNW', 'nasdaq:POAI', 'nasdaq:PODD', 'nasdaq:POLA', 'nasdaq:POOL', 'nasdaq:POR', 'nasdaq:POSH', 'nasdaq:POST', 'nasdaq:POWI', 'nasdaq:POWL', 'nasdaq:POWRU', 'nasdaq:POWW', 'nasdaq:PPBI', 'nasdaq:PPBT', 'nasdaq:PPC', 'nasdaq:PPD', 'nasdaq:PPG', 'nasdaq:PPGHU', 'nasdaq:PPIH', 'nasdaq:PPL', 'nasdaq:PPR', 'nasdaq:PPSI', 'nasdaq:PPT', 'nasdaq:PPX', 'nasdaq:PQG', 'nasdaq:PRA', 'nasdaq:PRAA', 'nasdaq:PRAH', 'nasdaq:PRAX', 'nasdaq:PRCH', 'nasdaq:PRDO', 'nasdaq:PRFT', 'nasdaq:PRFX', 'nasdaq:PRG', 'nasdaq:PRGO', 'nasdaq:PRGS', 'nasdaq:PRGX', 'nasdaq:PRI', 'nasdaq:PRIM', 'nasdaq:PRK', 'nasdaq:PRLB', 'nasdaq:PRLD', 'nasdaq:PRMW', 'nasdaq:PRO', 'nasdaq:PROF', 'nasdaq:PROG', 'nasdaq:PROS', 'nasdaq:PROV', 'nasdaq:PRPB', 'nasdaq:PRPH', 'nasdaq:PRPL', 'nasdaq:PRPO', 'nasdaq:PRQR', 'nasdaq:PRS', 'nasdaq:PRSP', 'nasdaq:PRSRU', 'nasdaq:PRT', 'nasdaq:PRTA', 'nasdaq:PRTC', 'nasdaq:PRTH', 'nasdaq:PRTK', 'nasdaq:PRTS', 'nasdaq:PRTY', 'nasdaq:PRU', 'nasdaq:PRVB', 'nasdaq:PS', 'nasdaq:PSA', 'nasdaq:PSAC', 'nasdaq:PSACU', 'nasdaq:PSB', 'nasdaq:PSEC', 'nasdaq:PSF', 'nasdaq:PSHG', 'nasdaq:PSMT', 'nasdaq:PSN', 'nasdaq:PSNL', 'nasdaq:PSO', 'nasdaq:PSTG', 'nasdaq:PSTH', 'nasdaq:PSTI', 'nasdaq:PSTL', 'nasdaq:PSTV', 'nasdaq:PSTX', 'nasdaq:PSX', 'nasdaq:PSXP', 'nasdaq:PT', 'nasdaq:PTA', 'nasdaq:PTC', 'nasdaq:PTCT', 'nasdaq:PTE', 'nasdaq:PTEN', 'nasdaq:PTGX', 'nasdaq:PTIC', 'nasdaq:PTICU', 'nasdaq:PTK', 'nasdaq:PTMN', 'nasdaq:PTN', 'nasdaq:PTNR', 'nasdaq:PTON', 'nasdaq:PTPI', 'nasdaq:PTR', 'nasdaq:PTRS', 'nasdaq:PTSI', 'nasdaq:PTVCA', 'nasdaq:PTVCB', 'nasdaq:PTVE', 'nasdaq:PTY', 'nasdaq:PUBM', 'nasdaq:PUK', 'nasdaq:PULM', 'nasdaq:PUMP', 'nasdaq:PUYI', 'nasdaq:PVAC', 'nasdaq:PVBC', 'nasdaq:PVG', 'nasdaq:PVH', 'nasdaq:PVL', 'nasdaq:PW', 'nasdaq:PWFL', 'nasdaq:PWOD', 'nasdaq:PWR', 'nasdaq:PXD', 'nasdaq:PXLW', 'nasdaq:PXS', 'nasdaq:PXSAP', 'nasdaq:PYN', 'nasdaq:PYPD', 'nasdaq:PYPL', 'nasdaq:PYS', 'nasdaq:PYT', 'nasdaq:PZC', 'nasdaq:PZG', 'nasdaq:PZN', 'nasdaq:PZZA', 'nasdaq:QADA', 'nasdaq:QADB', 'nasdaq:QCOM', 'nasdaq:QCRH', 'nasdaq:QD', 'nasdaq:QDEL', 'nasdaq:QELL', 'nasdaq:QELLU', 'nasdaq:QEP', 'nasdaq:QFIN', 'nasdaq:QGEN', 'nasdaq:QH', 'nasdaq:QIWI', 'nasdaq:QK', 'nasdaq:QLGN', 'nasdaq:QLI', 'nasdaq:QLYS', 'nasdaq:QMCO', 'nasdaq:QNST', 'nasdaq:QQQX', 'nasdaq:QRHC', 'nasdaq:QRTEA', 'nasdaq:QRTEB', 'nasdaq:QRTEP', 'nasdaq:QRVO', 'nasdaq:QS', 'nasdaq:QSR', 'nasdaq:QTNT', 'nasdaq:QTRX', 'nasdaq:QTS', 'nasdaq:QTT', 'nasdaq:QTWO', 'nasdaq:QUAD', 'nasdaq:QUIK', 'nasdaq:QUMU', 'nasdaq:QUOT', 'nasdaq:QURE', 'nasdaq:QVCC', 'nasdaq:QVCD', 'nasdaq:R', 'nasdaq:RA', 'nasdaq:RAACU', 'nasdaq:RACA', 'nasdaq:RACE', 'nasdaq:RAD', 'nasdaq:RADA', 'nasdaq:RADI', 'nasdaq:RAIL', 'nasdaq:RAMP', 'nasdaq:RAND', 'nasdaq:RAPT', 'nasdaq:RARE', 'nasdaq:RAVE', 'nasdaq:RAVN', 'nasdaq:RBA', 'nasdaq:RBAC', 'nasdaq:RBB', 'nasdaq:RBBN', 'nasdaq:RBC', 'nasdaq:RBCAA', 'nasdaq:RBCN', 'nasdaq:RBKB', 'nasdaq:RBNC', 'nasdaq:RC', 'nasdaq:RCA', 'nasdaq:RCB', 'nasdaq:RCEL', 'nasdaq:RCG', 'nasdaq:RCHG', 'nasdaq:RCHGU', 'nasdaq:RCI', 'nasdaq:RCII', 'nasdaq:RCKT', 'nasdaq:RCKY', 'nasdaq:RCL', 'nasdaq:RCM', 'nasdaq:RCMT', 'nasdaq:RCON', 'nasdaq:RCP', 'nasdaq:RCS', 'nasdaq:RCUS', 'nasdaq:RDCM', 'nasdaq:RDFN', 'nasdaq:RDHL', 'nasdaq:RDI', 'nasdaq:RDIB', 'nasdaq:RDN', 'nasdaq:RDNT', 'nasdaq:RDS/B', 'nasdaq:RDUS', 'nasdaq:RDVT', 'nasdaq:RDWR', 'nasdaq:RDY', 'nasdaq:RE', 'nasdaq:REAL', 'nasdaq:REDU', 'nasdaq:REED', 'nasdaq:REFR', 'nasdaq:REG', 'nasdaq:REGI', 'nasdaq:REGN', 'nasdaq:REI', 'nasdaq:REKR', 'nasdaq:RELI', 'nasdaq:RELL', 'nasdaq:RELX', 'nasdaq:RENN', 'nasdaq:REPH', 'nasdaq:REPL', 'nasdaq:RES', 'nasdaq:RESN', 'nasdaq:RETA', 'nasdaq:RETO', 'nasdaq:REV', 'nasdaq:REVG', 'nasdaq:REX', 'nasdaq:REXR', 'nasdaq:REYN', 'nasdaq:REZI', 'nasdaq:RF', 'nasdaq:RFI', 'nasdaq:RFIL', 'nasdaq:RFL', 'nasdaq:RFM', 'nasdaq:RFP', 'nasdaq:RGA', 'nasdaq:RGCO', 'nasdaq:RGEN', 'nasdaq:RGLD', 'nasdaq:RGLS', 'nasdaq:RGNX', 'nasdaq:RGP', 'nasdaq:RGR', 'nasdaq:RGS', 'nasdaq:RGT', 'nasdaq:RH', 'nasdaq:RHE', 'nasdaq:RHI', 'nasdaq:RHP', 'nasdaq:RIBT', 'nasdaq:RICE', 'nasdaq:RICK', 'nasdaq:RIDE', 'nasdaq:RIG', 'nasdaq:RIGL', 'nasdaq:RILY', 'nasdaq:RILYG', 'nasdaq:RILYH', 'nasdaq:RILYI', 'nasdaq:RILYL', 'nasdaq:RILYM', 'nasdaq:RILYN', 'nasdaq:RILYO', 'nasdaq:RILYP', 'nasdaq:RILYT', 'nasdaq:RILYZ', 'nasdaq:RIO', 'nasdaq:RIOT', 'nasdaq:RIV', 'nasdaq:RIVE', 'nasdaq:RJF', 'nasdaq:RKDA', 'nasdaq:RKT', 'nasdaq:RL', 'nasdaq:RLAY', 'nasdaq:RLGT', 'nasdaq:RLGY', 'nasdaq:RLH', 'nasdaq:RLI', 'nasdaq:RLJ', 'nasdaq:RLMD', 'nasdaq:RLX', 'nasdaq:RM', 'nasdaq:RMAX', 'nasdaq:RMBI', 'nasdaq:RMBL', 'nasdaq:RMBS', 'nasdaq:RMCF', 'nasdaq:RMD', 'nasdaq:RMED', 'nasdaq:RMGB', 'nasdaq:RMGBU', 'nasdaq:RMGCU', 'nasdaq:RMI', 'nasdaq:RMM', 'nasdaq:RMNI', 'nasdaq:RMO', 'nasdaq:RMR', 'nasdaq:RMRM', 'nasdaq:RMT', 'nasdaq:RMTI', 'nasdaq:RNA', 'nasdaq:RNDB', 'nasdaq:RNET', 'nasdaq:RNG', 'nasdaq:RNGR', 'nasdaq:RNLX', 'nasdaq:RNP', 'nasdaq:RNR', 'nasdaq:RNST', 'nasdaq:RNWK', 'nasdaq:ROAD', 'nasdaq:ROCC', 'nasdaq:ROCCU', 'nasdaq:ROCH', 'nasdaq:ROCHU', 'nasdaq:ROCK', 'nasdaq:ROG', 'nasdaq:ROIC', 'nasdaq:ROK', 'nasdaq:ROKU', 'nasdaq:ROL', 'nasdaq:ROLL', 'nasdaq:ROOT', 'nasdaq:ROP', 'nasdaq:ROST', 'nasdaq:RP', 'nasdaq:RPAI', 'nasdaq:RPAY', 'nasdaq:RPD', 'nasdaq:RPLA', 'nasdaq:RPM', 'nasdaq:RPRX', 'nasdaq:RPT', 'nasdaq:RPTX', 'nasdaq:RQI', 'nasdaq:RRBI', 'nasdaq:RRC', 'nasdaq:RRD', 'nasdaq:RRGB', 'nasdaq:RRR', 'nasdaq:RS', 'nasdaq:RSF', 'nasdaq:RSG', 'nasdaq:RSI', 'nasdaq:RSSS', 'nasdaq:RSVA', 'nasdaq:RSVAU', 'nasdaq:RTLR', 'nasdaq:RTP', 'nasdaq:RTPZ', 'nasdaq:RTX', 'nasdaq:RUBY', 'nasdaq:RUHN', 'nasdaq:RUN', 'nasdaq:RUSHA', 'nasdaq:RUSHB', 'nasdaq:RUTH', 'nasdaq:RVI', 'nasdaq:RVLV', 'nasdaq:RVMD', 'nasdaq:RVNC', 'nasdaq:RVP', 'nasdaq:RVPH', 'nasdaq:RVSB', 'nasdaq:RVT', 'nasdaq:RWLK', 'nasdaq:RWT', 'nasdaq:RXN', 'nasdaq:RXT', 'nasdaq:RY', 'nasdaq:RYAAY', 'nasdaq:RYAM', 'nasdaq:RYB', 'nasdaq:RYI', 'nasdaq:RYN', 'nasdaq:RYTM', 'nasdaq:RZA', 'nasdaq:RZB', 'nasdaq:RZLT', 'nasdaq:SA', 'nasdaq:SABR', 'nasdaq:SABRP', 'nasdaq:SACC', 'nasdaq:SACH', 'nasdaq:SAF', 'nasdaq:SAFE', 'nasdaq:SAFM', 'nasdaq:SAFT', 'nasdaq:SAGE', 'nasdaq:SAH', 'nasdaq:SAIA', 'nasdaq:SAIC', 'nasdaq:SAII', 'nasdaq:SAIIU', 'nasdaq:SAIL', 'nasdaq:SAK', 'nasdaq:SAL', 'nasdaq:SALM', 'nasdaq:SALT', 'nasdaq:SAM', 'nasdaq:SAMG', 'nasdaq:SANA', 'nasdaq:SAND          ', 'nasdaq:SANM', 'nasdaq:SANW', 'nasdaq:SAP', 'nasdaq:SAR', 'nasdaq:SASR', 'nasdaq:SATS', 'nasdaq:SAVA', 'nasdaq:SAVE', 'nasdaq:SB', 'nasdaq:SBAC', 'nasdaq:SBBA', 'nasdaq:SBBP', 'nasdaq:SBCF', 'nasdaq:SBE', 'nasdaq:SBFG', 'nasdaq:SBG', 'nasdaq:SBGI', 'nasdaq:SBH', 'nasdaq:SBI', 'nasdaq:SBLK', 'nasdaq:SBLKZ', 'nasdaq:SBNY', 'nasdaq:SBNYP', 'nasdaq:SBOW', 'nasdaq:SBR', 'nasdaq:SBRA', 'nasdaq:SBS', 'nasdaq:SBSI', 'nasdaq:SBSW', 'nasdaq:SBT', 'nasdaq:SBTX', 'nasdaq:SBUX', 'nasdaq:SC', 'nasdaq:SCA', 'nasdaq:SCCB', 'nasdaq:SCCC', 'nasdaq:SCCO', 'nasdaq:SCD', 'nasdaq:SCHL', 'nasdaq:SCHN', 'nasdaq:SCHW', 'nasdaq:SCI', 'nasdaq:SCKT', 'nasdaq:SCL', 'nasdaq:SCM', 'nasdaq:SCOAU', 'nasdaq:SCOR', 'nasdaq:SCPE', 'nasdaq:SCPH', 'nasdaq:SCPL', 'nasdaq:SCPS', 'nasdaq:SCS', 'nasdaq:SCSC', 'nasdaq:SCU', 'nasdaq:SCVL', 'nasdaq:SCVX', 'nasdaq:SCWX', 'nasdaq:SCX', 'nasdaq:SCYX', 'nasdaq:SD', 'nasdaq:SDACU', 'nasdaq:SDC', 'nasdaq:SDGR', 'nasdaq:SDHY', 'nasdaq:SDPI', 'nasdaq:SE', 'nasdaq:SEAC', 'nasdaq:SEAH', 'nasdaq:SEAS', 'nasdaq:SEB', 'nasdaq:SEDG', 'nasdaq:SEE', 'nasdaq:SEED', 'nasdaq:SEEL', 'nasdaq:SEER', 'nasdaq:SEIC', 'nasdaq:SELB', 'nasdaq:SELF', 'nasdaq:SEM', 'nasdaq:SENEA', 'nasdaq:SENEB', 'nasdaq:SENS', 'nasdaq:SESN', 'nasdaq:SF', 'nasdaq:SFB', 'nasdaq:SFBC', 'nasdaq:SFBS', 'nasdaq:SFE', 'nasdaq:SFET', 'nasdaq:SFIX', 'nasdaq:SFL', 'nasdaq:SFM', 'nasdaq:SFNC', 'nasdaq:SFST', 'nasdaq:SFT', 'nasdaq:SFTW', 'nasdaq:SFUN', 'nasdaq:SG', 'nasdaq:SGA', 'nasdaq:SGAM', 'nasdaq:SGAMU', 'nasdaq:SGBX', 'nasdaq:SGC', 'nasdaq:SGEN', 'nasdaq:SGH', 'nasdaq:SGLB', 'nasdaq:SGMA', 'nasdaq:SGMO', 'nasdaq:SGMS', 'nasdaq:SGOC', 'nasdaq:SGRP', 'nasdaq:SGRY', 'nasdaq:SGTX', 'nasdaq:SGU', 'nasdaq:SHACU', 'nasdaq:SHAK', 'nasdaq:SHBI', 'nasdaq:SHC', 'nasdaq:SHEN', 'nasdaq:SHG', 'nasdaq:SHI', 'nasdaq:SHIP', 'nasdaq:SHLS', 'nasdaq:SHLX', 'nasdaq:SHO', 'nasdaq:SHOO', 'nasdaq:SHOP', 'nasdaq:SHSP', 'nasdaq:SHW', 'nasdaq:SHYF', 'nasdaq:SI', 'nasdaq:SIBN', 'nasdaq:SIC', 'nasdaq:SID', 'nasdaq:SIEB', 'nasdaq:SIEN', 'nasdaq:SIF', 'nasdaq:SIFY', 'nasdaq:SIG', 'nasdaq:SIGA', 'nasdaq:SIGI', 'nasdaq:SIGIP', 'nasdaq:SII', 'nasdaq:SILC', 'nasdaq:SILK', 'nasdaq:SILV', 'nasdaq:SIM', 'nasdaq:SIMO', 'nasdaq:SINA', 'nasdaq:SINO', 'nasdaq:SINT', 'nasdaq:SIOX', 'nasdaq:SIRI', 'nasdaq:SITC', 'nasdaq:SITE', 'nasdaq:SITM', 'nasdaq:SIVB', 'nasdaq:SIVBP', 'nasdaq:SIX', 'nasdaq:SJ', 'nasdaq:SJI', 'nasdaq:SJIJ', 'nasdaq:SJIU', 'nasdaq:SJM', 'nasdaq:SJR', 'nasdaq:SJT', 'nasdaq:SJW', 'nasdaq:SKLZ', 'nasdaq:SKM', 'nasdaq:SKT', 'nasdaq:SKX', 'nasdaq:SKY', 'nasdaq:SKYW', 'nasdaq:SLAB', 'nasdaq:SLB', 'nasdaq:SLCA', 'nasdaq:SLCRU', 'nasdaq:SLCT', 'nasdaq:SLDB', 'nasdaq:SLF', 'nasdaq:SLG', 'nasdaq:SLGG', 'nasdaq:SLGL', 'nasdaq:SLGN', 'nasdaq:SLM', 'nasdaq:SLMBP', 'nasdaq:SLN', 'nasdaq:SLNO', 'nasdaq:SLP', 'nasdaq:SLQT', 'nasdaq:SLRC', 'nasdaq:SLRX', 'nasdaq:SLS', 'nasdaq:SM', 'nasdaq:SMAR', 'nasdaq:SMBC', 'nasdaq:SMBK', 'nasdaq:SMCI', 'nasdaq:SMED', 'nasdaq:SMFG', 'nasdaq:SMG', 'nasdaq:SMHI', 'nasdaq:SMID', 'nasdaq:SMIT', 'nasdaq:SMLP', 'nasdaq:SMM', 'nasdaq:SMMF', 'nasdaq:SMMT', 'nasdaq:SMP', 'nasdaq:SMPL', 'nasdaq:SMSI', 'nasdaq:SMTC', 'nasdaq:SMTI', 'nasdaq:SMTS', 'nasdaq:SMTX', 'nasdaq:SNA', 'nasdaq:SNAP', 'nasdaq:SNBR', 'nasdaq:SNCA', 'nasdaq:SNCR', 'nasdaq:SND', 'nasdaq:SNDE', 'nasdaq:SNDL', 'nasdaq:SNDR', 'nasdaq:SNDX', 'nasdaq:SNE', 'nasdaq:SNES', 'nasdaq:SNEX', 'nasdaq:SNFCA', 'nasdaq:SNGX', 'nasdaq:SNMP', 'nasdaq:SNN', 'nasdaq:SNOA', 'nasdaq:SNOW', 'nasdaq:SNP', 'nasdaq:SNPR', 'nasdaq:SNPS', 'nasdaq:SNR', 'nasdaq:SNRH', 'nasdaq:SNRHU', 'nasdaq:SNSE', 'nasdaq:SNSS', 'nasdaq:SNV', 'nasdaq:SNX', 'nasdaq:SO', 'nasdaq:SOAC', 'nasdaq:SOGO', 'nasdaq:SOHO', 'nasdaq:SOHOB', 'nasdaq:SOHON', 'nasdaq:SOHOO', 'nasdaq:SOHU', 'nasdaq:SOI', 'nasdaq:SOJB', 'nasdaq:SOJC', 'nasdaq:SOJD', 'nasdaq:SOJE', 'nasdaq:SOL', 'nasdaq:SOLN', 'nasdaq:SOLO', 'nasdaq:SOLY', 'nasdaq:SON', 'nasdaq:SONA', 'nasdaq:SONM', 'nasdaq:SONN', 'nasdaq:SONO', 'nasdaq:SOR', 'nasdaq:SOS', 'nasdaq:SP', 'nasdaq:SPB', 'nasdaq:SPCB', 'nasdaq:SPCE', 'nasdaq:SPE', 'nasdaq:SPFI', 'nasdaq:SPFR', 'nasdaq:SPG', 'nasdaq:SPGI', 'nasdaq:SPH', 'nasdaq:SPI', 'nasdaq:SPKE', 'nasdaq:SPKEP', 'nasdaq:SPLK', 'nasdaq:SPLP', 'nasdaq:SPNE', 'nasdaq:SPNS', 'nasdaq:SPNV', 'nasdaq:SPOK', 'nasdaq:SPOT', 'nasdaq:SPPI', 'nasdaq:SPR', 'nasdaq:SPRB', 'nasdaq:SPRO', 'nasdaq:SPRQ', 'nasdaq:SPRT', 'nasdaq:SPSC', 'nasdaq:SPT', 'nasdaq:SPTN', 'nasdaq:SPWH', 'nasdaq:SPWR', 'nasdaq:SPXC', 'nasdaq:SPXX', 'nasdaq:SQ', 'nasdaq:SQBG', 'nasdaq:SQFT', 'nasdaq:SQM', 'nasdaq:SQNS', 'nasdaq:SQZ', 'nasdaq:SR', 'nasdaq:SRAC', 'nasdaq:SRACU', 'nasdaq:SRAX', 'nasdaq:SRC', 'nasdaq:SRCE', 'nasdaq:SRCL', 'nasdaq:SRDX', 'nasdaq:SRE', 'nasdaq:SREA', 'nasdaq:SREV', 'nasdaq:SRG', 'nasdaq:SRGA', 'nasdaq:SRI', 'nasdaq:SRL', 'nasdaq:SRLP', 'nasdaq:SRNE', 'nasdaq:SRPT', 'nasdaq:SRRA', 'nasdaq:SRRK', 'nasdaq:SRSA', 'nasdaq:SRSAU', 'nasdaq:SRT', 'nasdaq:SRTS', 'nasdaq:SRV', 'nasdaq:SSAAU', 'nasdaq:SSB', 'nasdaq:SSBI', 'nasdaq:SSD', 'nasdaq:SSKN', 'nasdaq:SSL', 'nasdaq:SSNC', 'nasdaq:SSNT', 'nasdaq:SSP', 'nasdaq:SSPK', 'nasdaq:SSPKU', 'nasdaq:SSRM', 'nasdaq:SSSS', 'nasdaq:SSTI', 'nasdaq:SSTK', 'nasdaq:SSY', 'nasdaq:SSYS', 'nasdaq:ST', 'nasdaq:STAA', 'nasdaq:STAF', 'nasdaq:STAG', 'nasdaq:STAR          ', 'nasdaq:STAY', 'nasdaq:STBA', 'nasdaq:STC', 'nasdaq:STCN', 'nasdaq:STE', 'nasdaq:STEP', 'nasdaq:STFC', 'nasdaq:STG', 'nasdaq:STIC', 'nasdaq:STIM', 'nasdaq:STK', 'nasdaq:STKL', 'nasdaq:STKS', 'nasdaq:STL', 'nasdaq:STLA', 'nasdaq:STLD', 'nasdaq:STM', 'nasdaq:STMP', 'nasdaq:STN', 'nasdaq:STND', 'nasdaq:STNE', 'nasdaq:STNG', 'nasdaq:STOK', 'nasdaq:STON', 'nasdaq:STOR', 'nasdaq:STPK', 'nasdaq:STRA', 'nasdaq:STRL', 'nasdaq:STRM', 'nasdaq:STRO', 'nasdaq:STRR', 'nasdaq:STRRP', 'nasdaq:STRS', 'nasdaq:STRT', 'nasdaq:STSA', 'nasdaq:STT', 'nasdaq:STTK', 'nasdaq:STWD', 'nasdaq:STWO', 'nasdaq:STWOU', 'nasdaq:STX', 'nasdaq:STXB', 'nasdaq:STXS', 'nasdaq:STZ', 'nasdaq:STZ/B', 'nasdaq:SU', 'nasdaq:SUI', 'nasdaq:SUM', 'nasdaq:SUMO', 'nasdaq:SUMR', 'nasdaq:SUN', 'nasdaq:SUNS', 'nasdaq:SUNW', 'nasdaq:SUP', 'nasdaq:SUPN', 'nasdaq:SUPV', 'nasdaq:SURF', 'nasdaq:SUZ', 'nasdaq:SV', 'nasdaq:SVAC', 'nasdaq:SVACU', 'nasdaq:SVBI', 'nasdaq:SVC', 'nasdaq:SVFA', 'nasdaq:SVFAU', 'nasdaq:SVM', 'nasdaq:SVMK', 'nasdaq:SVOKU', 'nasdaq:SVRA', 'nasdaq:SVSVU', 'nasdaq:SVT', 'nasdaq:SVVC', 'nasdaq:SWAV', 'nasdaq:SWBI', 'nasdaq:SWCH', 'nasdaq:SWETU', 'nasdaq:SWI', 'nasdaq:SWIR', 'nasdaq:SWK', 'nasdaq:SWKH', 'nasdaq:SWKS', 'nasdaq:SWM', 'nasdaq:SWN', 'nasdaq:SWT', 'nasdaq:SWTX', 'nasdaq:SWX', 'nasdaq:SWZ', 'nasdaq:SXC', 'nasdaq:SXI', 'nasdaq:SXT', 'nasdaq:SXTC', 'nasdaq:SY', 'nasdaq:SYBT', 'nasdaq:SYBX', 'nasdaq:SYF', 'nasdaq:SYK', 'nasdaq:SYKE', 'nasdaq:SYN', 'nasdaq:SYNA', 'nasdaq:SYNC', 'nasdaq:SYNH', 'nasdaq:SYNL', 'nasdaq:SYPR', 'nasdaq:SYRS', 'nasdaq:SYTA', 'nasdaq:SYX', 'nasdaq:SYY', 'nasdaq:SZC', 'nasdaq:T', 'nasdaq:TA', 'nasdaq:TAC', 'nasdaq:TACA', 'nasdaq:TACO', 'nasdaq:TACT', 'nasdaq:TAIT', 'nasdaq:TAK', 'nasdaq:TAL', 'nasdaq:TALO', 'nasdaq:TANH', 'nasdaq:TANNI', 'nasdaq:TANNL', 'nasdaq:TANNZ', 'nasdaq:TAOP', 'nasdaq:TAP', 'nasdaq:TARA', 'nasdaq:TARO', 'nasdaq:TARS', 'nasdaq:TAST', 'nasdaq:TATT', 'nasdaq:TAYD', 'nasdaq:TBA', 'nasdaq:TBB', 'nasdaq:TBBK', 'nasdaq:TBC', 'nasdaq:TBCPU', 'nasdaq:TBI', 'nasdaq:TBIO', 'nasdaq:TBK', 'nasdaq:TBKCP', 'nasdaq:TBLT', 'nasdaq:TBNK', 'nasdaq:TBPH', 'nasdaq:TC', 'nasdaq:TCBI', 'nasdaq:TCBIL', 'nasdaq:TCBIP', 'nasdaq:TCBK', 'nasdaq:TCDA', 'nasdaq:TCF', 'nasdaq:TCFC', 'nasdaq:TCFCP', 'nasdaq:TCI', 'nasdaq:TCMD', 'nasdaq:TCOM', 'nasdaq:TCON', 'nasdaq:TCP', 'nasdaq:TCPC', 'nasdaq:TCRR', 'nasdaq:TCS', 'nasdaq:TCX', 'nasdaq:TD', 'nasdaq:TDA', 'nasdaq:TDAC', 'nasdaq:TDACU', 'nasdaq:TDC', 'nasdaq:TDE', 'nasdaq:TDF', 'nasdaq:TDG', 'nasdaq:TDI', 'nasdaq:TDJ', 'nasdaq:TDOC', 'nasdaq:TDS', 'nasdaq:TDW', 'nasdaq:TDY', 'nasdaq:TEAF', 'nasdaq:TEAM', 'nasdaq:TECH', 'nasdaq:TECK', 'nasdaq:TECTP', 'nasdaq:TEDU', 'nasdaq:TEF', 'nasdaq:TEI', 'nasdaq:TEKK', 'nasdaq:TEKKU', 'nasdaq:TEL', 'nasdaq:TELA', 'nasdaq:TELL', 'nasdaq:TEN', 'nasdaq:TENB', 'nasdaq:TENX', 'nasdaq:TEO', 'nasdaq:TER', 'nasdaq:TERN', 'nasdaq:TESS', 'nasdaq:TEVA', 'nasdaq:TEX', 'nasdaq:TFC', 'nasdaq:TFFP', 'nasdaq:TFII', 'nasdaq:TFSL', 'nasdaq:TFX', 'nasdaq:TG', 'nasdaq:TGA', 'nasdaq:TGB', 'nasdaq:TGC', 'nasdaq:TGH', 'nasdaq:TGI', 'nasdaq:TGLS', 'nasdaq:TGNA', 'nasdaq:TGP', 'nasdaq:TGS', 'nasdaq:TGT', 'nasdaq:TGTX', 'nasdaq:TH', 'nasdaq:THBR', 'nasdaq:THBRU', 'nasdaq:THC', 'nasdaq:THCA', 'nasdaq:THCAU', 'nasdaq:THCB', 'nasdaq:THCBU', 'nasdaq:THFF', 'nasdaq:THG', 'nasdaq:THM', 'nasdaq:THMAU', 'nasdaq:THMO', 'nasdaq:THO', 'nasdaq:THQ', 'nasdaq:THR', 'nasdaq:THRM', 'nasdaq:THRY', 'nasdaq:THS', 'nasdaq:THTX', 'nasdaq:THW', 'nasdaq:TIG', 'nasdaq:TIGO', 'nasdaq:TIGR', 'nasdaq:TILE', 'nasdaq:TIMB', 'nasdaq:TINV', 'nasdaq:TIPT', 'nasdaq:TIRX', 'nasdaq:TISI', 'nasdaq:TITN', 'nasdaq:TIXT', 'nasdaq:TJX', 'nasdaq:TK', 'nasdaq:TKAT', 'nasdaq:TKC', 'nasdaq:TKR', 'nasdaq:TLC', 'nasdaq:TLGT', 'nasdaq:TLK', 'nasdaq:TLMD', 'nasdaq:TLND', 'nasdaq:TLRY', 'nasdaq:TLS', 'nasdaq:TLSA', 'nasdaq:TLYS', 'nasdaq:TM', 'nasdaq:TMBR', 'nasdaq:TMDI', 'nasdaq:TMDX', 'nasdaq:TME', 'nasdaq:TMHC', 'nasdaq:TMKRU', 'nasdaq:TMO', 'nasdaq:TMP', 'nasdaq:TMPM', 'nasdaq:TMPMU', 'nasdaq:TMQ', 'nasdaq:TMST', 'nasdaq:TMTS', 'nasdaq:TMTSU', 'nasdaq:TMUS', 'nasdaq:TMX', 'nasdaq:TNAV', 'nasdaq:TNC', 'nasdaq:TNDM', 'nasdaq:TNET', 'nasdaq:TNK', 'nasdaq:TNP', 'nasdaq:TNXP', 'nasdaq:TOL', 'nasdaq:TOMZ', 'nasdaq:TOPS', 'nasdaq:TOT', 'nasdaq:TOUR', 'nasdaq:TOWN', 'nasdaq:TPB', 'nasdaq:TPC', 'nasdaq:TPCO', 'nasdaq:TPGY', 'nasdaq:TPH', 'nasdaq:TPHS', 'nasdaq:TPIC', 'nasdaq:TPL', 'nasdaq:TPR', 'nasdaq:TPRE', 'nasdaq:TPTX', 'nasdaq:TPVG', 'nasdaq:TPVY', 'nasdaq:TPX', 'nasdaq:TPZ', 'nasdaq:TR', 'nasdaq:TRC', 'nasdaq:TRCH', 'nasdaq:TREB', 'nasdaq:TREC', 'nasdaq:TREE', 'nasdaq:TREX', 'nasdaq:TRGP', 'nasdaq:TRHC', 'nasdaq:TRI', 'nasdaq:TRIB', 'nasdaq:TRIL', 'nasdaq:TRIN', 'nasdaq:TRIP', 'nasdaq:TRIT', 'nasdaq:TRMB', 'nasdaq:TRMD', 'nasdaq:TRMK', 'nasdaq:TRMT', 'nasdaq:TRN', 'nasdaq:TRNO', 'nasdaq:TRNS', 'nasdaq:TROW', 'nasdaq:TROX', 'nasdaq:TRP', 'nasdaq:TRQ', 'nasdaq:TRS', 'nasdaq:TRST', 'nasdaq:TRT', 'nasdaq:TRTN', 'nasdaq:TRTX', 'nasdaq:TRU', 'nasdaq:TRUE', 'nasdaq:TRUP', 'nasdaq:TRV', 'nasdaq:TRVG', 'nasdaq:TRVI', 'nasdaq:TRVN', 'nasdaq:TRX', 'nasdaq:TRXC', 'nasdaq:TS', 'nasdaq:TSBK', 'nasdaq:TSC', 'nasdaq:TSCAP', 'nasdaq:TSCBP', 'nasdaq:TSCO', 'nasdaq:TSE', 'nasdaq:TSEM', 'nasdaq:TSHA', 'nasdaq:TSI', 'nasdaq:TSIA', 'nasdaq:TSIAU', 'nasdaq:TSLA', 'nasdaq:TSLX', 'nasdaq:TSM', 'nasdaq:TSN', 'nasdaq:TSQ', 'nasdaq:TSRI', 'nasdaq:TT', 'nasdaq:TTC', 'nasdaq:TTCF', 'nasdaq:TTD', 'nasdaq:TTEC', 'nasdaq:TTEK', 'nasdaq:TTGT', 'nasdaq:TTI', 'nasdaq:TTM', 'nasdaq:TTMI', 'nasdaq:TTNP', 'nasdaq:TTOO', 'nasdaq:TTP', 'nasdaq:TTWO', 'nasdaq:TU', 'nasdaq:TUFN', 'nasdaq:TUP', 'nasdaq:TURN', 'nasdaq:TUSK', 'nasdaq:TV', 'nasdaq:TVACU', 'nasdaq:TVC', 'nasdaq:TVE', 'nasdaq:TVTX', 'nasdaq:TVTY', 'nasdaq:TW', 'nasdaq:TWCT', 'nasdaq:TWCTU', 'nasdaq:TWI', 'nasdaq:TWIN', 'nasdaq:TWLO', 'nasdaq:TWN', 'nasdaq:TWND', 'nasdaq:TWNK', 'nasdaq:TWO', 'nasdaq:TWOU', 'nasdaq:TWST', 'nasdaq:TWTR', 'nasdaq:TX', 'nasdaq:TXG', 'nasdaq:TXMD', 'nasdaq:TXN', 'nasdaq:TXRH', 'nasdaq:TXT', 'nasdaq:TY', 'nasdaq:TYG', 'nasdaq:TYHT', 'nasdaq:TYL', 'nasdaq:TYME', 'nasdaq:TZOO', 'nasdaq:TZPSU', 'nasdaq:U', 'nasdaq:UA', 'nasdaq:UAA', 'nasdaq:UAL', 'nasdaq:UAMY', 'nasdaq:UAN', 'nasdaq:UAVS', 'nasdaq:UBA', 'nasdaq:UBCP', 'nasdaq:UBER', 'nasdaq:UBFO', 'nasdaq:UBOH', 'nasdaq:UBP', 'nasdaq:UBS', 'nasdaq:UBSI', 'nasdaq:UBX', 'nasdaq:UCBI', 'nasdaq:UCBIO', 'nasdaq:UCL', 'nasdaq:UCTT', 'nasdaq:UDR', 'nasdaq:UE', 'nasdaq:UEC', 'nasdaq:UEIC', 'nasdaq:UEPS', 'nasdaq:UFAB', 'nasdaq:UFCS', 'nasdaq:UFI', 'nasdaq:UFPI', 'nasdaq:UFPT', 'nasdaq:UFS', 'nasdaq:UG', 'nasdaq:UGI', 'nasdaq:UGP', 'nasdaq:UGRO', 'nasdaq:UHAL', 'nasdaq:UHS', 'nasdaq:UHT', 'nasdaq:UI', 'nasdaq:UIHC', 'nasdaq:UIS', 'nasdaq:UK', 'nasdaq:UL', 'nasdaq:ULBI', 'nasdaq:ULH', 'nasdaq:ULTA', 'nasdaq:UMBF', 'nasdaq:UMC', 'nasdaq:UMH', 'nasdaq:UMPQ', 'nasdaq:UNAM', 'nasdaq:UNB', 'nasdaq:UNF', 'nasdaq:UNFI', 'nasdaq:UNH', 'nasdaq:UNIT', 'nasdaq:UNM', 'nasdaq:UNMA', 'nasdaq:UNP', 'nasdaq:UNTY', 'nasdaq:UNVR', 'nasdaq:UONE', 'nasdaq:UONEK', 'nasdaq:UPLD', 'nasdaq:UPS', 'nasdaq:UPST', 'nasdaq:UPWK', 'nasdaq:URBN', 'nasdaq:URG', 'nasdaq:URGN', 'nasdaq:URI', 'nasdaq:UROV', 'nasdaq:USA', 'nasdaq:USAC', 'nasdaq:USAK', 'nasdaq:USAP', 'nasdaq:USAS', 'nasdaq:USAT', 'nasdaq:USAU', 'nasdaq:USB', 'nasdaq:USCR', 'nasdaq:USDP', 'nasdaq:USEG', 'nasdaq:USFD', 'nasdaq:USIO', 'nasdaq:USLM', 'nasdaq:USM', 'nasdaq:USNA', 'nasdaq:USPH', 'nasdaq:USWS', 'nasdaq:USX', 'nasdaq:UTF', 'nasdaq:UTG', 'nasdaq:UTHR', 'nasdaq:UTI', 'nasdaq:UTL', 'nasdaq:UTMD', 'nasdaq:UTSI', 'nasdaq:UTZ', 'nasdaq:UUU', 'nasdaq:UUUU', 'nasdaq:UVE', 'nasdaq:UVSP', 'nasdaq:UVV', 'nasdaq:UWMC', 'nasdaq:UXIN', 'nasdaq:UZA', 'nasdaq:UZB', 'nasdaq:UZC', 'nasdaq:UZD', 'nasdaq:UZE', 'nasdaq:V', 'nasdaq:VAC', 'nasdaq:VACQ', 'nasdaq:VACQU', 'nasdaq:VALE', 'nasdaq:VALU', 'nasdaq:VAPO', 'nasdaq:VAR', 'nasdaq:VBF', 'nasdaq:VBFC', 'nasdaq:VBIV', 'nasdaq:VBLT', 'nasdaq:VBTX', 'nasdaq:VC', 'nasdaq:VCEL', 'nasdaq:VCF', 'nasdaq:VCIF', 'nasdaq:VCKAU', 'nasdaq:VCNX', 'nasdaq:VCRA', 'nasdaq:VCTR', 'nasdaq:VCV', 'nasdaq:VCVC', 'nasdaq:VCVCU', 'nasdaq:VCYT', 'nasdaq:VEC', 'nasdaq:VECO', 'nasdaq:VEDL', 'nasdaq:VEEV', 'nasdaq:VEL', 'nasdaq:VEON', 'nasdaq:VER', 'nasdaq:VERB', 'nasdaq:VERI', 'nasdaq:VERO', 'nasdaq:VERU', 'nasdaq:VERX', 'nasdaq:VERY', 'nasdaq:VET', 'nasdaq:VFC', 'nasdaq:VFF', 'nasdaq:VFL', 'nasdaq:VG', 'nasdaq:VGAC', 'nasdaq:VGI', 'nasdaq:VGM', 'nasdaq:VGR', 'nasdaq:VGZ', 'nasdaq:VHAQ', 'nasdaq:VHC', 'nasdaq:VHI', 'nasdaq:VIAC', 'nasdaq:VIACA', 'nasdaq:VIAO', 'nasdaq:VIAV', 'nasdaq:VICI', 'nasdaq:VICR', 'nasdaq:VIE', 'nasdaq:VIH', 'nasdaq:VIHAU', 'nasdaq:VIIAU', 'nasdaq:VINC', 'nasdaq:VINCU', 'nasdaq:VINP', 'nasdaq:VIOT', 'nasdaq:VIPS', 'nasdaq:VIR', 'nasdaq:VIRC', 'nasdaq:VIRI', 'nasdaq:VIRT', 'nasdaq:VISL', 'nasdaq:VIST', 'nasdaq:VITL', 'nasdaq:VIV', 'nasdaq:VIVE', 'nasdaq:VIVO', 'nasdaq:VJET', 'nasdaq:VKI', 'nasdaq:VKQ', 'nasdaq:VKTX', 'nasdaq:VLDR', 'nasdaq:VLGEA', 'nasdaq:VLO', 'nasdaq:VLRS', 'nasdaq:VLT', 'nasdaq:VLY', 'nasdaq:VLYPO', 'nasdaq:VLYPP', 'nasdaq:VMAC', 'nasdaq:VMACU', 'nasdaq:VMAR', 'nasdaq:VMC', 'nasdaq:VMD', 'nasdaq:VMI', 'nasdaq:VMM', 'nasdaq:VMO', 'nasdaq:VMW', 'nasdaq:VNCE', 'nasdaq:VNDA', 'nasdaq:VNE', 'nasdaq:VNET', 'nasdaq:VNO', 'nasdaq:VNOM', 'nasdaq:VNRX', 'nasdaq:VNT', 'nasdaq:VNTR', 'nasdaq:VOC', 'nasdaq:VOD', 'nasdaq:VOLT', 'nasdaq:VOR', 'nasdaq:VOSOU', 'nasdaq:VOXX', 'nasdaq:VOYA', 'nasdaq:VPG', 'nasdaq:VPV', 'nasdaq:VRA', 'nasdaq:VRAY', 'nasdaq:VRCA', 'nasdaq:VRDN', 'nasdaq:VREX', 'nasdaq:VRM', 'nasdaq:VRME', 'nasdaq:VRNA', 'nasdaq:VRNS', 'nasdaq:VRNT', 'nasdaq:VRRM', 'nasdaq:VRS', 'nasdaq:VRSK', 'nasdaq:VRSN', 'nasdaq:VRT', 'nasdaq:VRTS', 'nasdaq:VRTU', 'nasdaq:VRTV', 'nasdaq:VRTX', 'nasdaq:VS', 'nasdaq:VSAT', 'nasdaq:VSEC', 'nasdaq:VSH', 'nasdaq:VSPR', 'nasdaq:VSPRU', 'nasdaq:VST', 'nasdaq:VSTA', 'nasdaq:VSTM', 'nasdaq:VSTO', 'nasdaq:VTA', 'nasdaq:VTAQ', 'nasdaq:VTAQR', 'nasdaq:VTAQU', 'nasdaq:VTGN', 'nasdaq:VTIQU', 'nasdaq:VTN', 'nasdaq:VTNR', 'nasdaq:VTOL', 'nasdaq:VTR', 'nasdaq:VTRS', 'nasdaq:VTRU', 'nasdaq:VTSI', 'nasdaq:VTVT', 'nasdaq:VUZI', 'nasdaq:VVI', 'nasdaq:VVNT', 'nasdaq:VVOS', 'nasdaq:VVPR', 'nasdaq:VVR', 'nasdaq:VVV', 'nasdaq:VXRT', 'nasdaq:VYGG', 'nasdaq:VYGR', 'nasdaq:VYNE', 'nasdaq:VZ', 'nasdaq:W', 'nasdaq:WAB', 'nasdaq:WABC', 'nasdaq:WAFD', 'nasdaq:WAFU', 'nasdaq:WAL', 'nasdaq:WALA', 'nasdaq:WASH', 'nasdaq:WAT', 'nasdaq:WATT', 'nasdaq:WB', 'nasdaq:WBA', 'nasdaq:WBAI', 'nasdaq:WBK', 'nasdaq:WBS', 'nasdaq:WBT', 'nasdaq:WCC', 'nasdaq:WCN', 'nasdaq:WD', 'nasdaq:WDAY', 'nasdaq:WDC', 'nasdaq:WDFC', 'nasdaq:WDR', 'nasdaq:WEA', 'nasdaq:WEC', 'nasdaq:WEI', 'nasdaq:WELL', 'nasdaq:WEN', 'nasdaq:WERN', 'nasdaq:WES', 'nasdaq:WETF', 'nasdaq:WEX', 'nasdaq:WEYS', 'nasdaq:WF', 'nasdaq:WFC', 'nasdaq:WFG', 'nasdaq:WGO', 'nasdaq:WH', 'nasdaq:WHD', 'nasdaq:WHF', 'nasdaq:WHFBZ', 'nasdaq:WHG', 'nasdaq:WHLM', 'nasdaq:WHLR', 'nasdaq:WHLRD', 'nasdaq:WHLRP', 'nasdaq:WHR', 'nasdaq:WIA', 'nasdaq:WIFI', 'nasdaq:WILC', 'nasdaq:WIMI', 'nasdaq:WINA', 'nasdaq:WING', 'nasdaq:WINT', 'nasdaq:WIRE', 'nasdaq:WISA', 'nasdaq:WISH', 'nasdaq:WIT', 'nasdaq:WIW', 'nasdaq:WIX', 'nasdaq:WK', 'nasdaq:WKEY', 'nasdaq:WKHS', 'nasdaq:WLDN', 'nasdaq:WLFC', 'nasdaq:WLK', 'nasdaq:WLKP', 'nasdaq:WLL', 'nasdaq:WLTW', 'nasdaq:WM', 'nasdaq:WMB', 'nasdaq:WMC', 'nasdaq:WMG', 'nasdaq:WMK', 'nasdaq:WMS', 'nasdaq:WMT', 'nasdaq:WNC', 'nasdaq:WNEB', 'nasdaq:WNW', 'nasdaq:WOOF', 'nasdaq:WOR', 'nasdaq:WORK', 'nasdaq:WORX', 'nasdaq:WOW', 'nasdaq:WPC', 'nasdaq:WPF', 'nasdaq:WPG', 'nasdaq:WPM', 'nasdaq:WPP', 'nasdaq:WPRT', 'nasdaq:WRAP', 'nasdaq:WRB', 'nasdaq:WRE', 'nasdaq:WRI', 'nasdaq:WRK', 'nasdaq:WRLD', 'nasdaq:WRN', 'nasdaq:WSBC', 'nasdaq:WSBCP', 'nasdaq:WSBF', 'nasdaq:WSC', 'nasdaq:WSFS', 'nasdaq:WSM', 'nasdaq:WSO', 'nasdaq:WSO/B', 'nasdaq:WSR', 'nasdaq:WST', 'nasdaq:WSTG', 'nasdaq:WTBA', 'nasdaq:WTER', 'nasdaq:WTFC', 'nasdaq:WTFCM', 'nasdaq:WTFCP', 'nasdaq:WTI', 'nasdaq:WTM', 'nasdaq:WTRE', 'nasdaq:WTREP', 'nasdaq:WTRG', 'nasdaq:WTRH', 'nasdaq:WTRU', 'nasdaq:WTS', 'nasdaq:WTT', 'nasdaq:WTTR', 'nasdaq:WU', 'nasdaq:WVE', 'nasdaq:WVFC', 'nasdaq:WVVI', 'nasdaq:WVVIP', 'nasdaq:WW', 'nasdaq:WWD', 'nasdaq:WWE', 'nasdaq:WWR', 'nasdaq:WWW', 'nasdaq:WY', 'nasdaq:WYND', 'nasdaq:WYNN', 'nasdaq:WYY', 'nasdaq:X', 'nasdaq:XAIR', 'nasdaq:XAN', 'nasdaq:XBIO', 'nasdaq:XBIT', 'nasdaq:XCUR', 'nasdaq:XEC', 'nasdaq:XEL', 'nasdaq:XELA', 'nasdaq:XELB', 'nasdaq:XENE', 'nasdaq:XENT', 'nasdaq:XERS', 'nasdaq:XFLT', 'nasdaq:XFOR', 'nasdaq:XGN', 'nasdaq:XHR', 'nasdaq:XIN', 'nasdaq:XL', 'nasdaq:XLNX', 'nasdaq:XLRN', 'nasdaq:XM', 'nasdaq:XNCR', 'nasdaq:XNET', 'nasdaq:XOG', 'nasdaq:XOM', 'nasdaq:XOMA', 'nasdaq:XOMAP', 'nasdaq:XONE', 'nasdaq:XP', 'nasdaq:XPEL', 'nasdaq:XPER', 'nasdaq:XPEV', 'nasdaq:XPL', 'nasdaq:XPO', 'nasdaq:XPOA', 'nasdaq:XRAY', 'nasdaq:XRX', 'nasdaq:XSPA', 'nasdaq:XTLB', 'nasdaq:XTNT', 'nasdaq:XXII', 'nasdaq:XYF', 'nasdaq:XYL', 'nasdaq:Y', 'nasdaq:YAC', 'nasdaq:YALA', 'nasdaq:YCBD', 'nasdaq:YELP', 'nasdaq:YETI', 'nasdaq:YEXT', 'nasdaq:YGMZ', 'nasdaq:YI', 'nasdaq:YJ', 'nasdaq:YMAB', 'nasdaq:YMTX', 'nasdaq:YNDX', 'nasdaq:YORW', 'nasdaq:YPF', 'nasdaq:YQ', 'nasdaq:YRCW', 'nasdaq:YRD', 'nasdaq:YSAC', 'nasdaq:YSACU', 'nasdaq:YSG', 'nasdaq:YTEN', 'nasdaq:YTRA', 'nasdaq:YUM', 'nasdaq:YUMC', 'nasdaq:YVR', 'nasdaq:YY', 'nasdaq:Z', 'nasdaq:ZAGG', 'nasdaq:ZBH', 'nasdaq:ZBRA', 'nasdaq:ZCMD', 'nasdaq:ZDGE', 'nasdaq:ZEAL', 'nasdaq:ZEN', 'nasdaq:ZEUS', 'nasdaq:ZG', 'nasdaq:ZGNX', 'nasdaq:ZGYH', 'nasdaq:ZGYHR', 'nasdaq:ZGYHU', 'nasdaq:ZI', 'nasdaq:ZIM', 'nasdaq:ZION', 'nasdaq:ZIONL', 'nasdaq:ZIONN', 'nasdaq:ZIONO', 'nasdaq:ZIONP', 'nasdaq:ZIOP', 'nasdaq:ZIXI', 'nasdaq:ZKIN', 'nasdaq:ZLAB', 'nasdaq:ZM', 'nasdaq:ZNGA', 'nasdaq:ZNH', 'nasdaq:ZNTE', 'nasdaq:ZNTEU', 'nasdaq:ZNTL', 'nasdaq:ZOM', 'nasdaq:ZS', 'nasdaq:ZSAN', 'nasdaq:ZTO', 'nasdaq:ZTR', 'nasdaq:ZTS', 'nasdaq:ZUMZ', 'nasdaq:ZUO', 'nasdaq:ZVO', 'nasdaq:ZWRKU', 'nasdaq:ZYME', 'nasdaq:ZYNE', 'nasdaq:ZYXI', ]

# %%
# tickers = [ 'nyse:A', 'nyse:AA', 'nyse:AAIC', 'nyse:AAN', 'nyse:AAP', 'nyse:AAT', 'nyse:AB', 'nyse:ABB', 'nyse:ABBV', 'nyse:ABC', 'nyse:ABEV', 'nyse:ABG', 'nyse:ABM', 'nyse:ABR', 'nyse:ABT', 'nyse:AC', 'nyse:ACA', 'nyse:ACB', 'nyse:ACC', 'nyse:ACCO', 'nyse:ACEL', 'nyse:ACH', 'nyse:ACI', 'nyse:ACIC', 'nyse:ACM', 'nyse:ACN', 'nyse:ACND', 'nyse:ACP', 'nyse:ACRE', 'nyse:ACV', 'nyse:ADC', 'nyse:ADCT', 'nyse:ADM', 'nyse:ADNT', 'nyse:ADS', 'nyse:ADT', 'nyse:ADX', 'nyse:AEB', 'nyse:AEE', 'nyse:AEFC', 'nyse:AEG', 'nyse:AEL', 'nyse:AEM', 'nyse:AENZ', 'nyse:AEO', 'nyse:AER', 'nyse:AES', 'nyse:AFB', 'nyse:AFC', 'nyse:AFG', 'nyse:AFGB', 'nyse:AFGC', 'nyse:AFGD', 'nyse:AFGE', 'nyse:AFI', 'nyse:AFL', 'nyse:AFT', 'nyse:AG', 'nyse:AGCB', 'nyse:AGCO', 'nyse:AGD', 'nyse:AGI', 'nyse:AGM', 'nyse:AGO', 'nyse:AGR', 'nyse:AGRO', 'nyse:AGS', 'nyse:AGX', 'nyse:AHC', 'nyse:AHH', 'nyse:AHT', 'nyse:AI', 'nyse:AIC', 'nyse:AIF', 'nyse:AIG', 'nyse:AIN', 'nyse:AIO', 'nyse:AIR', 'nyse:AIRC', 'nyse:AIT', 'nyse:AIV', 'nyse:AIW', 'nyse:AIZ', 'nyse:AIZN', 'nyse:AIZP', 'nyse:AJAX', 'nyse:AJG', 'nyse:AJRD', 'nyse:AJX', 'nyse:AJXA', 'nyse:AKO/A', 'nyse:AKO/B', 'nyse:AKR', 'nyse:AL', 'nyse:ALB', 'nyse:ALC', 'nyse:ALE', 'nyse:ALEX', 'nyse:ALG', 'nyse:ALK', 'nyse:ALL', 'nyse:ALLE', 'nyse:ALLY', 'nyse:ALSN', 'nyse:ALTG', 'nyse:ALUS', 'nyse:ALV', 'nyse:ALX', 'nyse:AM', 'nyse:AMBC', 'nyse:AMC', 'nyse:AMCR', 'nyse:AME', 'nyse:AMG', 'nyse:AMH', 'nyse:AMK', 'nyse:AMN', 'nyse:AMOV', 'nyse:AMP', 'nyse:AMPY', 'nyse:AMR', 'nyse:AMRC', 'nyse:AMRX', 'nyse:AMT', 'nyse:AMWL', 'nyse:AMX', 'nyse:AN', 'nyse:ANET', 'nyse:ANF', 'nyse:ANH', 'nyse:ANTM', 'nyse:AOD', 'nyse:AON', 'nyse:AONE', 'nyse:AOS', 'nyse:AP', 'nyse:APAM', 'nyse:APD', 'nyse:APG', 'nyse:APH', 'nyse:APLE', 'nyse:APO', 'nyse:APRN', 'nyse:APSG', 'nyse:APTS', 'nyse:APTV', 'nyse:AQN', 'nyse:AQNA', 'nyse:AQNB', 'nyse:AQUA', 'nyse:AR', 'nyse:ARC', 'nyse:ARCH', 'nyse:ARCO', 'nyse:ARD', 'nyse:ARDC', 'nyse:ARE', 'nyse:ARES', 'nyse:ARGD', 'nyse:ARGO', 'nyse:ARI', 'nyse:ARL', 'nyse:ARLO', 'nyse:ARMK', 'nyse:ARNC', 'nyse:AROC', 'nyse:ARR', 'nyse:ARW', 'nyse:ASA', 'nyse:ASAN', 'nyse:ASAQ', 'nyse:ASB', 'nyse:ASC', 'nyse:ASG', 'nyse:ASGI', 'nyse:ASGN', 'nyse:ASH', 'nyse:ASIX', 'nyse:ASPL', 'nyse:ASPN', 'nyse:ASR', 'nyse:ASX', 'nyse:AT', 'nyse:ATA', 'nyse:ATAC', 'nyse:ATC', 'nyse:ATCO', 'nyse:ATEN', 'nyse:ATGE', 'nyse:ATH', 'nyse:ATHM', 'nyse:ATI', 'nyse:ATKR', 'nyse:ATO', 'nyse:ATR', 'nyse:ATTO', 'nyse:ATUS', 'nyse:AU', 'nyse:AUY', 'nyse:AVA', 'nyse:AVAL', 'nyse:AVAN', 'nyse:AVB', 'nyse:AVD', 'nyse:AVK', 'nyse:AVLR', 'nyse:AVNS', 'nyse:AVNT', 'nyse:AVTR', 'nyse:AVY', 'nyse:AVYA', 'nyse:AWF', 'nyse:AWI', 'nyse:AWK', 'nyse:AWP', 'nyse:AWR', 'nyse:AX', 'nyse:AXL', 'nyse:AXO', 'nyse:AXP', 'nyse:AXR', 'nyse:AXS', 'nyse:AXTA', 'nyse:AYI', 'nyse:AYX', 'nyse:AZEK', 'nyse:AZO', 'nyse:AZRE', 'nyse:AZUL', 'nyse:AZZ', 'nyse:B', 'nyse:BA', 'nyse:BABA', 'nyse:BAC', 'nyse:BAF', 'nyse:BAH', 'nyse:BAK', 'nyse:BALY', 'nyse:BAM', 'nyse:BAMH', 'nyse:BAMI', 'nyse:BANC', 'nyse:BAP', 'nyse:BAX', 'nyse:BB', 'nyse:BBAR', 'nyse:BBD', 'nyse:BBDC', 'nyse:BBDO', 'nyse:BBF', 'nyse:BBK', 'nyse:BBL', 'nyse:BBN', 'nyse:BBU', 'nyse:BBVA', 'nyse:BBW', 'nyse:BBY', 'nyse:BC', 'nyse:BCAT', 'nyse:BCC', 'nyse:BCE', 'nyse:BCEI', 'nyse:BCH', 'nyse:BCO', 'nyse:BCS', 'nyse:BCSF', 'nyse:BCX', 'nyse:BDC', 'nyse:BDJ', 'nyse:BDN', 'nyse:BDX', 'nyse:BDXB', 'nyse:BE', 'nyse:BEDU', 'nyse:BEKE', 'nyse:BEN', 'nyse:BEP', 'nyse:BEPC', 'nyse:BERY', 'nyse:BEST', 'nyse:BF/A', 'nyse:BF/B', 'nyse:BFAM', 'nyse:BFK', 'nyse:BFS', 'nyse:BFT', 'nyse:BFY', 'nyse:BFZ', 'nyse:BG', 'nyse:BGB', 'nyse:BGH', 'nyse:BGIO', 'nyse:BGR', 'nyse:BGS', 'nyse:BGSF', 'nyse:BGT', 'nyse:BGX', 'nyse:BGY', 'nyse:BH', 'nyse:BHC', 'nyse:BHE', 'nyse:BHK', 'nyse:BHLB', 'nyse:BHP', 'nyse:BHR', 'nyse:BHV', 'nyse:BHVN', 'nyse:BIF', 'nyse:BIG', 'nyse:BILL', 'nyse:BIO', 'nyse:BIO/B', 'nyse:BIP', 'nyse:BIPC', 'nyse:BIT', 'nyse:BJ', 'nyse:BK', 'nyse:BKD', 'nyse:BKE', 'nyse:BKH', 'nyse:BKI', 'nyse:BKN', 'nyse:BKR', 'nyse:BKT', 'nyse:BKU', 'nyse:BLD', 'nyse:BLE', 'nyse:BLK', 'nyse:BLL', 'nyse:BLW', 'nyse:BLX', 'nyse:BMA', 'nyse:BME', 'nyse:BMEZ', 'nyse:BMI', 'nyse:BMO', 'nyse:BMY', 'nyse:BNED', 'nyse:BNL', 'nyse:BNS', 'nyse:BNY', 'nyse:BOAC', 'nyse:BOE', 'nyse:BOH', 'nyse:BOOT', 'nyse:BORR', 'nyse:BOX', 'nyse:BP', 'nyse:BPMP', 'nyse:BPT', 'nyse:BQ', 'nyse:BR', 'nyse:BRBR', 'nyse:BRC', 'nyse:BRFS', 'nyse:BRK/A', 'nyse:BRK/B', 'nyse:BRMK', 'nyse:BRO', 'nyse:BRT', 'nyse:BRX', 'nyse:BSA', 'nyse:BSAC', 'nyse:BSBR', 'nyse:BSD', 'nyse:BSE', 'nyse:BSIG', 'nyse:BSL', 'nyse:BSM', 'nyse:BSMX', 'nyse:BSN', 'nyse:BST', 'nyse:BSTZ', 'nyse:BSX', 'nyse:BTA', 'nyse:BTI', 'nyse:BTO', 'nyse:BTT', 'nyse:BTU', 'nyse:BTZ', 'nyse:BUD', 'nyse:BUI', 'nyse:BUR', 'nyse:BURL', 'nyse:BV', 'nyse:BVH', 'nyse:BVN', 'nyse:BW', 'nyse:BWA', 'nyse:BWG', 'nyse:BWXT', 'nyse:BX', 'nyse:BXC', 'nyse:BXG', 'nyse:BXMT', 'nyse:BXMX', 'nyse:BXP', 'nyse:BXS', 'nyse:BY', 'nyse:BYD', 'nyse:BYM', 'nyse:BZH', 'nyse:BZM', 'nyse:C', 'nyse:CAAP', 'nyse:CABO', 'nyse:CACI', 'nyse:CADE', 'nyse:CAE', 'nyse:CAF', 'nyse:CAG', 'nyse:CAH', 'nyse:CAI', 'nyse:CAJ', 'nyse:CAL', 'nyse:CALX', 'nyse:CANG', 'nyse:CAP', 'nyse:CAPL', 'nyse:CARR', 'nyse:CARS', 'nyse:CAS', 'nyse:CAT', 'nyse:CATO', 'nyse:CB', 'nyse:CBAH', 'nyse:CBB', 'nyse:CBD', 'nyse:CBH', 'nyse:CBRE', 'nyse:CBT', 'nyse:CBU', 'nyse:CBZ', 'nyse:CC', 'nyse:CCAC', 'nyse:CCEP', 'nyse:CCI', 'nyse:CCIV', 'nyse:CCJ', 'nyse:CCK', 'nyse:CCL', 'nyse:CCM', 'nyse:CCO', 'nyse:CCS', 'nyse:CCU', 'nyse:CCV', 'nyse:CCX', 'nyse:CCZ', 'nyse:CDAY', 'nyse:CDE', 'nyse:CDR', 'nyse:CE', 'nyse:CEA', 'nyse:CEE', 'nyse:CEIX', 'nyse:CEL', 'nyse:CELP', 'nyse:CEM', 'nyse:CEN', 'nyse:CEO', 'nyse:CEPU', 'nyse:CEQP', 'nyse:CF', 'nyse:CFG', 'nyse:CFR', 'nyse:CFX', 'nyse:CFXA', 'nyse:CGA', 'nyse:CHCT', 'nyse:CHD', 'nyse:CHE', 'nyse:CHGG', 'nyse:CHH', 'nyse:CHMI', 'nyse:CHN', 'nyse:CHRA', 'nyse:CHS', 'nyse:CHT', 'nyse:CHWY', 'nyse:CI', 'nyse:CIA', 'nyse:CIB', 'nyse:CIEN', 'nyse:CIF', 'nyse:CIG', 'nyse:CII', 'nyse:CIM', 'nyse:CINR', 'nyse:CIO', 'nyse:CIR', 'nyse:CIT', 'nyse:CIXX', 'nyse:CKH', 'nyse:CL', 'nyse:CLA', 'nyse:CLB', 'nyse:CLDR', 'nyse:CLDT', 'nyse:CLF', 'nyse:CLGX', 'nyse:CLH', 'nyse:CLI', 'nyse:CLII', 'nyse:CLNC', 'nyse:CLNY', 'nyse:CLPR', 'nyse:CLR', 'nyse:CLS', 'nyse:CLVT', 'nyse:CLW', 'nyse:CLX', 'nyse:CM', 'nyse:CMA', 'nyse:CMC', 'nyse:CMCM', 'nyse:CMD', 'nyse:CMG', 'nyse:CMI', 'nyse:CMO', 'nyse:CMP', 'nyse:CMRE', 'nyse:CMS', 'nyse:CMSA', 'nyse:CMSC', 'nyse:CMSD', 'nyse:CMU', 'nyse:CNA', 'nyse:CNC', 'nyse:CND', 'nyse:CNF', 'nyse:CNHI', 'nyse:CNI', 'nyse:CNK', 'nyse:CNMD', 'nyse:CNNE', 'nyse:CNO', 'nyse:CNP', 'nyse:CNQ', 'nyse:CNR', 'nyse:CNS', 'nyse:CNX', 'nyse:CO', 'nyse:CODI', 'nyse:COE', 'nyse:COF', 'nyse:COG', 'nyse:COLD', 'nyse:COO', 'nyse:COP', 'nyse:COR', 'nyse:CORR', 'nyse:COTY', 'nyse:CP', 'nyse:CPA', 'nyse:CPAC', 'nyse:CPB', 'nyse:CPE', 'nyse:CPF', 'nyse:CPG', 'nyse:CPK', 'nyse:CPLG', 'nyse:CPRI', 'nyse:CPS', 'nyse:CPSR', 'nyse:CPT', 'nyse:CR', 'nyse:CRC', 'nyse:CRD/A', 'nyse:CRD/B', 'nyse:CRH', 'nyse:CRHC', 'nyse:CRI', 'nyse:CRK', 'nyse:CRL', 'nyse:CRM', 'nyse:CRS', 'nyse:CRT', 'nyse:CRY', 'nyse:CS', 'nyse:CSL', 'nyse:CSLT', 'nyse:CSPR', 'nyse:CSR', 'nyse:CSTM', 'nyse:CSU', 'nyse:CSV', 'nyse:CTAA', 'nyse:CTAC', 'nyse:CTB', 'nyse:CTBB', 'nyse:CTDD', 'nyse:CTK', 'nyse:CTLT', 'nyse:CTO', 'nyse:CTR', 'nyse:CTS', 'nyse:CTT', 'nyse:CTVA', 'nyse:CUB', 'nyse:CUBB', 'nyse:CUBE', 'nyse:CUBI', 'nyse:CUK', 'nyse:CULP', 'nyse:CURO', 'nyse:CUZ', 'nyse:CVA', 'nyse:CVE', 'nyse:CVEO', 'nyse:CVI', 'nyse:CVNA', 'nyse:CVS', 'nyse:CVX', 'nyse:CW', 'nyse:CWEN', 'nyse:CWH', 'nyse:CWK', 'nyse:CWT', 'nyse:CX', 'nyse:CXE', 'nyse:CXH', 'nyse:CXP', 'nyse:CXW', 'nyse:CYD', 'nyse:CYH', 'nyse:CZZ', 'nyse:D', 'nyse:DAC', 'nyse:DAL', 'nyse:DAN', 'nyse:DAO', 'nyse:DAR', 'nyse:DASH', 'nyse:DAVA', 'nyse:DB', 'nyse:DBD', 'nyse:DBI', 'nyse:DBL', 'nyse:DCF', 'nyse:DCI', 'nyse:DCO', 'nyse:DCP', 'nyse:DCUE', 'nyse:DD', 'nyse:DDD', 'nyse:DDF', 'nyse:DDS', 'nyse:DDT', 'nyse:DE', 'nyse:DEA', 'nyse:DECK', 'nyse:DEH', 'nyse:DEI', 'nyse:DELL', 'nyse:DEN', 'nyse:DEO', 'nyse:DESP', 'nyse:DEX', 'nyse:DFIN', 'nyse:DFNS', 'nyse:DFP', 'nyse:DFS', 'nyse:DG', 'nyse:DGNR', 'nyse:DGX', 'nyse:DHF', 'nyse:DHI', 'nyse:DHR', 'nyse:DHT', 'nyse:DHX', 'nyse:DIAX', 'nyse:DIN', 'nyse:DIS', 'nyse:DK', 'nyse:DKL', 'nyse:DKS', 'nyse:DL', 'nyse:DLB', 'nyse:DLNG', 'nyse:DLR', 'nyse:DLX', 'nyse:DLY', 'nyse:DM', 'nyse:DMB', 'nyse:DMO', 'nyse:DMS', 'nyse:DMYD', 'nyse:DMYI', 'nyse:DNB', 'nyse:DNK', 'nyse:DNMR', 'nyse:DNOW', 'nyse:DNP', 'nyse:DOC', 'nyse:DOOR', 'nyse:DOV', 'nyse:DOW', 'nyse:DPG', 'nyse:DPZ', 'nyse:DQ', 'nyse:DRD', 'nyse:DRE', 'nyse:DRH', 'nyse:DRI', 'nyse:DRQ', 'nyse:DRUA', 'nyse:DS', 'nyse:DSE', 'nyse:DSL', 'nyse:DSM', 'nyse:DSSI', 'nyse:DSU', 'nyse:DSX', 'nyse:DT', 'nyse:DTB', 'nyse:DTE', 'nyse:DTF', 'nyse:DTJ', 'nyse:DTP', 'nyse:DTW', 'nyse:DTY', 'nyse:DUC', 'nyse:DUK', 'nyse:DUKB', 'nyse:DUKH', 'nyse:DVA', 'nyse:DVD', 'nyse:DVN', 'nyse:DWIN', 'nyse:DX', 'nyse:DXC', 'nyse:DY', 'nyse:DYFN', 'nyse:E', 'nyse:EAF', 'nyse:EAI', 'nyse:EARN', 'nyse:EAT', 'nyse:EB', 'nyse:EBF', 'nyse:EBR', 'nyse:EBS', 'nyse:EC', 'nyse:ECC           ', 'nyse:ECCB', 'nyse:ECCX', 'nyse:ECCY', 'nyse:ECL', 'nyse:ECOM          ', 'nyse:ED', 'nyse:EDD', 'nyse:EDF', 'nyse:EDI', 'nyse:EDN', 'nyse:EDU', 'nyse:EEA', 'nyse:EEX', 'nyse:EFC', 'nyse:EFF', 'nyse:EFL', 'nyse:EFR', 'nyse:EFT', 'nyse:EFX', 'nyse:EGF', 'nyse:EGHT', 'nyse:EGO', 'nyse:EGP', 'nyse:EGY', 'nyse:EHC', 'nyse:EHI', 'nyse:EHT', 'nyse:EIC', 'nyse:EIG', 'nyse:EIX', 'nyse:EL', 'nyse:ELAN', 'nyse:ELAT', 'nyse:ELC', 'nyse:ELF', 'nyse:ELP', 'nyse:ELS', 'nyse:ELVT', 'nyse:ELY', 'nyse:EMD', 'nyse:EME', 'nyse:EMF', 'nyse:EMN', 'nyse:EMO', 'nyse:EMP', 'nyse:EMPW', 'nyse:EMR', 'nyse:ENB', 'nyse:ENBA', 'nyse:ENBL', 'nyse:ENIA', 'nyse:ENIC', 'nyse:ENJ', 'nyse:ENLC', 'nyse:ENO', 'nyse:ENPC', 'nyse:ENR', 'nyse:ENS', 'nyse:ENV', 'nyse:ENVA', 'nyse:ENZ', 'nyse:EOD', 'nyse:EOG', 'nyse:EOI', 'nyse:EOS', 'nyse:EOT', 'nyse:EPAC', 'nyse:EPAM', 'nyse:EPC', 'nyse:EPD', 'nyse:EPR', 'nyse:EPRT', 'nyse:EQC', 'nyse:EQD', 'nyse:EQH', 'nyse:EQNR', 'nyse:EQR', 'nyse:EQS', 'nyse:EQT', 'nyse:ERF', 'nyse:ERJ', 'nyse:ES', 'nyse:ESE', 'nyse:ESGC', 'nyse:ESI', 'nyse:ESNT', 'nyse:ESRT', 'nyse:ESS', 'nyse:ESTC', 'nyse:ESTE', 'nyse:ET', 'nyse:ETB', 'nyse:ETG', 'nyse:ETH', 'nyse:ETJ', 'nyse:ETM', 'nyse:ETN', 'nyse:ETO', 'nyse:ETR', 'nyse:ETRN', 'nyse:ETV', 'nyse:ETW', 'nyse:ETWO', 'nyse:ETX           ', 'nyse:ETY', 'nyse:EURN', 'nyse:EV', 'nyse:EVA', 'nyse:EVC', 'nyse:EVF', 'nyse:EVG', 'nyse:EVH', 'nyse:EVN', 'nyse:EVR', 'nyse:EVRG', 'nyse:EVRI', 'nyse:EVT', 'nyse:EVTC', 'nyse:EW', 'nyse:EXD', 'nyse:EXG', 'nyse:EXK', 'nyse:EXP', 'nyse:EXPR', 'nyse:EXR', 'nyse:EXTN', 'nyse:F', 'nyse:FAF', 'nyse:FAII', 'nyse:FAM', 'nyse:FBC', 'nyse:FBHS', 'nyse:FBK', 'nyse:FBP', 'nyse:FC', 'nyse:FCF', 'nyse:FCN', 'nyse:FCPT', 'nyse:FCRW', 'nyse:FCRZ', 'nyse:FCT', 'nyse:FCX', 'nyse:FDEU', 'nyse:FDP', 'nyse:FDX', 'nyse:FE', 'nyse:FEDU', 'nyse:FEI           ', 'nyse:FENG', 'nyse:FEO', 'nyse:FET', 'nyse:FF', 'nyse:FFA', 'nyse:FFC', 'nyse:FFG', 'nyse:FGB', 'nyse:FGNA', 'nyse:FHI', 'nyse:FHN', 'nyse:FI', 'nyse:FICO', 'nyse:FIF', 'nyse:FINS', 'nyse:FINV', 'nyse:FIS', 'nyse:FIV', 'nyse:FIX', 'nyse:FL', 'nyse:FLC', 'nyse:FLNG', 'nyse:FLO', 'nyse:FLOW', 'nyse:FLR', 'nyse:FLS', 'nyse:FLT', 'nyse:FLY', 'nyse:FMAC', 'nyse:FMC', 'nyse:FMN', 'nyse:FMO', 'nyse:FMS', 'nyse:FMX', 'nyse:FMY', 'nyse:FN', 'nyse:FNB', 'nyse:FND', 'nyse:FNF', 'nyse:FNV', 'nyse:FOE', 'nyse:FOF', 'nyse:FOR', 'nyse:FOUR', 'nyse:FPAC', 'nyse:FPF', 'nyse:FPH', 'nyse:FPI', 'nyse:FPL', 'nyse:FR', 'nyse:FRA', 'nyse:FRC', 'nyse:FRO', 'nyse:FRT', 'nyse:FRX', 'nyse:FSD', 'nyse:FSK', 'nyse:FSKR', 'nyse:FSLF', 'nyse:FSLY', 'nyse:FSM', 'nyse:FSR', 'nyse:FSS', 'nyse:FST', 'nyse:FT', 'nyse:FTAI', 'nyse:FTCH', 'nyse:FTHY', 'nyse:FTI', 'nyse:FTK', 'nyse:FTS', 'nyse:FTV', 'nyse:FUBO', 'nyse:FUL', 'nyse:FUN', 'nyse:FUSE', 'nyse:FVRR', 'nyse:G', 'nyse:GAB', 'nyse:GAM', 'nyse:GATO', 'nyse:GATX', 'nyse:GB', 'nyse:GBAB', 'nyse:GBL', 'nyse:GBX', 'nyse:GCI', 'nyse:GCO', 'nyse:GCP', 'nyse:GCV', 'nyse:GD', 'nyse:GDDY', 'nyse:GDL', 'nyse:GDO', 'nyse:GDOT', 'nyse:GDV', 'nyse:GE', 'nyse:GEF', 'nyse:GEL', 'nyse:GEN           ', 'nyse:GEO', 'nyse:GER', 'nyse:GES', 'nyse:GF', 'nyse:GFF', 'nyse:GFI', 'nyse:GFL', 'nyse:GFLU', 'nyse:GGB', 'nyse:GGG', 'nyse:GGM', 'nyse:GGT', 'nyse:GGZ', 'nyse:GHC', 'nyse:GHG', 'nyse:GHL', 'nyse:GHLD', 'nyse:GHM', 'nyse:GHY', 'nyse:GIB', 'nyse:GIK', 'nyse:GIL', 'nyse:GIM', 'nyse:GIS', 'nyse:GIX', 'nyse:GJH', 'nyse:GJO', 'nyse:GJP', 'nyse:GJR', 'nyse:GJS', 'nyse:GJT', 'nyse:GKOS', 'nyse:GL', 'nyse:GLEO', 'nyse:GLOB', 'nyse:GLOG', 'nyse:GLOP', 'nyse:GLP', 'nyse:GLT', 'nyse:GLW', 'nyse:GM', 'nyse:GME', 'nyse:GMED', 'nyse:GMRE', 'nyse:GMS', 'nyse:GMTA', 'nyse:GNE', 'nyse:GNK', 'nyse:GNL', 'nyse:GNPK', 'nyse:GNRC', 'nyse:GNT', 'nyse:GNW', 'nyse:GOAC', 'nyse:GOF', 'nyse:GOL', 'nyse:GOLD', 'nyse:GOLF', 'nyse:GOOS', 'nyse:GPC', 'nyse:GPI', 'nyse:GPJA', 'nyse:GPK', 'nyse:GPM', 'nyse:GPMT', 'nyse:GPN', 'nyse:GPRK', 'nyse:GPS', 'nyse:GPX', 'nyse:GRA', 'nyse:GRC', 'nyse:GRUB', 'nyse:GRX', 'nyse:GS', 'nyse:GSAH', 'nyse:GSBD', 'nyse:GSK', 'nyse:GSL', 'nyse:GSLD', 'nyse:GSX', 'nyse:GTES', 'nyse:GTLS', 'nyse:GTN', 'nyse:GTS', 'nyse:GTT', 'nyse:GTY', 'nyse:GUT', 'nyse:GVA', 'nyse:GWB', 'nyse:GWRE', 'nyse:GWW', 'nyse:GYC', 'nyse:H', 'nyse:HAE', 'nyse:HAL', 'nyse:HASI', 'nyse:HBB', 'nyse:HBI', 'nyse:HBM', 'nyse:HCA', 'nyse:HCC', 'nyse:HCHC', 'nyse:HCI', 'nyse:HCXY', 'nyse:HCXZ', 'nyse:HD', 'nyse:HDB', 'nyse:HE', 'nyse:HEI', 'nyse:HEI/A', 'nyse:HEP', 'nyse:HEQ', 'nyse:HES', 'nyse:HESM', 'nyse:HEXO', 'nyse:HFC', 'nyse:HFRO', 'nyse:HGH', 'nyse:HGLB', 'nyse:HGV', 'nyse:HHC', 'nyse:HI', 'nyse:HIE', 'nyse:HIG', 'nyse:HIGA', 'nyse:HII', 'nyse:HIL', 'nyse:HIMS', 'nyse:HIO', 'nyse:HIW', 'nyse:HIX', 'nyse:HKIB', 'nyse:HL', 'nyse:HLF', 'nyse:HLI', 'nyse:HLT', 'nyse:HLX', 'nyse:HMC', 'nyse:HMI', 'nyse:HMLP', 'nyse:HMN', 'nyse:HMY', 'nyse:HNGR', 'nyse:HNI', 'nyse:HNP', 'nyse:HOG', 'nyse:HOME', 'nyse:HON', 'nyse:HOV', 'nyse:HP', 'nyse:HPE', 'nyse:HPF', 'nyse:HPI', 'nyse:HPP', 'nyse:HPQ', 'nyse:HPR', 'nyse:HPS', 'nyse:HPX', 'nyse:HQH', 'nyse:HQL', 'nyse:HR', 'nyse:HRB', 'nyse:HRC', 'nyse:HRI', 'nyse:HRL', 'nyse:HRTG', 'nyse:HSBC', 'nyse:HSC', 'nyse:HSY', 'nyse:HT', 'nyse:HTA', 'nyse:HTD', 'nyse:HTFA', 'nyse:HTGC', 'nyse:HTH', 'nyse:HTPA', 'nyse:HTY', 'nyse:HUBB', 'nyse:HUBS', 'nyse:HUM', 'nyse:HUN', 'nyse:HUYA', 'nyse:HVT', 'nyse:HVT/A', 'nyse:HWM', 'nyse:HXL', 'nyse:HY', 'nyse:HYB', 'nyse:HYI', 'nyse:HYLN', 'nyse:HYT', 'nyse:HZAC', 'nyse:HZN', 'nyse:HZO', 'nyse:HZON', 'nyse:IAA', 'nyse:IACA', 'nyse:IAE', 'nyse:IAG', 'nyse:IBA', 'nyse:IBM', 'nyse:IBN', 'nyse:IBP', 'nyse:ICD', 'nyse:ICE', 'nyse:ICL', 'nyse:IDA', 'nyse:IDE', 'nyse:IDT', 'nyse:IEX', 'nyse:IFF', 'nyse:IFFT', 'nyse:IFN', 'nyse:IFS', 'nyse:IGA', 'nyse:IGD', 'nyse:IGI', 'nyse:IGR', 'nyse:IGT', 'nyse:IH', 'nyse:IHC', 'nyse:IHD', 'nyse:IHG', 'nyse:IHIT', 'nyse:IHTA', 'nyse:IIAC', 'nyse:IID', 'nyse:IIF', 'nyse:IIM', 'nyse:IIPR', 'nyse:IMAX', 'nyse:IMPX', 'nyse:INFO', 'nyse:INFY', 'nyse:ING', 'nyse:INGR', 'nyse:INN', 'nyse:INSI', 'nyse:INSP', 'nyse:INSW', 'nyse:INT', 'nyse:INVH', 'nyse:IO', 'nyse:IP', 'nyse:IPG', 'nyse:IPI', 'nyse:IPOD', 'nyse:IPOE', 'nyse:IPOF', 'nyse:IPV', 'nyse:IQI', 'nyse:IQV', 'nyse:IR', 'nyse:IRL', 'nyse:IRM', 'nyse:IRR', 'nyse:IRS', 'nyse:IRT', 'nyse:ISD', 'nyse:IT', 'nyse:ITCB', 'nyse:ITGR', 'nyse:ITT', 'nyse:ITUB', 'nyse:ITW', 'nyse:IVC', 'nyse:IVH', 'nyse:IVR', 'nyse:IVZ', 'nyse:IX', 'nyse:J', 'nyse:JAX', 'nyse:JBGS', 'nyse:JBK', 'nyse:JBL', 'nyse:JBT', 'nyse:JCE', 'nyse:JCI', 'nyse:JCO', 'nyse:JDD', 'nyse:JE', 'nyse:JEF', 'nyse:JELD', 'nyse:JEMD', 'nyse:JEQ', 'nyse:JFR', 'nyse:JGH', 'nyse:JHAA', 'nyse:JHB', 'nyse:JHG', 'nyse:JHI', 'nyse:JHS', 'nyse:JHX', 'nyse:JIH', 'nyse:JILL', 'nyse:JKS', 'nyse:JLL', 'nyse:JLS', 'nyse:JMIA', 'nyse:JMM', 'nyse:JMP', 'nyse:JNJ', 'nyse:JNPR', 'nyse:JOE', 'nyse:JOF', 'nyse:JP', 'nyse:JPC', 'nyse:JPI', 'nyse:JPM', 'nyse:JPS', 'nyse:JPT', 'nyse:JQC', 'nyse:JRI', 'nyse:JRO', 'nyse:JRS', 'nyse:JSD', 'nyse:JT', 'nyse:JTA', 'nyse:JTD', 'nyse:JW/A', 'nyse:JW/B', 'nyse:JWN', 'nyse:JWS', 'nyse:K', 'nyse:KAI', 'nyse:KAMN', 'nyse:KAR', 'nyse:KB', 'nyse:KBH', 'nyse:KBR', 'nyse:KEN', 'nyse:KEP', 'nyse:KEX', 'nyse:KEY', 'nyse:KEYS', 'nyse:KF', 'nyse:KFS', 'nyse:KFY', 'nyse:KGC', 'nyse:KIM', 'nyse:KIO', 'nyse:KKR', 'nyse:KL', 'nyse:KMB', 'nyse:KMF', 'nyse:KMI', 'nyse:KMPR', 'nyse:KMT', 'nyse:KMX', 'nyse:KN', 'nyse:KNL', 'nyse:KNOP', 'nyse:KNX', 'nyse:KO', 'nyse:KODK', 'nyse:KOF', 'nyse:KOP', 'nyse:KOS', 'nyse:KR', 'nyse:KRA', 'nyse:KRC', 'nyse:KREF', 'nyse:KRG', 'nyse:KRO', 'nyse:KRP', 'nyse:KSM', 'nyse:KSS', 'nyse:KSU', 'nyse:KT', 'nyse:KTB', 'nyse:KTF', 'nyse:KTH', 'nyse:KTN', 'nyse:KUKE', 'nyse:KW', 'nyse:KWR', 'nyse:KYN', 'nyse:L', 'nyse:LAC', 'nyse:LAD', 'nyse:LADR', 'nyse:LAIX', 'nyse:LAZ', 'nyse:LB', 'nyse:LBRT', 'nyse:LC', 'nyse:LCI', 'nyse:LCII', 'nyse:LDL', 'nyse:LDOS', 'nyse:LDP', 'nyse:LEA', 'nyse:LEAF', 'nyse:LEAP', 'nyse:LEE', 'nyse:LEG', 'nyse:LEJU', 'nyse:LEN', 'nyse:LEO', 'nyse:LEVI', 'nyse:LFC', 'nyse:LFT', 'nyse:LGI', 'nyse:LGVW', 'nyse:LH', 'nyse:LHX', 'nyse:LII', 'nyse:LIN', 'nyse:LINX', 'nyse:LITB', 'nyse:LL', 'nyse:LLY', 'nyse:LMND', 'nyse:LMT', 'nyse:LNC', 'nyse:LND', 'nyse:LNFA', 'nyse:LNN', 'nyse:LOKB', 'nyse:LOMA', 'nyse:LOW', 'nyse:LPG', 'nyse:LPI', 'nyse:LPL', 'nyse:LPX', 'nyse:LRN', 'nyse:LSI', 'nyse:LSPD', 'nyse:LTC', 'nyse:LTHM', 'nyse:LU', 'nyse:LUB', 'nyse:LUMN', 'nyse:LUV', 'nyse:LVS', 'nyse:LW', 'nyse:LXP', 'nyse:LXU', 'nyse:LYB', 'nyse:LYG', 'nyse:LYV', 'nyse:LZB', 'nyse:M', 'nyse:MA', 'nyse:MAA', 'nyse:MAC', 'nyse:MAIN', 'nyse:MAN', 'nyse:MANU', 'nyse:MAS', 'nyse:MATX', 'nyse:MAV', 'nyse:MAX', 'nyse:MAXR', 'nyse:MBI', 'nyse:MBT', 'nyse:MC', 'nyse:MCA', 'nyse:MCB', 'nyse:MCD', 'nyse:MCI', 'nyse:MCK', 'nyse:MCN', 'nyse:MCO', 'nyse:MCR', 'nyse:MCS', 'nyse:MCY', 'nyse:MD', 'nyse:MDC', 'nyse:MDLA', 'nyse:MDLQ', 'nyse:MDLX', 'nyse:MDLY', 'nyse:MDP', 'nyse:MDT', 'nyse:MDU', 'nyse:MEC', 'nyse:MED', 'nyse:MEG', 'nyse:MEI', 'nyse:MEN', 'nyse:MET', 'nyse:MFA', 'nyse:MFC', 'nyse:MFD', 'nyse:MFG', 'nyse:MFGP', 'nyse:MFL', 'nyse:MFM', 'nyse:MFT', 'nyse:MFV', 'nyse:MG', 'nyse:MGA', 'nyse:MGF', 'nyse:MGM', 'nyse:MGP', 'nyse:MGR', 'nyse:MGRB', 'nyse:MGU', 'nyse:MGY', 'nyse:MHD', 'nyse:MHE', 'nyse:MHF', 'nyse:MHI', 'nyse:MHK', 'nyse:MHLA', 'nyse:MHN', 'nyse:MHNC', 'nyse:MHO', 'nyse:MIC', 'nyse:MIE', 'nyse:MIN', 'nyse:MITT', 'nyse:MIXT', 'nyse:MIY', 'nyse:MKC', 'nyse:MKL', 'nyse:MLI', 'nyse:MLM', 'nyse:MLP', 'nyse:MLR', 'nyse:MMC', 'nyse:MMD', 'nyse:MMI', 'nyse:MMM', 'nyse:MMP', 'nyse:MMS', 'nyse:MMT', 'nyse:MMU', 'nyse:MN', 'nyse:MNP', 'nyse:MNR', 'nyse:MNRL', 'nyse:MNSO', 'nyse:MO', 'nyse:MOD', 'nyse:MODN', 'nyse:MOGU', 'nyse:MOH', 'nyse:MOS', 'nyse:MOTV', 'nyse:MOV', 'nyse:MP', 'nyse:MPA', 'nyse:MPC', 'nyse:MPLN', 'nyse:MPLX', 'nyse:MPV', 'nyse:MPW', 'nyse:MPX', 'nyse:MQT', 'nyse:MQY', 'nyse:MRC', 'nyse:MRK', 'nyse:MRO', 'nyse:MS', 'nyse:MSA', 'nyse:MSB', 'nyse:MSC', 'nyse:MSCI', 'nyse:MSD', 'nyse:MSGE', 'nyse:MSGN', 'nyse:MSGS', 'nyse:MSI', 'nyse:MSM', 'nyse:MSP', 'nyse:MT', 'nyse:MTB', 'nyse:MTCN', 'nyse:MTD', 'nyse:MTDR', 'nyse:MTG', 'nyse:MTH', 'nyse:MTL', 'nyse:MTN', 'nyse:MTOR', 'nyse:MTR', 'nyse:MTRN', 'nyse:MTT', 'nyse:MTW', 'nyse:MTX', 'nyse:MTZ', 'nyse:MUA', 'nyse:MUC', 'nyse:MUE', 'nyse:MUFG', 'nyse:MUH', 'nyse:MUI', 'nyse:MUJ', 'nyse:MUR', 'nyse:MUS', 'nyse:MUSA', 'nyse:MUX', 'nyse:MVF', 'nyse:MVO', 'nyse:MVT', 'nyse:MWA', 'nyse:MX', 'nyse:MXE', 'nyse:MXF', 'nyse:MXL', 'nyse:MYC', 'nyse:MYD', 'nyse:MYE', 'nyse:MYF', 'nyse:MYI', 'nyse:MYJ', 'nyse:MYN', 'nyse:MYOV', 'nyse:MYTE', 'nyse:MZA', 'nyse:NAC', 'nyse:NAD', 'nyse:NAN', 'nyse:NAT', 'nyse:NAV', 'nyse:NAZ', 'nyse:NBB', 'nyse:NBHC', 'nyse:NBR', 'nyse:NC', 'nyse:NCA', 'nyse:NCB', 'nyse:NCLH', 'nyse:NCR', 'nyse:NCV', 'nyse:NCZ', 'nyse:NDMO', 'nyse:NDP', 'nyse:NEA', 'nyse:NEE', 'nyse:NEM', 'nyse:NEP', 'nyse:NET', 'nyse:NEU', 'nyse:NEV', 'nyse:NEW', 'nyse:NEWR', 'nyse:NEX', 'nyse:NEXA', 'nyse:NFG', 'nyse:NFH', 'nyse:NFJ', 'nyse:NGA', 'nyse:NGG', 'nyse:NGL', 'nyse:NGS', 'nyse:NGVC', 'nyse:NGVT', 'nyse:NHA', 'nyse:NHF', 'nyse:NHI', 'nyse:NI', 'nyse:NID', 'nyse:NIE', 'nyse:NIM', 'nyse:NINE', 'nyse:NIO', 'nyse:NIQ', 'nyse:NJR', 'nyse:NJV', 'nyse:NKE', 'nyse:NKG', 'nyse:NKX', 'nyse:NL', 'nyse:NLS', 'nyse:NLSN', 'nyse:NLY', 'nyse:NM', 'nyse:NMCO', 'nyse:NMI', 'nyse:NMM', 'nyse:NMR', 'nyse:NMS', 'nyse:NMT', 'nyse:NMY', 'nyse:NMZ', 'nyse:NNA', 'nyse:NNI', 'nyse:NNN', 'nyse:NNY', 'nyse:NOA', 'nyse:NOAH', 'nyse:NOC', 'nyse:NOK', 'nyse:NOM', 'nyse:NOMD', 'nyse:NOV', 'nyse:NOVA', 'nyse:NOW', 'nyse:NP', 'nyse:NPK', 'nyse:NPN', 'nyse:NPO', 'nyse:NPTN', 'nyse:NPV', 'nyse:NQP', 'nyse:NR', 'nyse:NREF', 'nyse:NRG', 'nyse:NRGX', 'nyse:NRK', 'nyse:NRP', 'nyse:NRT', 'nyse:NRUC', 'nyse:NRZ', 'nyse:NS', 'nyse:NSA', 'nyse:NSC', 'nyse:NSCO', 'nyse:NSH', 'nyse:NSL', 'nyse:NSP', 'nyse:NSS', 'nyse:NTB', 'nyse:NTCO', 'nyse:NTG', 'nyse:NTP', 'nyse:NTR', 'nyse:NTST', 'nyse:NTZ', 'nyse:NUE', 'nyse:NUM', 'nyse:NUO', 'nyse:NUS', 'nyse:NUV', 'nyse:NUW', 'nyse:NVG', 'nyse:NVGS', 'nyse:NVO', 'nyse:NVR', 'nyse:NVRO', 'nyse:NVS', 'nyse:NVST', 'nyse:NVT', 'nyse:NVTA', 'nyse:NWG', 'nyse:NWHM', 'nyse:NWN', 'nyse:NX', 'nyse:NXC', 'nyse:NXJ', 'nyse:NXN', 'nyse:NXP', 'nyse:NXQ', 'nyse:NXR', 'nyse:NXRT', 'nyse:NYC', 'nyse:NYCB', 'nyse:NYT', 'nyse:NYV', 'nyse:NZF', 'nyse:O', 'nyse:OACB', 'nyse:OC', 'nyse:OCA', 'nyse:OCFT', 'nyse:OCN', 'nyse:ODC', 'nyse:OEC', 'nyse:OFC', 'nyse:OFG', 'nyse:OGE', 'nyse:OGS', 'nyse:OHI', 'nyse:OI', 'nyse:OIA', 'nyse:OII', 'nyse:OIS', 'nyse:OKE', 'nyse:OLN', 'nyse:OLP', 'nyse:OMC', 'nyse:OMF', 'nyse:OMI', 'nyse:ONE', 'nyse:ONTF', 'nyse:ONTO', 'nyse:OOMA', 'nyse:OPP', 'nyse:OPY', 'nyse:OR', 'nyse:ORA', 'nyse:ORAN', 'nyse:ORC', 'nyse:ORCC', 'nyse:ORCL', 'nyse:ORI', 'nyse:ORN', 'nyse:OSG', 'nyse:OSH', 'nyse:OSK', 'nyse:OTIS', 'nyse:OUT', 'nyse:OVV', 'nyse:OXM', 'nyse:OXY', 'nyse:PAC', 'nyse:PACE', 'nyse:PACK', 'nyse:PAG', 'nyse:PAGS', 'nyse:PAI', 'nyse:PAM', 'nyse:PANA', 'nyse:PANW', 'nyse:PAR', 'nyse:PARR', 'nyse:PAYC', 'nyse:PB', 'nyse:PBA', 'nyse:PBB', 'nyse:PBC', 'nyse:PBF', 'nyse:PBFX', 'nyse:PBH', 'nyse:PBI', 'nyse:PBR', 'nyse:PBT', 'nyse:PBY', 'nyse:PCF', 'nyse:PCG', 'nyse:PCGU', 'nyse:PCI', 'nyse:PCK', 'nyse:PCM', 'nyse:PCN', 'nyse:PCPC', 'nyse:PCQ', 'nyse:PD', 'nyse:PDAC', 'nyse:PDI', 'nyse:PDM', 'nyse:PDO', 'nyse:PDS', 'nyse:PDT', 'nyse:PEAK', 'nyse:PEB', 'nyse:PEG', 'nyse:PEI', 'nyse:PEN', 'nyse:PEO', 'nyse:PFD', 'nyse:PFE', 'nyse:PFGC', 'nyse:PFH', 'nyse:PFL', 'nyse:PFN', 'nyse:PFO', 'nyse:PFS', 'nyse:PFSI', 'nyse:PG', 'nyse:PGP', 'nyse:PGR', 'nyse:PGRE', 'nyse:PGTI', 'nyse:PGZ', 'nyse:PH', 'nyse:PHD', 'nyse:PHG', 'nyse:PHI', 'nyse:PHK', 'nyse:PHM', 'nyse:PHR', 'nyse:PHT', 'nyse:PHX', 'nyse:PIAI', 'nyse:PII', 'nyse:PIM', 'nyse:PINE', 'nyse:PING', 'nyse:PINS', 'nyse:PIPP', 'nyse:PIPR', 'nyse:PJT', 'nyse:PK', 'nyse:PKE', 'nyse:PKG', 'nyse:PKI', 'nyse:PKO', 'nyse:PKX', 'nyse:PLAN', 'nyse:PLD', 'nyse:PLNT', 'nyse:PLOW', 'nyse:PLT', 'nyse:PLTR', 'nyse:PLYM', 'nyse:PM', 'nyse:PMF', 'nyse:PML', 'nyse:PMM', 'nyse:PMO', 'nyse:PMT', 'nyse:PMVC', 'nyse:PMX', 'nyse:PNC', 'nyse:PNF', 'nyse:PNI', 'nyse:PNM', 'nyse:PNR', 'nyse:PNW', 'nyse:POR', 'nyse:POST', 'nyse:PPG', 'nyse:PPL', 'nyse:PPR', 'nyse:PPT', 'nyse:PPX', 'nyse:PQG', 'nyse:PRA', 'nyse:PRG', 'nyse:PRGO', 'nyse:PRI', 'nyse:PRLB', 'nyse:PRMW', 'nyse:PRO', 'nyse:PROS', 'nyse:PRPB', 'nyse:PRS', 'nyse:PRSP', 'nyse:PRT', 'nyse:PRTY', 'nyse:PRU', 'nyse:PSA', 'nyse:PSB', 'nyse:PSF', 'nyse:PSN', 'nyse:PSO', 'nyse:PSTG', 'nyse:PSTH', 'nyse:PSTL', 'nyse:PSX', 'nyse:PSXP', 'nyse:PTA', 'nyse:PTR', 'nyse:PTY', 'nyse:PUK', 'nyse:PUMP', 'nyse:PVG', 'nyse:PVH', 'nyse:PVL', 'nyse:PWR', 'nyse:PXD', 'nyse:PYN', 'nyse:PYS', 'nyse:PYT', 'nyse:PZC', 'nyse:PZN', 'nyse:QD', 'nyse:QEP', 'nyse:QGEN', 'nyse:QS', 'nyse:QSR', 'nyse:QTS', 'nyse:QTWO', 'nyse:QUAD', 'nyse:QUOT', 'nyse:QVCC', 'nyse:QVCD', 'nyse:R', 'nyse:RA', 'nyse:RACE', 'nyse:RAD', 'nyse:RAMP', 'nyse:RBA', 'nyse:RBAC', 'nyse:RBC', 'nyse:RC', 'nyse:RCA', 'nyse:RCB', 'nyse:RCI', 'nyse:RCL', 'nyse:RCP', 'nyse:RCS', 'nyse:RCUS', 'nyse:RDN', 'nyse:RDS/B', 'nyse:RDY', 'nyse:RE', 'nyse:RELX', 'nyse:RENN', 'nyse:RES', 'nyse:REV', 'nyse:REVG', 'nyse:REX', 'nyse:REXR', 'nyse:REZI', 'nyse:RF', 'nyse:RFI', 'nyse:RFL', 'nyse:RFM', 'nyse:RFP', 'nyse:RGA', 'nyse:RGR', 'nyse:RGS', 'nyse:RGT', 'nyse:RH', 'nyse:RHI', 'nyse:RHP', 'nyse:RICE', 'nyse:RIG', 'nyse:RIO', 'nyse:RIV', 'nyse:RJF', 'nyse:RKT', 'nyse:RL', 'nyse:RLGY', 'nyse:RLH', 'nyse:RLI', 'nyse:RLJ', 'nyse:RLX', 'nyse:RM', 'nyse:RMAX', 'nyse:RMD', 'nyse:RMI', 'nyse:RMM', 'nyse:RMO', 'nyse:RMT', 'nyse:RNG', 'nyse:RNGR', 'nyse:RNP', 'nyse:RNR', 'nyse:ROG', 'nyse:ROK', 'nyse:ROL', 'nyse:ROP', 'nyse:RPAI', 'nyse:RPLA', 'nyse:RPM', 'nyse:RPT', 'nyse:RQI', 'nyse:RRC', 'nyse:RRD', 'nyse:RS', 'nyse:RSF', 'nyse:RSG', 'nyse:RSI', 'nyse:RTP', 'nyse:RTPZ', 'nyse:RTX', 'nyse:RVI', 'nyse:RVLV', 'nyse:RVT', 'nyse:RWT', 'nyse:RXN', 'nyse:RY', 'nyse:RYAM', 'nyse:RYB', 'nyse:RYI', 'nyse:RYN', 'nyse:RZA', 'nyse:RZB', 'nyse:SA', 'nyse:SAF', 'nyse:SAFE', 'nyse:SAH', 'nyse:SAIC', 'nyse:SAIL', 'nyse:SAK', 'nyse:SALT', 'nyse:SAM', 'nyse:SAN', 'nyse:SAND          ', 'nyse:SAP', 'nyse:SAR', 'nyse:SAVE', 'nyse:SB', 'nyse:SBBA', 'nyse:SBE', 'nyse:SBG', 'nyse:SBH', 'nyse:SBI', 'nyse:SBOW', 'nyse:SBR', 'nyse:SBS', 'nyse:SBSW', 'nyse:SC', 'nyse:SCA', 'nyse:SCCO', 'nyse:SCD', 'nyse:SCHW', 'nyse:SCI', 'nyse:SCL', 'nyse:SCM', 'nyse:SCPE', 'nyse:SCS', 'nyse:SCU', 'nyse:SCVX', 'nyse:SCX', 'nyse:SD', 'nyse:SDHY', 'nyse:SE', 'nyse:SEAH', 'nyse:SEAS', 'nyse:SEE', 'nyse:SEM', 'nyse:SF', 'nyse:SFB', 'nyse:SFE', 'nyse:SFL', 'nyse:SFTW', 'nyse:SFUN', 'nyse:SGU', 'nyse:SHAK', 'nyse:SHG', 'nyse:SHI', 'nyse:SHLX', 'nyse:SHO', 'nyse:SHOP', 'nyse:SHW', 'nyse:SI', 'nyse:SID', 'nyse:SIG', 'nyse:SII', 'nyse:SITC', 'nyse:SITE', 'nyse:SIX', 'nyse:SJI', 'nyse:SJIJ', 'nyse:SJIU', 'nyse:SJM', 'nyse:SJR', 'nyse:SJT', 'nyse:SJW', 'nyse:SKLZ', 'nyse:SKM', 'nyse:SKT', 'nyse:SKX', 'nyse:SKY', 'nyse:SLB', 'nyse:SLCA', 'nyse:SLF', 'nyse:SLG', 'nyse:SLQT', 'nyse:SM', 'nyse:SMAR', 'nyse:SMFG', 'nyse:SMG', 'nyse:SMHI', 'nyse:SMLP', 'nyse:SMM', 'nyse:SMP', 'nyse:SNA', 'nyse:SNAP', 'nyse:SNDR', 'nyse:SNE', 'nyse:SNN', 'nyse:SNOW', 'nyse:SNP', 'nyse:SNPR', 'nyse:SNR', 'nyse:SNV', 'nyse:SNX', 'nyse:SO', 'nyse:SOAC', 'nyse:SOGO', 'nyse:SOI', 'nyse:SOJB', 'nyse:SOJC', 'nyse:SOJD', 'nyse:SOJE', 'nyse:SOL', 'nyse:SOLN', 'nyse:SON', 'nyse:SOR', 'nyse:SOS', 'nyse:SPB', 'nyse:SPCE', 'nyse:SPE', 'nyse:SPFR', 'nyse:SPG', 'nyse:SPGI', 'nyse:SPH', 'nyse:SPLP', 'nyse:SPNV', 'nyse:SPOT', 'nyse:SPR', 'nyse:SPRQ', 'nyse:SPXC', 'nyse:SPXX', 'nyse:SQ', 'nyse:SQM', 'nyse:SQNS', 'nyse:SQZ', 'nyse:SR', 'nyse:SRC', 'nyse:SRE', 'nyse:SREA', 'nyse:SRG', 'nyse:SRI', 'nyse:SRL', 'nyse:SRLP', 'nyse:SRT', 'nyse:SRV', 'nyse:SSD', 'nyse:SSL', 'nyse:SSTK', 'nyse:ST', 'nyse:STAG', 'nyse:STAR          ', 'nyse:STC', 'nyse:STE', 'nyse:STG', 'nyse:STIC', 'nyse:STK', 'nyse:STL', 'nyse:STLA', 'nyse:STM', 'nyse:STN', 'nyse:STNG', 'nyse:STON', 'nyse:STOR', 'nyse:STPK', 'nyse:STT', 'nyse:STWD', 'nyse:STZ', 'nyse:STZ/B', 'nyse:SU', 'nyse:SUI', 'nyse:SUM', 'nyse:SUN', 'nyse:SUP', 'nyse:SUPV', 'nyse:SUZ', 'nyse:SWCH', 'nyse:SWI', 'nyse:SWK', 'nyse:SWM', 'nyse:SWN', 'nyse:SWT', 'nyse:SWX', 'nyse:SWZ', 'nyse:SXC', 'nyse:SXI', 'nyse:SXT', 'nyse:SYF', 'nyse:SYK', 'nyse:SYX', 'nyse:SYY', 'nyse:SZC', 'nyse:T', 'nyse:TAC', 'nyse:TACA', 'nyse:TAK', 'nyse:TAL', 'nyse:TALO', 'nyse:TAP', 'nyse:TARO', 'nyse:TBA', 'nyse:TBB', 'nyse:TBC', 'nyse:TBI', 'nyse:TCI', 'nyse:TCP', 'nyse:TCS', 'nyse:TD', 'nyse:TDA', 'nyse:TDC', 'nyse:TDE', 'nyse:TDF', 'nyse:TDG', 'nyse:TDI', 'nyse:TDJ', 'nyse:TDOC', 'nyse:TDS', 'nyse:TDW', 'nyse:TDY', 'nyse:TEAF', 'nyse:TECK', 'nyse:TEF', 'nyse:TEI', 'nyse:TEL', 'nyse:TEN', 'nyse:TEO', 'nyse:TEVA', 'nyse:TEX', 'nyse:TFC', 'nyse:TFII', 'nyse:TFX', 'nyse:TG', 'nyse:TGH', 'nyse:TGI', 'nyse:TGNA', 'nyse:TGP', 'nyse:TGS', 'nyse:TGT', 'nyse:THC', 'nyse:THG', 'nyse:THO', 'nyse:THQ', 'nyse:THR', 'nyse:THS', 'nyse:THW', 'nyse:TIMB', 'nyse:TINV', 'nyse:TISI', 'nyse:TIXT', 'nyse:TJX', 'nyse:TK', 'nyse:TKC', 'nyse:TKR', 'nyse:TLK', 'nyse:TLYS', 'nyse:TM', 'nyse:TME', 'nyse:TMHC', 'nyse:TMO', 'nyse:TMST', 'nyse:TMX', 'nyse:TNC', 'nyse:TNET', 'nyse:TNK', 'nyse:TNP', 'nyse:TOL', 'nyse:TOT', 'nyse:TPB', 'nyse:TPC', 'nyse:TPGY', 'nyse:TPH', 'nyse:TPL', 'nyse:TPR', 'nyse:TPRE', 'nyse:TPVG', 'nyse:TPVY', 'nyse:TPX', 'nyse:TPZ', 'nyse:TR', 'nyse:TRC', 'nyse:TREB', 'nyse:TREC', 'nyse:TREX', 'nyse:TRGP', 'nyse:TRI', 'nyse:TRN', 'nyse:TRNO', 'nyse:TROX', 'nyse:TRP', 'nyse:TRQ', 'nyse:TRTN', 'nyse:TRTX', 'nyse:TRU', 'nyse:TRV', 'nyse:TS', 'nyse:TSE', 'nyse:TSI', 'nyse:TSLX', 'nyse:TSM', 'nyse:TSN', 'nyse:TSQ', 'nyse:TT', 'nyse:TTC', 'nyse:TTI', 'nyse:TTM', 'nyse:TTP', 'nyse:TU', 'nyse:TUFN', 'nyse:TUP', 'nyse:TV', 'nyse:TVC', 'nyse:TVE', 'nyse:TWI', 'nyse:TWLO', 'nyse:TWN', 'nyse:TWND', 'nyse:TWO', 'nyse:TWTR', 'nyse:TX', 'nyse:TXT', 'nyse:TY', 'nyse:TYG', 'nyse:TYL', 'nyse:U', 'nyse:UA', 'nyse:UAA', 'nyse:UAN', 'nyse:UBA', 'nyse:UBER', 'nyse:UBP', 'nyse:UBS', 'nyse:UDR', 'nyse:UE', 'nyse:UFI', 'nyse:UFS', 'nyse:UGI', 'nyse:UGP', 'nyse:UHS', 'nyse:UHT', 'nyse:UI', 'nyse:UIS', 'nyse:UL', 'nyse:UMC', 'nyse:UMH', 'nyse:UNF', 'nyse:UNFI', 'nyse:UNH', 'nyse:UNM', 'nyse:UNMA', 'nyse:UNP', 'nyse:UNVR', 'nyse:UPS', 'nyse:URI', 'nyse:USA', 'nyse:USAC', 'nyse:USB', 'nyse:USDP', 'nyse:USFD', 'nyse:USM', 'nyse:USNA', 'nyse:USPH', 'nyse:USX', 'nyse:UTF', 'nyse:UTI', 'nyse:UTL', 'nyse:UTZ', 'nyse:UVE', 'nyse:UVV', 'nyse:UWMC', 'nyse:UZA', 'nyse:UZB', 'nyse:UZC', 'nyse:UZD', 'nyse:UZE', 'nyse:V', 'nyse:VAC', 'nyse:VALE', 'nyse:VAPO', 'nyse:VAR', 'nyse:VBF', 'nyse:VCIF', 'nyse:VCRA', 'nyse:VCV', 'nyse:VEC', 'nyse:VEDL', 'nyse:VEEV', 'nyse:VEL', 'nyse:VER', 'nyse:VET', 'nyse:VFC', 'nyse:VGAC', 'nyse:VGI', 'nyse:VGM', 'nyse:VGR', 'nyse:VHC', 'nyse:VHI', 'nyse:VIAO', 'nyse:VICI', 'nyse:VIPS', 'nyse:VIST', 'nyse:VIV', 'nyse:VKQ', 'nyse:VLO', 'nyse:VLRS', 'nyse:VLT', 'nyse:VMC', 'nyse:VMI', 'nyse:VMO', 'nyse:VMW', 'nyse:VNCE', 'nyse:VNE', 'nyse:VNO', 'nyse:VNT', 'nyse:VNTR', 'nyse:VOC', 'nyse:VOYA', 'nyse:VPG', 'nyse:VPV', 'nyse:VRS', 'nyse:VRT', 'nyse:VRTV', 'nyse:VSH', 'nyse:VST', 'nyse:VSTO', 'nyse:VTA', 'nyse:VTN', 'nyse:VTOL', 'nyse:VTR', 'nyse:VVI', 'nyse:VVNT', 'nyse:VVR', 'nyse:VVV', 'nyse:VYGG', 'nyse:W', 'nyse:WAB', 'nyse:WAL', 'nyse:WALA', 'nyse:WAT', 'nyse:WBAI', 'nyse:WBK', 'nyse:WBS', 'nyse:WBT', 'nyse:WCC', 'nyse:WCN', 'nyse:WD', 'nyse:WDR', 'nyse:WEA', 'nyse:WEC', 'nyse:WEI', 'nyse:WELL', 'nyse:WES', 'nyse:WEX', 'nyse:WF', 'nyse:WFC', 'nyse:WFG', 'nyse:WGO', 'nyse:WH', 'nyse:WHD', 'nyse:WHG', 'nyse:WHR', 'nyse:WIA', 'nyse:WIT', 'nyse:WIW', 'nyse:WK', 'nyse:WLK', 'nyse:WLKP', 'nyse:WLL', 'nyse:WM', 'nyse:WMB', 'nyse:WMC', 'nyse:WMK', 'nyse:WMS', 'nyse:WMT', 'nyse:WNC', 'nyse:WNS', 'nyse:WOR', 'nyse:WORK', 'nyse:WOW', 'nyse:WPC', 'nyse:WPF', 'nyse:WPG', 'nyse:WPM', 'nyse:WPP', 'nyse:WRB', 'nyse:WRE', 'nyse:WRI', 'nyse:WRK', 'nyse:WSM', 'nyse:WSO', 'nyse:WSO/B', 'nyse:WSR', 'nyse:WST', 'nyse:WTI', 'nyse:WTM', 'nyse:WTRG', 'nyse:WTRU', 'nyse:WTS', 'nyse:WTTR', 'nyse:WU', 'nyse:WWE', 'nyse:WWW', 'nyse:WY', 'nyse:WYND', 'nyse:X', 'nyse:XAN', 'nyse:XEC', 'nyse:XFLT', 'nyse:XHR', 'nyse:XIN', 'nyse:XL', 'nyse:XOM', 'nyse:XPEV', 'nyse:XPO', 'nyse:XPOA', 'nyse:XRX', 'nyse:XYF', 'nyse:XYL', 'nyse:Y', 'nyse:YAC', 'nyse:YALA', 'nyse:YELP', 'nyse:YETI', 'nyse:YEXT', 'nyse:YPF', 'nyse:YRD', 'nyse:YSG', 'nyse:YUM', 'nyse:YUMC', 'nyse:ZBH', 'nyse:ZEN', 'nyse:ZIM', 'nyse:ZNH', 'nyse:ZTO', 'nyse:ZTR', 'nyse:ZTS', 'nyse:ZUO', 'nyse:ZYME',  ]

# %%
tickers = [
'nyse:WGO',
'nyse:WH',
'nyse:WHD',
'nyse:WHG',
'nyse:WHR',
'nyse:WIA',
'nyse:WIT',
'nyse:WIW',
'nyse:WK',
'nyse:WLK',
'nyse:WLKP',
'nyse:WLL',
'nyse:WM',
'nyse:WMB',
'nyse:WMC',
'nyse:WMK',
'nyse:WMS',
'nyse:WMT',
'nyse:WNC',
'nyse:WNS',
'nyse:WOR',
'nyse:WORK',
'nyse:WOW',
'nyse:WPC',
'nyse:WPF',
'nyse:WPG',
'nyse:WPM',
'nyse:WPP',
'nyse:WRB',
'nyse:WRE',
'nyse:WRI',
'nyse:WRK',
'nyse:WSM',
'nyse:WSO',
'nyse:WSO/B',
'nyse:WSR',
'nyse:WST',
'nyse:WTI',
'nyse:WTM',
'nyse:WTRG',
'nyse:WTRU',
'nyse:WTS',
'nyse:WTTR',
'nyse:WU',
'nyse:WWE',
'nyse:WWW',
'nyse:WY',
'nyse:WYND',
'nyse:X',
'nyse:XAN',
'nyse:XEC',
'nyse:XFLT',
'nyse:XHR',
'nyse:XIN',
'nyse:XL',
'nyse:XOM',
'nyse:XPEV',
'nyse:XPO',
'nyse:XPOA',
'nyse:XRX',
'nyse:XYF',
'nyse:XYL',
'nyse:Y',
'nyse:YAC',
'nyse:YALA',
'nyse:YELP',
'nyse:YETI',
'nyse:YEXT',
'nyse:YPF',
'nyse:YRD',
'nyse:YSG',
'nyse:YUM',
'nyse:YUMC',
'nyse:ZBH',
'nyse:ZEN',
'nyse:ZIM',
'nyse:ZNH',
'nyse:ZTO',
'nyse:ZTR',
'nyse:ZTS',
'nyse:ZUO',
'nyse:ZYME',
]

# %%
def rdpModelReturn(payoutRatio, PE, returnOnEquity):
    return (1 + returnOnEquity*(1-payoutRatio))*(1+payoutRatio/PE)-1

# %%
cookies = {
  "_ga": "GA1.2.465595028.1610542879",
  " ajs_anonymous_id": "%229fa85477-0683-4967-a2f4-5e4289755b69%22",
  " gclid": "undefined",
  " ajs_user_id": "%2256bb7b06d6377f0b00fb6640%22",
  " jitta_nu": "2",
  " hunt7586-_zldp": "ss%2BYrC93NjNPjMVjGzdz%2F7UmKMbXaQiIpI2z3bqlTvYr3icTQcalwR7hfL9yLBo3T3IUrdIYs4k%3D",
  " _hjTLDTest": "1",
  " _hjid": "1aaa3b21-3699-4b5c-bf7a-827a3a7080eb",
  " JDCID": "7549935af7b604712397f9e6073c0ca61e2283149f7d8f4902c29587c831d8ac.5439c914472955e6ecc4ac71c9a4f2c5dbfb045dc7df3ba0b4b66079cb3e506c755327157f5bbd49210a4b2cc4dec3851703061b2413e31845162f61f94110a261b435e1405ca208b920a0f8f433b0620c295848890c",
  " _gid": "GA1.2.980595266.1612585235",
  " hunt7586-_zldt": "ec44337e-837b-4a92-80c7-a9ca9e45ac70-1",
  " mp_d55123f7330a45efc28a32923e676d48_mixpanel": "%7B%22distinct_id%22%3A%20%2256bb7b06d6377f0b00fb6640%22%2C%22%24device_id%22%3A%20%22176fbd61699958-0e8600597c19b9-31346d-1fa400-176fbd6169ad4c%22%2C%22%24initial_referrer%22%3A%20%22%24direct%22%2C%22%24initial_referring_domain%22%3A%20%22%24direct%22%2C%22%24search_engine%22%3A%20%22google%22%2C%22%24user_id%22%3A%20%2256bb7b06d6377f0b00fb6640%22%7D"
}

# %%
def convert_row_to_data(row):
    r = row.find_all('span')
    c = map(lambda x: p2f(x.text), r)
    return list(c)

def p2f(x):
    cx = x.replace('%', '').replace(',', '')
    return None if cx == '- -' else float(cx)/100

# %%
def calculate(ticker):
    with requests.post('https://www.jitta.com/stock/' + ticker + '/factsheet', cookies=cookies) as r:
        soup = BeautifulSoup(r.content, 'lxml')
        row = soup.find_all('div', {'class': 'dAGwCX'})

        if len(row) == 0:
            return  {
            "TICKER": ticker,
            "AVG_G_THEORY": None,
            "AVG_ROE": None,
            "AVG_DPR": None,
            "LAST_G_THEORY": None,
            "LAST_ROE": None,
            "LAST_DPR": None,
            "NEGATIVE_ROE": None,
            "COUNT_ROE": None,
        }

        EPS = convert_row_to_data(row[1]) 
        ROE = convert_row_to_data(row[20])
        ROA = convert_row_to_data(row[21])
        DE = convert_row_to_data(row[23])
        DPR = convert_row_to_data(row[24])
        avg_ROE = 0
        last_ROE = 0
        negative_ROE = 0
        avg_DPR = 0
        last_DPR = 0
        c_ROE = 0
        avg_g_theory = 0
        last_g_theory = 0
        avg_g_empirical = 0
        c_g = 0
        print(ROE)
        for i in range(0, len(ROE)):
            if ROE[i] == None:
                continue

            dpr = 0 if DPR[i] == None else DPR[i]
            avg_g_theory += ROE[i] * (1 - dpr)
            avg_ROE += ROE[i]
            avg_DPR += dpr
            c_ROE += 1
            last_ROE = ROE[i]
            last_DPR = dpr
            last_g_theory = ROE[i] * (1 - dpr)

            if ROE[i] < 0:
                negative_ROE += 1

        avg_ROE /= c_ROE
        avg_DPR /= c_ROE
        avg_DPR = 0 if avg_DPR == None else avg_DPR
        avg_g_theory /= c_ROE

        return {
            "TICKER": ticker,
            "AVG_G_THEORY": avg_g_theory,
            "AVG_ROE": avg_ROE,
            "AVG_DPR": avg_DPR,
            "LAST_G_THEORY": last_g_theory,
            "LAST_ROE": last_ROE,
            "LAST_DPR": last_DPR,
            "NEGATIVE_ROE": negative_ROE,
            "COUNT_ROE": c_ROE,

        }

# %%
f = open('stock-screen.csv', 'w')
f.write('ticker|AVG_G_THEORY|AVG_ROE|AVG_DPR|LAST_G_THEORY|LAST_ROE|LAST_DPR|NEGATIVE_ROE|COUNT_ROE\n')

def fetch_stock(ticker):
    data = calculate(ticker)
    print(data)
    if data['AVG_G_THEORY'] == None:
        return
        
    f.write(ticker + '|' + 
        '{:.4f}'.format(data['AVG_G_THEORY']) + '|' +
        '{:.4f}'.format(data['AVG_ROE']) + '|' +
        '{:.4f}'.format(data['AVG_DPR']) + '|' +
        '{:.4f}'.format(data['LAST_G_THEORY']) + '|' +
        '{:.4f}'.format(data['LAST_ROE']) + '|' +
        '{:.4f}'.format(data['LAST_DPR']) + '|' + 
        '{}'.format(data['NEGATIVE_ROE']) + '|' + 
        '{}'.format(data['COUNT_ROE']) + '\n'
       )

# %%
threads  = []
for ticker in tickers:
    fetch_stock(ticker)
#      t = threading.Thread(target=fetch_stock, args=(ticker,))
#      threads.append(t)
#      t.start()
        
# for t in threads:
#     t.join()   

f.close()
